# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/mini_project/파이널프로젝트_RAW_210329_210926.xlsx')
df.head()
# Out:
#        id  customer_id  course_id     type      state  \
# 0  970634     504760.0   201435.0    ORDER  CANCELLED
# 1  970650     432862.0   203178.0    ORDER  CANCELLED
# 2  970657      72297.0   204246.0  PAYMENT  COMPLETED
# 3  970656      72297.0   204246.0    ORDER  CANCELLED
# 4  970658     478028.0   201797.0  PAYMENT  COMPLETED
#
#                     course_title category_title  format        completed_at  \
# 0      올인원 패키지 : 알고리즘 기술면접 완전 정복          프로그래밍     올인원 2021-03-28 15:00:11
# 1    초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원 2021-03-28 15:16:53
# 2           시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인 2021-03-28 15:21:43
# 3           시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인 2021-03-28 15:21:43
# 4  올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성     올인원 2021-03-28 15:21:54
#
#    transaction_amount              coupon_title  coupon_discount_amount  \
# 0               90500                       NaN                     NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105419 entries, 0 to 105418
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      105419 non-null  int64
#  1   customer_id             105416 non-null  float64
#  2   course_id               100212 non-null  float64
#  3   type                    105419 non-null  object
#  4   state                   105419 non-null  object
#  5   course_title            105403 non-null  object
#  6   category_title          105395 non-null  object
#  7   format                  105403 non-null  object
#  8   completed_at            105419 non-null  datetime64[ns]
#  9   transaction_amount      105419 non-null  int64
#  10  coupon_title            31817 non-null   object
#  11  coupon_discount_amount  31817 non-null   float64
#  12  sale_price              104291 non-null  float64
# ...

# %%
df = df[['customer_id', 'course_id', 'type', 'state' , 'course_title', 'category_title', 'format', 'completed_at', 'transaction_amount', 'coupon_title', 'coupon_discount_amount', 'sale_price', 'pg', 'method', 'subcategory_title', 'marketing_start_at']]
df.head()
# Out:
#    customer_id  course_id     type      state                   course_title  \
# 0     504760.0   201435.0    ORDER  CANCELLED      올인원 패키지 : 알고리즘 기술면접 완전 정복
# 1     432862.0   203178.0    ORDER  CANCELLED    초격차 패키지 : 한번에 끝내는 영상 촬영과 편집
# 2      72297.0   204246.0  PAYMENT  COMPLETED           시크릿코드 : 프론트엔드 실무 완성편
# 3      72297.0   204246.0    ORDER  CANCELLED           시크릿코드 : 프론트엔드 실무 완성편
# 4     478028.0   201797.0  PAYMENT  COMPLETED  올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX
#
#   category_title  format        completed_at  transaction_amount  \
# 0          프로그래밍     올인원 2021-03-28 15:00:11               90500
# 1          영상/3D     올인원 2021-03-28 15:16:53               96000
# 2          프로그래밍  스쿨 온라인 2021-03-28 15:21:43              171810
# 3          프로그래밍  스쿨 온라인 2021-03-28 15:21:43              171810
# 4         업무 생산성     올인원 2021-03-28 15:21:54               97500
#
#                coupon_title  coupon_discount_amount  sale_price   pg method  \
# ...

# %% [markdown]
# ## 구매자 [PAYMENT.COMPLETED.customer_id - REFUND.COMPLETED.customer_id]

# %%
a = df['type'] == 'PAYMENT'
a = df[a]
b = a['state'] == 'COMPLETED'
a = a[b]
a
# Out:
#         customer_id  course_id     type      state  \
# 2           72297.0   204246.0  PAYMENT  COMPLETED
# 4          478028.0   201797.0  PAYMENT  COMPLETED
# 8          478033.0   203178.0  PAYMENT  COMPLETED
# 10         469860.0   203644.0  PAYMENT  COMPLETED
# 14         478035.0   203720.0  PAYMENT  COMPLETED
# ...             ...        ...      ...        ...
# 105411     669238.0   204286.0  PAYMENT  COMPLETED
# 105412     384003.0   203178.0  PAYMENT  COMPLETED
# 105413     670891.0   203935.0  PAYMENT  COMPLETED
# 105416     640697.0   205365.0  PAYMENT  COMPLETED
# 105418     610626.0   206720.0  PAYMENT  COMPLETED
#
#                                           course_title category_title  format  \
# 2                                 시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인
# 4                        올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성     올인원
# 8                          초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원
# ...

# %%
df['type'].unique()
# Out:
# array(['ORDER', 'PAYMENT', 'REFUND', 'TRANSACTION'], dtype=object)

# %%
c = df['type'] == 'REFUND'
c = df[c]
d = c['state'] == 'COMPLETED'
b = c[d]
b
# Out:
#         customer_id  course_id    type      state  \
# 651        444760.0   204122.0  REFUND  COMPLETED
# 652        472666.0   203178.0  REFUND  COMPLETED
# 666        447177.0   203989.0  REFUND  COMPLETED
# 672        373915.0   204264.0  REFUND  COMPLETED
# 675        456086.0        NaN  REFUND  COMPLETED
# ...             ...        ...     ...        ...
# 105169     600073.0   206065.0  REFUND  COMPLETED
# 105175     645911.0        NaN  REFUND  COMPLETED
# 105205     506356.0   206720.0  REFUND  COMPLETED
# 105245     604077.0   205569.0  REFUND  COMPLETED
# 105248     552100.0   203525.0  REFUND  COMPLETED
#
#                                             course_title category_title  \
# 651                               퍼포먼스 마케터 되기 온라인 완주반 2기            마케팅
# 652                          초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D
# 666                   올인원 패키지 : 소금툰과 함께 캐릭터 드로잉/굿즈/임티/컷툰            디자인
# ...

# %%
df_total = pd.merge(a,b,how='outer')
df_total
# Out:
#        customer_id  course_id     type      state  \
# 0          72297.0   204246.0  PAYMENT  COMPLETED
# 1         478028.0   201797.0  PAYMENT  COMPLETED
# 2         478033.0   203178.0  PAYMENT  COMPLETED
# 3         469860.0   203644.0  PAYMENT  COMPLETED
# 4         478035.0   203720.0  PAYMENT  COMPLETED
# ...            ...        ...      ...        ...
# 56719     600073.0   206065.0   REFUND  COMPLETED
# 56720     645911.0        NaN   REFUND  COMPLETED
# 56721     506356.0   206720.0   REFUND  COMPLETED
# 56722     604077.0   205569.0   REFUND  COMPLETED
# 56723     552100.0   203525.0   REFUND  COMPLETED
#
#                                            course_title category_title  \
# 0                                  시크릿코드 : 프론트엔드 실무 완성편          프로그래밍
# 1                         올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성
# 2                           초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D
# 3        올인원 패키지 : 권오상의 금융 아카데미 - 권오상의 재무제표 분석 기초(평생소장)         부동산/금융
# ...

# %%
df_total = df_total.drop_duplicates(subset='customer_id')

# %%
df_pay = df_total['type'] == 'PAYMENT'
df_pay = df_total[df_pay]
df_pay
# Out:
#        customer_id  course_id     type      state  \
# 0          72297.0   204246.0  PAYMENT  COMPLETED
# 1         478028.0   201797.0  PAYMENT  COMPLETED
# 2         478033.0   203178.0  PAYMENT  COMPLETED
# 3         469860.0   203644.0  PAYMENT  COMPLETED
# 4         478035.0   203720.0  PAYMENT  COMPLETED
# ...            ...        ...      ...        ...
# 52896     545804.0        NaN  PAYMENT  COMPLETED
# 52897     669238.0   204286.0  PAYMENT  COMPLETED
# 52899     670891.0   203935.0  PAYMENT  COMPLETED
# 52900     640697.0   205365.0  PAYMENT  COMPLETED
# 52901     610626.0   206720.0  PAYMENT  COMPLETED
#
#                                          course_title category_title  format  \
# 0                                시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인
# 1                       올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성     올인원
# 2                         초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원
# ...

# %% [markdown]
# ## category 8개로 축약하기

# %%
df['category_title'].value_counts().to_frame()
# Out:
#           category_title
# 프로그래밍              34430
# 데이터사이언스            14076
# 업무 생산성             13323
# 디자인                12009
# 영상/3D              10260
# 마케팅                 9857
# 부동산/금융              5523
# 투자/재테크              2501
# 크리에이티브              2250
# 교육                  1031
# 지식콘텐츠                 56
# 비즈니스                  42
# 파이낸스                  25
# 데이터 사이언스               9
# 관리                     2
# 일러스트                   1

# %%
df = df.replace({'category_title':{'데이터 사이언스':'데이터사이언스'}})
#프레임 내부 데이터를 바꾸고 싶다면 {column이름:{원래 있는 것을:이렇게 바꾼다}}
df['category_title'].value_counts().to_frame()
# Out:
#          category_title
# 프로그래밍             34430
# 데이터사이언스           14085
# 업무 생산성            13323
# 디자인               12010
# 영상/3D             10260
# 마케팅                9857
# 부동산/금융             5523
# 투자/재테크             2501
# 크리에이티브             2250
# 교육                 1031
# 지식콘텐츠                56
# 비즈니스                 42
# 파이낸스                 25
# 관리                    2

# %%
df.isna().sum()
# Out:
# customer_id                   3
# course_id                  5207
# type                          0
# state                         0
# course_title                 16
# category_title               24
# format                       16
# completed_at                  0
# transaction_amount            0
# coupon_title              73602
# coupon_discount_amount    73602
# sale_price                 1128
# pg                        15075
# method                    13096
# subcategory_title         19829
# marketing_start_at        17979
# dtype: int64

# %%
test_df = df.copy()
test_df = test_df.dropna(subset=['category_title'])

# %%
test_df.isna().sum()
# Out:
# customer_id                   0
# course_id                  5130
# type                          0
# state                         0
# course_title                  0
# category_title                0
# format                        0
# completed_at                  0
# transaction_amount            0
# coupon_title              73457
# coupon_discount_amount    73457
# sale_price                 1110
# pg                        15055
# method                    13075
# subcategory_title         19680
# marketing_start_at        17897
# dtype: int64

# %%
test_df = test_df[test_df.category_title != '파이낸스']
test_df['category_title'].value_counts().to_frame()
# Out:
#          category_title
# 프로그래밍             34430
# 데이터사이언스           14085
# 업무 생산성            13323
# 디자인               12010
# 영상/3D             10260
# 마케팅                9857
# 부동산/금융             5523
# 투자/재테크             2501
# 크리에이티브             2250
# 교육                 1031

# %%
test_df
# Out:
#         customer_id  course_id     type      state  \
# 0          504760.0   201435.0    ORDER  CANCELLED
# 1          432862.0   203178.0    ORDER  CANCELLED
# 2           72297.0   204246.0  PAYMENT  COMPLETED
# 3           72297.0   204246.0    ORDER  CANCELLED
# 4          478028.0   201797.0  PAYMENT  COMPLETED
# ...             ...        ...      ...        ...
# 105414     640697.0   205365.0  PAYMENT  CANCELLED
# 105415     670896.0   204159.0  PAYMENT  CANCELLED
# 105416     640697.0   205365.0  PAYMENT  COMPLETED
# 105417     670896.0   204159.0  PAYMENT  CANCELLED
# 105418     610626.0   206720.0  PAYMENT  COMPLETED
#
#                            course_title category_title  format  \
# 0             올인원 패키지 : 알고리즘 기술면접 완전 정복          프로그래밍     올인원
# 1           초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원
# 2                  시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인
# 3                  시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105419 entries, 0 to 105418
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   customer_id             105416 non-null  float64
#  1   course_id               100212 non-null  float64
#  2   type                    105419 non-null  object
#  3   state                   105419 non-null  object
#  4   course_title            105403 non-null  object
#  5   category_title          105395 non-null  object
#  6   format                  105403 non-null  object
#  7   completed_at            105419 non-null  datetime64[ns]
#  8   transaction_amount      105419 non-null  int64
#  9   coupon_title            31817 non-null   object
#  10  coupon_discount_amount  31817 non-null   float64
#  11  sale_price              104291 non-null  float64
#  12  pg                      90344 non-null   object
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 105270 entries, 0 to 105418
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   customer_id             105270 non-null  float64
#  1   course_id               100140 non-null  float64
#  2   type                    105270 non-null  object
#  3   state                   105270 non-null  object
#  4   course_title            105270 non-null  object
#  5   category_title          105270 non-null  object
#  6   format                  105270 non-null  object
#  7   completed_at            105270 non-null  datetime64[ns]
#  8   transaction_amount      105270 non-null  int64
#  9   coupon_title            31813 non-null   object
#  10  coupon_discount_amount  31813 non-null   float64
#  11  sale_price              104160 non-null  float64
#  12  pg                      90215 non-null   object
# ...

# %%
df = test_df

# %% [markdown]
# ## a

# %%
sample.loc[sample.category_title.str.contains('데이터 사이언스'), 'category_title'] # = '데이터사이언스'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-16d56f084410> in <module>()
#       1 from typing import Container
# ----> 2 sample.loc[sample.category_title.str.contains('데이터 사이언스'), 'category_title'] # = '데이터사이언스'
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1098     def _getitem_tuple(self, tup: tuple):
#    1099         with suppress(IndexingError):
# -> 1100             return self._getitem_lowerdim(tup)
#    1101
# ...

# %%
a = df['category_title'].value_counts()
a.to_frame()
# Out:
#          category_title
# 프로그래밍             34430
# 데이터사이언스           14085
# 업무 생산성            13323
# 디자인               12010
# 영상/3D             10260
# 마케팅                9857
# 부동산/금융             5523
# 투자/재테크             2501
# 크리에이티브             2250
# 교육                 1031

# %%
df['coupon_title'].value_counts()
# Out:
# [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                                 5498
# [WELCOME] 온라인 강의 3만원 할인쿠폰                                3206
# [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰                                 2469
# [WELCOME] 온라인 강의 2만원 할인쿠폰                                2325
# [WELCOME] 온라인 강의 1만원 할인쿠폰                                1900
#                                                          ...
# [무료수강권] 한 번에 끝내는 Java/Spring 웹 개발 마스터 초격차 패키지_안성훈 강사님       1
# [무료수강권] RED 검수용_공정필 PM님                                     1
# [서포터즈 전용] 재무/세무 회계 실무 완성 무료 수강                              1
# [서포터즈 전용] Financial Modeling 무료 수강                          1
# [재결제쿠폰]초격차 패키지 : 한 번에 끝내는 node.js 웹 프로그래밍                   1
# Name: coupon_title, Length: 492, dtype: int64

# %%
# df['coupon_title'] == '[웰컴쿠폰]' | df['coupon_title'] == '[WELCOME]'
df[(df['coupon_title'].str.contains('만원')) | (df['coupon_title'].str.contains(''))]
# Out:
#         customer_id  course_id     type      state  \
# 4          478028.0   201797.0  PAYMENT  COMPLETED
# 8          478033.0   203178.0  PAYMENT  COMPLETED
# 14         478035.0   203720.0  PAYMENT  COMPLETED
# 15         478035.0   203720.0    ORDER  CANCELLED
# 28         471759.0   204068.0  PAYMENT  COMPLETED
# ...             ...        ...      ...        ...
# 105393     638903.0   203178.0  PAYMENT  COMPLETED
# 105396     623392.0   206060.0  PAYMENT  CANCELLED
# 105414     640697.0   205365.0  PAYMENT  CANCELLED
# 105416     640697.0   205365.0  PAYMENT  COMPLETED
# 105418     610626.0   206720.0  PAYMENT  COMPLETED
#
#                                     course_title category_title format  \
# 4                  올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성    올인원
# 8                    초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D    올인원
# 14                   초격차 패키지 : 한 번에 끝내는 프론트엔드 개발          프로그래밍    올인원
# ...

# %%
# Out:
# 179

# %%
df['pg'].unique()
# Out:
# array([nan, 'INICIS', 'KAKAO', 'CHAI', 'PAYCO', 'NAVER'], dtype=object)

# %%
df['course_title'].unique()
# Out:
# array(['올인원 패키지 : 알고리즘 기술면접 완전 정복', '초격차 패키지 : 한번에 끝내는 영상 촬영과 편집',
#        '시크릿코드 : 프론트엔드 실무 완성편', ..., '(B2B) 그린오션스 온라인 구독 올 플랜 - 비대면바우처',
#        '(B2B) 디캠프 패밀리사 온라인 구독 올 플랜 (9월)',
#        '(B2B) (주)오디 온라인 구독 올 플랜 - 비대면바우처'], dtype=object)

# %%
df['category_title'].unique()
# Out:
# array(['프로그래밍', '영상/3D', '업무 생산성', '크리에이티브', '부동산/금융', '데이터사이언스', '디자인',
#        '마케팅', '교육', '투자/재테크', nan, '관리', '데이터 사이언스', '비즈니스', '지식콘텐츠',
#        '일러스트', '파이낸스'], dtype=object)

# %%
df['format'].unique()
# Out:
# array(['올인원', '스쿨 온라인', '온라인 완주반', 'RED', 'B2B 온라인', '캠프', '스쿨', nan,
#        'B2B', '이벤트', '하루10분컷', '아카이브', '관리', '온라인', 'MBA', '콜로소', 'B2G'],
#       dtype=object)

# %%
df['coupon_title'].unique()
# Out:
# array([nan, '[10% 할인] 시크릿코드 실무 완성편', '[웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰',
#        '[웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰', '[웰컴쿠폰] 온라인 완주반 5만원 할인 쿠폰',
#        '?즉시할인 쿠폰 코드 : spring5% ?', '[럭키룰렛] 올인원패키지',
#        '[웰컴쿠폰] 올인원 패키지 3만원 할인 쿠폰', '타이포그래피 기수강생 할인 쿠폰',
#        '[할인쿠폰] 파이낸스 카테고리 올인원 패키지 30% 할인 (금융 아카데미 제외)', '[럭키룰렛] 완주반',
#        '[10% 할인] 프론트엔드 실무 완성편',
#        '한 번에 끝내는 Java/Sring 웹 개발 마스터 초격차 패키지 무료 쿠폰 (-2/28)',
#        '수강생 50만명 돌파 기념 감사제 쿠폰', '올인원 패키지 : 타이포그래피와 편집디자인 강의 수강권',
#        '[무료수강권] 강의 검수용_이호상 PM님', '패캐머_온라인 쿠폰 !',
#        '[무료수강권] 파이낸스 카테고리 올인원 패키지_대체투자 자산운용 실무 영상 오픈 일정 변경',
#        '한 번에 끝내는 반복 업무 자동화 초격차 패키지 사용 가능 쿠폰', 'crm 검수용 쿠폰 aop',
#        '[쿠폰재발급]수강생 50만명 돌파 기념 감사제 쿠폰', '[재발급] 페이백 쿠폰',
#        '[무료수강권] 강의검수용_강사님 쿠폰_박혜린 강사님', '신해동 발행 쿠폰', '[무료수강권] 강사님 제공용 RED',
#        '[무료수강권] 강사님 제공용', '[할인쿠폰] 영상/디자인 카테고리 올인원 패키지 5만원 할인_영상 오픈 일정 변경',
#        '[무료수강권] 내부직원 검수용 RED',
#        '[무료수강권] 올인원 패키지 : 인스타를 성장시킨 50명의 성공 방정식 강의검수용_강사님 쿠폰', '올인원패키지',
# ...

# %%
df['coupon_discount_amount'].nunique()
# Out:
# 773

# %%
df['method'].unique()
# Out:
# array(['VBANK', 'CARD', 'TRANS', 'PROMOTION', 'TRANSFER', 'ONSITE',
#        'B2B_CONTRACT', nan, 'POINT', 'VOUCHER'], dtype=object)

# %%
df['subcategory_title'].unique()
# Out:
# array(['개발자 커리어', '영상 편집', nan, 'PPT/보고서', '금융/투자 실무', '프론트엔드 개발',
#        'DevOps', 'UX/UI', '머신러닝', '모션그래픽', '딥러닝/인공지능', '글쓰기/카피라이팅',
#        '디지털마케팅', '엑셀/VBA', '데이터분석', '디자인툴', '모바일앱', '업무자동화', 'SNS마케팅',
#        '게임', '회계/재무/세무', '부동산 개발', '시각디자인', '백엔드 개발', '데이터마케팅', '일러스트',
#        '부동산 투자', '코딩 입문', '커뮤니케이션', '리더십', '주식 투자', '게임 그래픽', '데이터엔지니어링',
#        'VFX'], dtype=object)

# %% [markdown]
# ## 1. 전체 강의 수강률 > 결제 금액과 연관성 > 할인(쿠폰) 연관성

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105419 entries, 0 to 105418
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      105419 non-null  int64
#  1   customer_id             105416 non-null  float64
#  2   course_id               100212 non-null  float64
#  3   type                    105419 non-null  object
#  4   state                   105419 non-null  object
#  5   course_title            105403 non-null  object
#  6   category_title          105395 non-null  object
#  7   format                  105403 non-null  object
#  8   completed_at            105419 non-null  datetime64[ns]
#  9   transaction_amount      105419 non-null  int64
#  10  coupon_title            31817 non-null   object
#  11  coupon_discount_amount  31817 non-null   float64
#  12  sale_price              104291 non-null  float64
# ...

# %%
# 전체 강의 수강률

df["course_title"].value_counts()
# Out:
# 초격차 패키지 : 한 번에 끝내는 프론트엔드 개발               3257
# 초격차 패키지 : 한번에 끝내는 Java/Spring 웹 개발 마스터    2756
# 초격차 패키지 : 한번에 끝내는 영상 촬영과 편집               2541
# The RED : 김영하 작가의 내 안의 숨은 이야기를 찾아 쓰는 법    2132
# 올인원 패키지 : star741의 캐주얼 일러스트 드로잉           1636
#                                           ...
# (B2B) 미니랜드 온라인 구독 올 플랜 - 비대면바우처              1
# (B2B) (주)유투바이오 온라인 구독 패키지 플랜 - 비대면바우처        1
# (B2B) 카테크 온라인 구독 올 플랜 - 비대면바우처               1
# (B2B) 주식회사 마링 온라인 구독 올 플랜 - 비대면바우처           1
# (B2B) (주)오디 온라인 구독 올 플랜 - 비대면바우처             1
# Name: course_title, Length: 1641, dtype: int64

# %%
df['course_title'].nunique()
# Out:
# 1641

# %%
df.isna().sum()
# Out:
# id                            0
# customer_id                   3
# course_id                  5207
# type                          0
# state                         0
# course_title                 16
# category_title               24
# format                       16
# completed_at                  0
# transaction_amount            0
# coupon_title              73602
# coupon_discount_amount    73602
# sale_price                 1128
# tax_free_amount            1128
# pg                        15075
# method                    13096
# subcategory_title         19829
# marketing_start_at        17979
# dtype: int64

# %%
cour_ti = df.dropna(subset=['course_title'])
cour_ti.isna().sum()
# Out:
# id                            0
# customer_id                   0
# course_id                  5191
# type                          0
# state                         0
# course_title                  0
# category_title                8
# format                        0
# completed_at                  0
# transaction_amount            0
# coupon_title              73586
# coupon_discount_amount    73586
# sale_price                 1112
# tax_free_amount            1112
# pg                        15059
# method                    13096
# subcategory_title         19813
# marketing_start_at        17963
# dtype: int64

# %%
cour_ti['course_title']
# Out:
# 0               올인원 패키지 : 알고리즘 기술면접 완전 정복
# 1             초격차 패키지 : 한번에 끝내는 영상 촬영과 편집
# 2                    시크릿코드 : 프론트엔드 실무 완성편
# 3                    시크릿코드 : 프론트엔드 실무 완성편
# 4           올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX
#                        ...
# 105414    초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기
# 105415                부동산 디벨로퍼 아카데미 : 인허가
# 105416    초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기
# 105417                부동산 디벨로퍼 아카데미 : 인허가
# 105418                 용호수의 돈 버는 실전 영상 제작
# Name: course_title, Length: 105403, dtype: object

# %%
coti_df = cour_ti[cour_ti['course_title'].str.contains('패키지')]
co_df = coti_df[['course_title', 'transaction_amount']].value_counts()
cdf = co_df.to_frame()
cdf
# sns.scatterplot(data=cdf)
# Out:
#                                                                          0
# course_title                                       transaction_amount
# 올인원 패키지 : star741의 캐주얼 일러스트 드로잉                    144000              573
# 초격차 패키지 : 일잘러 필수 스킬 모음.zip                         109000              553
# 올인원 패키지 : 아카데미 : 편집하는여자의 영상편집 마스터클래스 - 제 1강 프리미... 98000               541
# 초격차 패키지 : 한 번에 끝내는 프론트엔드 개발                        95000               463
#                                                    116000              454
# ...                                                                    ...
# 올인원 패키지 : 수학적으로 접근하는 딥러닝                           76000                 1
#                                                    76500                 1
#                                                    84000                 1
#                                                    85000                 1
# 올인원 패키지 : 아파트 말고 부동산 재테크 시작하기                      222000                1
#
# ...

# %%
cdf.columns
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
df[['course_title', 'transaction_amount', 'sale_price']]
# Out:
#                            course_title  transaction_amount  sale_price
# 0             올인원 패키지 : 알고리즘 기술면접 완전 정복               90500    110500.0
# 1           초격차 패키지 : 한번에 끝내는 영상 촬영과 편집               96000    116000.0
# 2                  시크릿코드 : 프론트엔드 실무 완성편              171810    190900.0
# 3                  시크릿코드 : 프론트엔드 실무 완성편              171810    190900.0
# 4         올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX               97500    117500.0
# ...                                 ...                 ...         ...
# 105414  초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기               96000    116000.0
# 105415              부동산 디벨로퍼 아카데미 : 인허가              189000    189000.0
# 105416  초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기               96000    116000.0
# 105417              부동산 디벨로퍼 아카데미 : 인허가              189000    189000.0
# 105418               용호수의 돈 버는 실전 영상 제작              139000    169000.0
#
# [105419 rows x 3 columns]

# %%
co_ti = df.groupby('course_title').mean()
co_ti
# Out:
#                                                 id    customer_id  course_id  \
# course_title
# (B2B)  컨테이너 랩 온라인 구독 올 플랜 - 비대면바우처    1.130005e+06  556177.000000   205478.0
# (B2B) (재)은행권청년창업재단 온라인 구독 올 플랜        1.274762e+06  557372.000000   205213.0
# (B2B) (주)가이던스 온라인 구독 올 플랜 - 비대면바우처    1.216739e+06  594286.000000   206267.0
# (B2B) (주)경원테크 온라인 구독 올 플랜 - 비대면바우처    1.085206e+06  535617.000000   205327.0
# (B2B) (주)공정씨컴퍼니 온라인 구독 올 플랜 - 비대면바우처  1.367252e+06  672301.000000   207714.0
# ...                                            ...            ...        ...
# 프론트엔드 개발자 되기 온라인 완주반 3기               9.957672e+05  333459.794118   204265.0
# 프론트엔드 개발자 되기 온라인 완주반 4기               1.073298e+06  424479.656863   205058.0
# 합격 패스 : ADsP                          1.029687e+06  418192.495822   202589.0
# 합격 패스 : 데이터베이스와 SQLD                  1.134520e+06  418817.864789   202698.0
# 합격 패스 : 정보처리기사 필기&실기                  1.160277e+06  409125.182398   201518.0
#
# ...

# %%
df[['course_title', 'transaction_amount', 'sale_price']].value_counts()
# Out:
# course_title                            transaction_amount  sale_price
# The RED : 김영하 작가의 내 안의 숨은 이야기를 찾아 쓰는 법  140000              140000.0      880
# 네카라쿠배 프론트엔드 취업완성 스쿨 2기_1차 테스트           0                   1.0           875
# The RED : 김영하 작가의 내 안의 숨은 이야기를 찾아 쓰는 법  149000              149000.0      606
# 올인원 패키지 : star741의 캐주얼 일러스트 드로잉         144000              144000.0      559
# 합격 패스 : 정보처리기사 필기&실기                    9900                9900.0        527
#                                                                          ...
# 올인원 패키지 : 부동산 투자                        26000               115000.0        1
#                                         25500               116500.0        1
#                                         24000               147000.0        1
#                                         23500               115500.0        1
# 올인원 패키지 : 소금툰과 함께 캐릭터 드로잉/굿즈/임티/컷툰      26000               95000.0         1
# Length: 10576, dtype: int64

# %% [markdown]
# ## 2. pg/method를 통해 결제 수단 통계 > 결제 금액과 연관성

# %%
df[['pg', 'method']].value_counts()
# Out:
# pg      method
# INICIS  CARD        50823
#         VBANK        7138
# KAKAO   POINT        6174
#         CARD         3528
# NAVER   CARD         3350
# INICIS  TRANS        2126
# PAYCO   CARD         1839
# NAVER   POINT        1276
# PAYCO   POINT         634
# NAVER   TRANS         197
# CHAI    TRANS         154
# PAYCO   VBANK           8
#         TRANSFER        1
# dtype: int64

# %%
df['transaction_amount'].value_counts()
# Out:
#  0         4736
#  299000    2191
#  99000     1906
#  119000    1649
#  149000    1616
#            ...
#  53700        1
#  58700        1
#  94300        1
# -186666       1
# -108186       1
# Name: transaction_amount, Length: 2393, dtype: int64

# %%
adf = df['transaction_amount'] == '0'
adf[[adf, 'courts_title']]
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/common.py:241: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = np.asarray(values, dtype=dtype)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-135-6f47f9f9f407> in <module>()
#       1 adf = df['transaction_amount'] == '0'
# ----> 2 adf[[adf, 'courts_title']]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     964             return self._get_values(key)
#     965
# --> 966         return self._get_with(key)
#     967
#     968     def _get_with(self, key):
#
# ...

# %% [markdown]
# ## 3. 강의 종류의 따른 수강 통계 > 마케팅 시작(달 기준) or 금액과 연관성
