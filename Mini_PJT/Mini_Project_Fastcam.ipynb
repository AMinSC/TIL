# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/mini_project/파이널프로젝트_RAW_210329_210926.xlsx')
df.head()
# Out:
#        id  customer_id  course_id     type      state  \
# 0  970634     504760.0   201435.0    ORDER  CANCELLED
# 1  970650     432862.0   203178.0    ORDER  CANCELLED
# 2  970657      72297.0   204246.0  PAYMENT  COMPLETED
# 3  970656      72297.0   204246.0    ORDER  CANCELLED
# 4  970658     478028.0   201797.0  PAYMENT  COMPLETED
#
#                     course_title category_title  format        completed_at  \
# 0      올인원 패키지 : 알고리즘 기술면접 완전 정복          프로그래밍     올인원 2021-03-28 15:00:11
# 1    초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원 2021-03-28 15:16:53
# 2           시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인 2021-03-28 15:21:43
# 3           시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인 2021-03-28 15:21:43
# 4  올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성     올인원 2021-03-28 15:21:54
#
#    transaction_amount              coupon_title  coupon_discount_amount  \
# 0               90500                       NaN                     NaN
# 1               96000                       NaN                     NaN
# 2              171810     [10% 할인] 시크릿코드 실무 완성편                 19090.0
# 3              171810                       NaN                     NaN
# 4               97500  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
#
#    sale_price  tax_free_amount   pg method subcategory_title  \
# 0    110500.0         110500.0  NaN  VBANK           개발자 커리어
# 1    116000.0         116000.0  NaN   CARD             영상 편집
# 2    190900.0         190900.0  NaN   CARD               NaN
# 3    190900.0         190900.0  NaN   CARD               NaN
# 4    117500.0         117500.0  NaN   CARD           PPT/보고서
#
#   marketing_start_at
# 0                NaT
# 1         2020-12-02
# 2         2021-03-04
# 3         2021-03-04
# 4         2019-11-14

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105419 entries, 0 to 105418
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      105419 non-null  int64
#  1   customer_id             105416 non-null  float64
#  2   course_id               100212 non-null  float64
#  3   type                    105419 non-null  object
#  4   state                   105419 non-null  object
#  5   course_title            105403 non-null  object
#  6   category_title          105395 non-null  object
#  7   format                  105403 non-null  object
#  8   completed_at            105419 non-null  datetime64[ns]
#  9   transaction_amount      105419 non-null  int64
#  10  coupon_title            31817 non-null   object
#  11  coupon_discount_amount  31817 non-null   float64
#  12  sale_price              104291 non-null  float64
#  13  tax_free_amount         104291 non-null  float64
#  14  pg                      90344 non-null   object
#  15  method                  92323 non-null   object
#  16  subcategory_title       85590 non-null   object
#  17  marketing_start_at      87440 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(5), int64(2), object(9)
# memory usage: 14.5+ MB

# %%
df = df[['customer_id', 'course_id', 'type', 'state' , 'course_title', 'category_title', 'format', 'completed_at', 'transaction_amount', 'coupon_title', 'coupon_discount_amount', 'sale_price', 'pg', 'method', 'subcategory_title', 'marketing_start_at']]
df.head()
# Out:
#    customer_id  course_id     type      state                   course_title  \
# 0     504760.0   201435.0    ORDER  CANCELLED      올인원 패키지 : 알고리즘 기술면접 완전 정복
# 1     432862.0   203178.0    ORDER  CANCELLED    초격차 패키지 : 한번에 끝내는 영상 촬영과 편집
# 2      72297.0   204246.0  PAYMENT  COMPLETED           시크릿코드 : 프론트엔드 실무 완성편
# 3      72297.0   204246.0    ORDER  CANCELLED           시크릿코드 : 프론트엔드 실무 완성편
# 4     478028.0   201797.0  PAYMENT  COMPLETED  올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX
#
#   category_title  format        completed_at  transaction_amount  \
# 0          프로그래밍     올인원 2021-03-28 15:00:11               90500
# 1          영상/3D     올인원 2021-03-28 15:16:53               96000
# 2          프로그래밍  스쿨 온라인 2021-03-28 15:21:43              171810
# 3          프로그래밍  스쿨 온라인 2021-03-28 15:21:43              171810
# 4         업무 생산성     올인원 2021-03-28 15:21:54               97500
#
#                coupon_title  coupon_discount_amount  sale_price   pg method  \
# 0                       NaN                     NaN    110500.0  NaN  VBANK
# 1                       NaN                     NaN    116000.0  NaN   CARD
# 2     [10% 할인] 시크릿코드 실무 완성편                 19090.0    190900.0  NaN   CARD
# 3                       NaN                     NaN    190900.0  NaN   CARD
# 4  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0    117500.0  NaN   CARD
#
#   subcategory_title marketing_start_at
# 0           개발자 커리어                NaT
# 1             영상 편집         2020-12-02
# 2               NaN         2021-03-04
# 3               NaN         2021-03-04
# 4           PPT/보고서         2019-11-14

# %% [markdown]
# ## 구매자 [PAYMENT.COMPLETED.customer_id - REFUND.COMPLETED.customer_id]

# %%
a = df['type'] == 'PAYMENT'
a = df[a]
b = a['state'] == 'COMPLETED'
a = a[b]
a
# Out:
#              id  customer_id  course_id     type      state  \
# 2        970657      72297.0   204246.0  PAYMENT  COMPLETED
# 4        970658     478028.0   201797.0  PAYMENT  COMPLETED
# 8        970669     478033.0   203178.0  PAYMENT  COMPLETED
# 10       970671     469860.0   203644.0  PAYMENT  COMPLETED
# 14       970676     478035.0   203720.0  PAYMENT  COMPLETED
# ...         ...          ...        ...      ...        ...
# 105411  1364969     669238.0   204286.0  PAYMENT  COMPLETED
# 105412  1364976     384003.0   203178.0  PAYMENT  COMPLETED
# 105413  1364991     670891.0   203935.0  PAYMENT  COMPLETED
# 105416  1364996     640697.0   205365.0  PAYMENT  COMPLETED
# 105418  1365007     610626.0   206720.0  PAYMENT  COMPLETED
#
#                                           course_title category_title  format  \
# 2                                 시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인
# 4                        올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성     올인원
# 8                          초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원
# 10      올인원 패키지 : 권오상의 금융 아카데미 - 권오상의 재무제표 분석 기초(평생소장)         부동산/금융     올인원
# 14                         초격차 패키지 : 한 번에 끝내는 프론트엔드 개발          프로그래밍     올인원
# ...                                                ...            ...     ...
# 105411                      초격차 패키지 : 한번에 끝내는 3D 디자인 툴            디자인     올인원
# 105412                     초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원
# 105413                     초격차 패키지 : 한 번에 끝내는 파이썬 웹 개발          프로그래밍     올인원
# 105416                 초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기          영상/3D     올인원
# 105418                              용호수의 돈 버는 실전 영상 제작          영상/3D     올인원
#
#               completed_at  transaction_amount               coupon_title  \
# 2      2021-03-28 15:21:43              171810      [10% 할인] 시크릿코드 실무 완성편
# 4      2021-03-28 15:21:54               97500   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 8      2021-03-28 15:26:47               96000   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 10     2021-03-28 15:27:17              263000                        NaN
# 14     2021-03-28 15:31:01               91000   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# ...                    ...                 ...                        ...
# 105411 2021-09-25 13:39:26              212000    [미래투자금] 온라인 강의 2만원 할인쿠폰
# 105412 2021-09-25 13:46:29              149000                        NaN
# 105413 2021-09-25 14:01:26              159000    [미래투자금] 온라인 강의 2만원 할인쿠폰
# 105416 2021-09-25 14:17:41               96000  [WELCOME] 온라인 강의 2만원 할인쿠폰
# 105418 2021-09-25 14:25:47              139000  [WELCOME] 온라인 강의 3만원 할인쿠폰
#
#         coupon_discount_amount  sale_price  tax_free_amount      pg method  \
# 2                      19090.0    190900.0         190900.0     NaN   CARD
# 4                      20000.0    117500.0         117500.0     NaN   CARD
# 8                      20000.0    116000.0         116000.0     NaN   CARD
# 10                         NaN    263000.0         263000.0     NaN   CARD
# 14                     20000.0    111000.0         111000.0     NaN   CARD
# ...                        ...         ...              ...     ...    ...
# 105411                 20000.0    232000.0         232000.0  INICIS   CARD
# 105412                     NaN    149000.0         149000.0   KAKAO   CARD
# 105413                 20000.0    179000.0         179000.0  INICIS   CARD
# 105416                 20000.0    116000.0         116000.0  INICIS  VBANK
# 105418                 30000.0    169000.0         169000.0   NAVER  POINT
#
#        subcategory_title marketing_start_at
# 2                    NaN         2021-03-04
# 4                PPT/보고서         2019-11-14
# 8                  영상 편집         2020-12-02
# 10                   NaN         2020-11-27
# 14              프론트엔드 개발         2021-02-02
# ...                  ...                ...
# 105411              디자인툴         2021-04-23
# 105412             영상 편집         2020-12-02
# 105413            백엔드 개발         2021-05-31
# 105416             영상 편집         2021-06-15
# 105418             영상 편집         2021-08-17
#
# [52902 rows x 18 columns]

# %%
df['type'].unique()
# Out:
# array(['ORDER', 'PAYMENT', 'REFUND', 'TRANSACTION'], dtype=object)

# %%
c = df['type'] == 'REFUND'
c = df[c]
d = c['state'] == 'COMPLETED'
b = c[d]
b
# Out:
#              id  customer_id  course_id    type      state  \
# 651      972377     444760.0   204122.0  REFUND  COMPLETED
# 652      972381     472666.0   203178.0  REFUND  COMPLETED
# 666      972409     447177.0   203989.0  REFUND  COMPLETED
# 672      972422     373915.0   204264.0  REFUND  COMPLETED
# 675      972436     456086.0        NaN  REFUND  COMPLETED
# ...         ...          ...        ...     ...        ...
# 105169  1363708     600073.0   206065.0  REFUND  COMPLETED
# 105175  1363721     645911.0        NaN  REFUND  COMPLETED
# 105205  1363934     506356.0   206720.0  REFUND  COMPLETED
# 105245  1364149     604077.0   205569.0  REFUND  COMPLETED
# 105248  1364217     552100.0   203525.0  REFUND  COMPLETED
#
#                                             course_title category_title  \
# 651                               퍼포먼스 마케터 되기 온라인 완주반 2기            마케팅
# 652                          초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D
# 666                   올인원 패키지 : 소금툰과 함께 캐릭터 드로잉/굿즈/임티/컷툰            디자인
# 672                            데이터분석 프로젝트+자격증 온라인 완주반 3기        데이터사이언스
# 675               프로모션 :연봉 앞자리가 바뀌는 프론트엔드 한끝세트 (3월 프리패스)          프로그래밍
# ...                                                  ...            ...
# 105169  (프로모션 7/16-7/29) 초격차 패키지 : 한 번에 끝내는 Spring 완.전.판          프로그래밍
# 105175              프로모션 : 콘텐츠 마케터 맥북 air 패스(9월 현물 프리패스)            마케팅
# 105205                                용호수의 돈 버는 실전 영상 제작          영상/3D
# 105245                     올인원 패키지 : 공여사와 무작정 풀어보는 엑셀 실무         업무 생산성
# 105248            초격차 패키지 : 한번에 끝내는 Java/Spring 웹 개발 마스터          프로그래밍
#
#          format        completed_at  transaction_amount coupon_title  \
# 651     온라인 완주반 2021-03-29 09:24:43             -147000          NaN
# 652         올인원 2021-03-29 09:26:13              -96000          NaN
# 666         올인원 2021-03-29 09:40:54              -79000          NaN
# 672     온라인 완주반 2021-03-29 09:44:01             -340000          NaN
# 675         올인원 2021-03-29 09:47:17             -299000          NaN
# ...         ...                 ...                 ...          ...
# 105169      올인원 2021-09-24 14:34:50             -149000          NaN
# 105175      올인원 2021-09-24 14:41:35            -1400000          NaN
# 105205      올인원 2021-09-24 16:10:55             -259000          NaN
# 105245      올인원 2021-09-24 17:09:30             -109000          NaN
# 105248      올인원 2021-09-24 17:33:53             -108186          NaN
#
#         coupon_discount_amount  sale_price  tax_free_amount      pg method  \
# 651                        NaN    404000.0         404000.0     NaN  VBANK
# 652                        NaN    116000.0         116000.0     NaN   CARD
# 666                        NaN     89000.0          89000.0     NaN   CARD
# 672                        NaN    340000.0         340000.0     NaN  VBANK
# 675                        NaN    299000.0         299000.0     NaN   CARD
# ...                        ...         ...              ...     ...    ...
# 105169                     NaN    179000.0         179000.0   NAVER   CARD
# 105175                     NaN   1400000.0         251600.0  INICIS   CARD
# 105205                     NaN    259000.0         259000.0   NAVER   CARD
# 105245                     NaN    129000.0         129000.0   KAKAO  POINT
# 105248                     NaN    114000.0         114000.0  INICIS   CARD
#
#        subcategory_title marketing_start_at
# 651                  NaN                NaT
# 652                영상 편집         2020-12-02
# 666                 일러스트         2021-02-19
# 672                  NaN         2021-03-08
# 675                  NaN                NaT
# ...                  ...                ...
# 105169            백엔드 개발         2021-07-15
# 105175               NaN                NaT
# 105205             영상 편집         2021-08-17
# 105245            엑셀/VBA         2021-08-17
# 105248            백엔드 개발         2021-02-01
#
# [3822 rows x 18 columns]

# %%
df_total = pd.merge(a,b,how='outer')
df_total
# Out:
#             id  customer_id  course_id     type      state  \
# 0       970657      72297.0   204246.0  PAYMENT  COMPLETED
# 1       970658     478028.0   201797.0  PAYMENT  COMPLETED
# 2       970669     478033.0   203178.0  PAYMENT  COMPLETED
# 3       970671     469860.0   203644.0  PAYMENT  COMPLETED
# 4       970676     478035.0   203720.0  PAYMENT  COMPLETED
# ...        ...          ...        ...      ...        ...
# 56719  1363708     600073.0   206065.0   REFUND  COMPLETED
# 56720  1363721     645911.0        NaN   REFUND  COMPLETED
# 56721  1363934     506356.0   206720.0   REFUND  COMPLETED
# 56722  1364149     604077.0   205569.0   REFUND  COMPLETED
# 56723  1364217     552100.0   203525.0   REFUND  COMPLETED
#
#                                            course_title category_title  \
# 0                                  시크릿코드 : 프론트엔드 실무 완성편          프로그래밍
# 1                         올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성
# 2                           초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D
# 3        올인원 패키지 : 권오상의 금융 아카데미 - 권오상의 재무제표 분석 기초(평생소장)         부동산/금융
# 4                           초격차 패키지 : 한 번에 끝내는 프론트엔드 개발          프로그래밍
# ...                                                 ...            ...
# 56719  (프로모션 7/16-7/29) 초격차 패키지 : 한 번에 끝내는 Spring 완.전.판          프로그래밍
# 56720              프로모션 : 콘텐츠 마케터 맥북 air 패스(9월 현물 프리패스)            마케팅
# 56721                                용호수의 돈 버는 실전 영상 제작          영상/3D
# 56722                     올인원 패키지 : 공여사와 무작정 풀어보는 엑셀 실무         업무 생산성
# 56723            초격차 패키지 : 한번에 끝내는 Java/Spring 웹 개발 마스터          프로그래밍
#
#        format        completed_at  transaction_amount  \
# 0      스쿨 온라인 2021-03-28 15:21:43              171810
# 1         올인원 2021-03-28 15:21:54               97500
# 2         올인원 2021-03-28 15:26:47               96000
# 3         올인원 2021-03-28 15:27:17              263000
# 4         올인원 2021-03-28 15:31:01               91000
# ...       ...                 ...                 ...
# 56719     올인원 2021-09-24 14:34:50             -149000
# 56720     올인원 2021-09-24 14:41:35            -1400000
# 56721     올인원 2021-09-24 16:10:55             -259000
# 56722     올인원 2021-09-24 17:09:30             -109000
# 56723     올인원 2021-09-24 17:33:53             -108186
#
#                    coupon_title  coupon_discount_amount  sale_price  \
# 0         [10% 할인] 시크릿코드 실무 완성편                 19090.0    190900.0
# 1      [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0    117500.0
# 2      [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0    116000.0
# 3                           NaN                     NaN    263000.0
# 4      [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0    111000.0
# ...                         ...                     ...         ...
# 56719                       NaN                     NaN    179000.0
# 56720                       NaN                     NaN   1400000.0
# 56721                       NaN                     NaN    259000.0
# 56722                       NaN                     NaN    129000.0
# 56723                       NaN                     NaN    114000.0
#
#        tax_free_amount      pg method subcategory_title marketing_start_at
# 0             190900.0     NaN   CARD               NaN         2021-03-04
# 1             117500.0     NaN   CARD           PPT/보고서         2019-11-14
# 2             116000.0     NaN   CARD             영상 편집         2020-12-02
# 3             263000.0     NaN   CARD               NaN         2020-11-27
# 4             111000.0     NaN   CARD          프론트엔드 개발         2021-02-02
# ...                ...     ...    ...               ...                ...
# 56719         179000.0   NAVER   CARD            백엔드 개발         2021-07-15
# 56720         251600.0  INICIS   CARD               NaN                NaT
# 56721         259000.0   NAVER   CARD             영상 편집         2021-08-17
# 56722         129000.0   KAKAO  POINT            엑셀/VBA         2021-08-17
# 56723         114000.0  INICIS   CARD            백엔드 개발         2021-02-01
#
# [56724 rows x 18 columns]

# %%
df_total = df_total.drop_duplicates(subset='customer_id')

# %%
df_pay = df_total['type'] == 'PAYMENT'
df_pay = df_total[df_pay]
df_pay
# Out:
#             id  customer_id  course_id     type      state  \
# 0       970657      72297.0   204246.0  PAYMENT  COMPLETED
# 1       970658     478028.0   201797.0  PAYMENT  COMPLETED
# 2       970669     478033.0   203178.0  PAYMENT  COMPLETED
# 3       970671     469860.0   203644.0  PAYMENT  COMPLETED
# 4       970676     478035.0   203720.0  PAYMENT  COMPLETED
# ...        ...          ...        ...      ...        ...
# 52896  1364956     545804.0        NaN  PAYMENT  COMPLETED
# 52897  1364969     669238.0   204286.0  PAYMENT  COMPLETED
# 52899  1364991     670891.0   203935.0  PAYMENT  COMPLETED
# 52900  1364996     640697.0   205365.0  PAYMENT  COMPLETED
# 52901  1365007     610626.0   206720.0  PAYMENT  COMPLETED
#
#                                          course_title category_title  format  \
# 0                                시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인
# 1                       올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성     올인원
# 2                         초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원
# 3      올인원 패키지 : 권오상의 금융 아카데미 - 권오상의 재무제표 분석 기초(평생소장)         부동산/금융     올인원
# 4                         초격차 패키지 : 한 번에 끝내는 프론트엔드 개발          프로그래밍     올인원
# ...                                               ...            ...     ...
# 52896                프로모션 : 디자인 맥북 pro 패스(9월 현물 프리패스)            디자인     올인원
# 52897                      초격차 패키지 : 한번에 끝내는 3D 디자인 툴            디자인     올인원
# 52899                     초격차 패키지 : 한 번에 끝내는 파이썬 웹 개발          프로그래밍     올인원
# 52900                 초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기          영상/3D     올인원
# 52901                              용호수의 돈 버는 실전 영상 제작          영상/3D     올인원
#
#              completed_at  transaction_amount               coupon_title  \
# 0     2021-03-28 15:21:43              171810      [10% 할인] 시크릿코드 실무 완성편
# 1     2021-03-28 15:21:54               97500   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 2     2021-03-28 15:26:47               96000   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 3     2021-03-28 15:27:17              263000                        NaN
# 4     2021-03-28 15:31:01               91000   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# ...                   ...                 ...                        ...
# 52896 2021-09-25 13:25:49             1800000                        NaN
# 52897 2021-09-25 13:39:26              212000    [미래투자금] 온라인 강의 2만원 할인쿠폰
# 52899 2021-09-25 14:01:26              159000    [미래투자금] 온라인 강의 2만원 할인쿠폰
# 52900 2021-09-25 14:17:41               96000  [WELCOME] 온라인 강의 2만원 할인쿠폰
# 52901 2021-09-25 14:25:47              139000  [WELCOME] 온라인 강의 3만원 할인쿠폰
#
#        coupon_discount_amount  sale_price  tax_free_amount      pg method  \
# 0                     19090.0    190900.0         190900.0     NaN   CARD
# 1                     20000.0    117500.0         117500.0     NaN   CARD
# 2                     20000.0    116000.0         116000.0     NaN   CARD
# 3                         NaN    263000.0         263000.0     NaN   CARD
# 4                     20000.0    111000.0         111000.0     NaN   CARD
# ...                       ...         ...              ...     ...    ...
# 52896                     NaN   1800000.0         295200.0  INICIS   CARD
# 52897                 20000.0    232000.0         232000.0  INICIS   CARD
# 52899                 20000.0    179000.0         179000.0  INICIS   CARD
# 52900                 20000.0    116000.0         116000.0  INICIS  VBANK
# 52901                 30000.0    169000.0         169000.0   NAVER  POINT
#
#       subcategory_title marketing_start_at
# 0                   NaN         2021-03-04
# 1               PPT/보고서         2019-11-14
# 2                 영상 편집         2020-12-02
# 3                   NaN         2020-11-27
# 4              프론트엔드 개발         2021-02-02
# ...                 ...                ...
# 52896               NaN                NaT
# 52897              디자인툴         2021-04-23
# 52899            백엔드 개발         2021-05-31
# 52900             영상 편집         2021-06-15
# 52901             영상 편집         2021-08-17
#
# [39519 rows x 18 columns]

# %% [markdown]
# ## category 8개로 축약하기

# %%
df['category_title'].value_counts().to_frame()
# Out:
#           category_title
# 프로그래밍              34430
# 데이터사이언스            14076
# 업무 생산성             13323
# 디자인                12009
# 영상/3D              10260
# 마케팅                 9857
# 부동산/금융              5523
# 투자/재테크              2501
# 크리에이티브              2250
# 교육                  1031
# 지식콘텐츠                 56
# 비즈니스                  42
# 파이낸스                  25
# 데이터 사이언스               9
# 관리                     2
# 일러스트                   1

# %%
df = df.replace({'category_title':{'일러스트':'디자인'}})
df['category_title'].value_counts().to_frame()
# Out:
#           category_title
# 프로그래밍              34430
# 데이터사이언스            14076
# 업무 생산성             13323
# 디자인                12010
# 영상/3D              10260
# 마케팅                 9857
# 부동산/금융              5523
# 투자/재테크              2501
# 크리에이티브              2250
# 교육                  1031
# 지식콘텐츠                 56
# 비즈니스                  42
# 파이낸스                  25
# 데이터 사이언스               9
# 관리                     2

# %%
df = df.replace({'category_title':{'데이터 사이언스':'데이터사이언스'}})
#프레임 내부 데이터를 바꾸고 싶다면 {column이름:{원래 있는 것을:이렇게 바꾼다}}
df['category_title'].value_counts().to_frame()
# Out:
#          category_title
# 프로그래밍             34430
# 데이터사이언스           14085
# 업무 생산성            13323
# 디자인               12010
# 영상/3D             10260
# 마케팅                9857
# 부동산/금융             5523
# 투자/재테크             2501
# 크리에이티브             2250
# 교육                 1031
# 지식콘텐츠                56
# 비즈니스                 42
# 파이낸스                 25
# 관리                    2

# %%
df.isna().sum()
# Out:
# id                            0
# customer_id                   3
# course_id                  5207
# type                          0
# state                         0
# course_title                 16
# category_title               24
# format                       16
# completed_at                  0
# transaction_amount            0
# coupon_title              73602
# coupon_discount_amount    73602
# sale_price                 1128
# tax_free_amount            1128
# pg                        15075
# method                    13096
# subcategory_title         19829
# marketing_start_at        17979
# dtype: int64

# %%
test_df = df.copy()
test_df = test_df.dropna(subset=['category_title'])

# %%
test_df.isna().sum()
# Out:
# id                            0
# customer_id                   0
# course_id                  5183
# type                          0
# state                         0
# course_title                  0
# category_title                0
# format                        0
# completed_at                  0
# transaction_amount            0
# coupon_title              73578
# coupon_discount_amount    73578
# sale_price                 1112
# tax_free_amount            1112
# pg                        15058
# method                    13095
# subcategory_title         19805
# marketing_start_at        17955
# dtype: int64

# %%
test_df = test_df[test_df.category_title != '관리']
test_df['category_title'].value_counts().to_frame()
# Out:
#          category_title
# 프로그래밍             34430
# 데이터사이언스           14085
# 업무 생산성            13323
# 디자인               12010
# 영상/3D             10260
# 마케팅                9857
# 부동산/금융             5523
# 투자/재테크             2501
# 크리에이티브             2250
# 교육                 1031
# 지식콘텐츠                56
# 비즈니스                 42
# 파이낸스                 25

# %%
test_df
# Out:
#              id  customer_id  course_id     type      state  \
# 0        970634     504760.0   201435.0    ORDER  CANCELLED
# 1        970650     432862.0   203178.0    ORDER  CANCELLED
# 2        970657      72297.0   204246.0  PAYMENT  COMPLETED
# 3        970656      72297.0   204246.0    ORDER  CANCELLED
# 4        970658     478028.0   201797.0  PAYMENT  COMPLETED
# ...         ...          ...        ...      ...        ...
# 105414  1364995     640697.0   205365.0  PAYMENT  CANCELLED
# 105415  1364998     670896.0   204159.0  PAYMENT  CANCELLED
# 105416  1364996     640697.0   205365.0  PAYMENT  COMPLETED
# 105417  1365005     670896.0   204159.0  PAYMENT  CANCELLED
# 105418  1365007     610626.0   206720.0  PAYMENT  COMPLETED
#
#                            course_title category_title  format  \
# 0             올인원 패키지 : 알고리즘 기술면접 완전 정복          프로그래밍     올인원
# 1           초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원
# 2                  시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인
# 3                  시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인
# 4         올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성     올인원
# ...                                 ...            ...     ...
# 105414  초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기          영상/3D     올인원
# 105415              부동산 디벨로퍼 아카데미 : 인허가         부동산/금융     올인원
# 105416  초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기          영상/3D     올인원
# 105417              부동산 디벨로퍼 아카데미 : 인허가         부동산/금융     올인원
# 105418               용호수의 돈 버는 실전 영상 제작          영상/3D     올인원
#
#               completed_at  transaction_amount               coupon_title  \
# 0      2021-03-28 15:00:11               90500                        NaN
# 1      2021-03-28 15:16:53               96000                        NaN
# 2      2021-03-28 15:21:43              171810      [10% 할인] 시크릿코드 실무 완성편
# 3      2021-03-28 15:21:43              171810                        NaN
# 4      2021-03-28 15:21:54               97500   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# ...                    ...                 ...                        ...
# 105414 2021-09-25 14:10:42               96000  [WELCOME] 온라인 강의 2만원 할인쿠폰
# 105415 2021-09-25 14:16:33              189000                        NaN
# 105416 2021-09-25 14:17:41               96000  [WELCOME] 온라인 강의 2만원 할인쿠폰
# 105417 2021-09-25 14:19:56              189000                        NaN
# 105418 2021-09-25 14:25:47              139000  [WELCOME] 온라인 강의 3만원 할인쿠폰
#
#         coupon_discount_amount  sale_price  tax_free_amount      pg method  \
# 0                          NaN    110500.0         110500.0     NaN  VBANK
# 1                          NaN    116000.0         116000.0     NaN   CARD
# 2                      19090.0    190900.0         190900.0     NaN   CARD
# 3                          NaN    190900.0         190900.0     NaN   CARD
# 4                      20000.0    117500.0         117500.0     NaN   CARD
# ...                        ...         ...              ...     ...    ...
# 105414                 20000.0    116000.0         116000.0  INICIS  TRANS
# 105415                     NaN    189000.0         189000.0  INICIS   CARD
# 105416                 20000.0    116000.0         116000.0  INICIS  VBANK
# 105417                     NaN    189000.0         189000.0  INICIS   CARD
# 105418                 30000.0    169000.0         169000.0   NAVER  POINT
#
#        subcategory_title marketing_start_at
# 0                개발자 커리어                NaT
# 1                  영상 편집         2020-12-02
# 2                    NaN         2021-03-04
# 3                    NaN         2021-03-04
# 4                PPT/보고서         2019-11-14
# ...                  ...                ...
# 105414             영상 편집         2021-06-15
# 105415            부동산 개발         2021-02-10
# 105416             영상 편집         2021-06-15
# 105417            부동산 개발         2021-02-10
# 105418             영상 편집         2021-08-17
#
# [105393 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105419 entries, 0 to 105418
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      105419 non-null  int64
#  1   customer_id             105416 non-null  float64
#  2   course_id               100212 non-null  float64
#  3   type                    105419 non-null  object
#  4   state                   105419 non-null  object
#  5   course_title            105403 non-null  object
#  6   category_title          105395 non-null  object
#  7   format                  105403 non-null  object
#  8   completed_at            105419 non-null  datetime64[ns]
#  9   transaction_amount      105419 non-null  int64
#  10  coupon_title            31817 non-null   object
#  11  coupon_discount_amount  31817 non-null   float64
#  12  sale_price              104291 non-null  float64
#  13  tax_free_amount         104291 non-null  float64
#  14  pg                      90344 non-null   object
#  15  method                  92323 non-null   object
#  16  subcategory_title       85590 non-null   object
#  17  marketing_start_at      87440 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(5), int64(2), object(9)
# memory usage: 14.5+ MB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 105393 entries, 0 to 105418
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      105393 non-null  int64
#  1   customer_id             105393 non-null  float64
#  2   course_id               100210 non-null  float64
#  3   type                    105393 non-null  object
#  4   state                   105393 non-null  object
#  5   course_title            105393 non-null  object
#  6   category_title          105393 non-null  object
#  7   format                  105393 non-null  object
#  8   completed_at            105393 non-null  datetime64[ns]
#  9   transaction_amount      105393 non-null  int64
#  10  coupon_title            31817 non-null   object
#  11  coupon_discount_amount  31817 non-null   float64
#  12  sale_price              104281 non-null  float64
#  13  tax_free_amount         104281 non-null  float64
#  14  pg                      90335 non-null   object
#  15  method                  92299 non-null   object
#  16  subcategory_title       85590 non-null   object
#  17  marketing_start_at      87440 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(5), int64(2), object(9)
# memory usage: 15.3+ MB

# %%
df = test_df

# %% [markdown]
# ## 재결재율:
# 1. 웰컴 할인쿠폰을 받은 사람 중 재결재률
# 2. 동일한 결제 수단으로 재 결제 여부

# %%
df_pay.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39519 entries, 0 to 52901
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      39519 non-null  int64
#  1   customer_id             39519 non-null  float64
#  2   course_id               37968 non-null  float64
#  3   type                    39519 non-null  object
#  4   state                   39519 non-null  object
#  5   course_title            39518 non-null  object
#  6   category_title          39516 non-null  object
#  7   format                  39518 non-null  object
#  8   completed_at            39519 non-null  datetime64[ns]
#  9   transaction_amount      39519 non-null  int64
#  10  coupon_title            17134 non-null  object
#  11  coupon_discount_amount  17134 non-null  float64
#  12  sale_price              38582 non-null  float64
#  13  tax_free_amount         38582 non-null  float64
#  14  pg                      32179 non-null  object
#  15  method                  39519 non-null  object
#  16  subcategory_title       31995 non-null  object
#  17  marketing_start_at      32404 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(5), int64(2), object(9)
# memory usage: 5.7+ MB

# %%
df_pay['coupon_title'].value_counts()
# Out:
# [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                      3455
# [WELCOME] 온라인 강의 3만원 할인쿠폰                     2036
# [WELCOME] 온라인 강의 2만원 할인쿠폰                     1488
# [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰                      1446
# [WELCOME] 온라인 강의 1만원 할인쿠폰                     1051
#                                               ...
# [무료수강권] 30개 프로젝트로 배우는 Android 앱 개발_최종원 강사님       1
# [패스트캠퍼스] 올인원 패키지: 컴퓨터 공학 전공_박용현 강사님              1
# [무료수강권] GA4 탑재, 구글 애널리틱스 끝장내기_안혜진 강사님            1
# [디자인 툴] 기수강생 5만원 구매 쿠폰                           1
# [재결제쿠폰]초격차 패키지 : 한 번에 끝내는 node.js 웹 프로그래밍        1
# Name: coupon_title, Length: 367, dtype: int64

# %%
# 쿠폰 사용자 추출
wc_df_all = df[(df['coupon_title'].str.contains('웰컴')) | (df['coupon_title'].str.contains('WELCOME'))]
wc_df_all
# Out:
#              id  customer_id  course_id     type      state  \
# 4        970658     478028.0   201797.0  PAYMENT  COMPLETED
# 8        970669     478033.0   203178.0  PAYMENT  COMPLETED
# 14       970676     478035.0   203720.0  PAYMENT  COMPLETED
# 15       970673     478035.0   203720.0    ORDER  CANCELLED
# 28       970704     471759.0   204068.0  PAYMENT  COMPLETED
# ...         ...          ...        ...      ...        ...
# 105393  1364869     638903.0   203178.0  PAYMENT  COMPLETED
# 105396  1364879     623392.0   206060.0  PAYMENT  CANCELLED
# 105414  1364995     640697.0   205365.0  PAYMENT  CANCELLED
# 105416  1364996     640697.0   205365.0  PAYMENT  COMPLETED
# 105418  1365007     610626.0   206720.0  PAYMENT  COMPLETED
#
#                                     course_title category_title format  \
# 4                  올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성    올인원
# 8                    초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D    올인원
# 14                   초격차 패키지 : 한 번에 끝내는 프론트엔드 개발          프로그래밍    올인원
# 15                   초격차 패키지 : 한 번에 끝내는 프론트엔드 개발          프로그래밍    올인원
# 28                    올인원 패키지 : 마디아의 UX/UI 포트폴리오            디자인    올인원
# ...                                          ...            ...    ...
# 105393               초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D    올인원
# 105396  초격차 패키지 : 한 번에 끝내는 컴퓨터 공학 전공필수 & 인공지능 심화          프로그래밍    올인원
# 105414           초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기          영상/3D    올인원
# 105416           초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기          영상/3D    올인원
# 105418                        용호수의 돈 버는 실전 영상 제작          영상/3D    올인원
#
#               completed_at  transaction_amount               coupon_title  \
# 4      2021-03-28 15:21:54               97500   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 8      2021-03-28 15:26:47               96000   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 14     2021-03-28 15:31:01               91000   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 15     2021-03-28 15:31:02               91000   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 28     2021-03-28 15:46:22               89000   [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰
# ...                    ...                 ...                        ...
# 105393 2021-09-25 11:22:07              139000  [WELCOME] 온라인 강의 1만원 할인쿠폰
# 105396 2021-09-25 11:38:53              173000  [WELCOME] 온라인 강의 3만원 할인쿠폰
# 105414 2021-09-25 14:10:42               96000  [WELCOME] 온라인 강의 2만원 할인쿠폰
# 105416 2021-09-25 14:17:41               96000  [WELCOME] 온라인 강의 2만원 할인쿠폰
# 105418 2021-09-25 14:25:47              139000  [WELCOME] 온라인 강의 3만원 할인쿠폰
#
#         coupon_discount_amount  sale_price  tax_free_amount      pg method  \
# 4                      20000.0    117500.0         117500.0     NaN   CARD
# 8                      20000.0    116000.0         116000.0     NaN   CARD
# 14                     20000.0    111000.0         111000.0     NaN   CARD
# 15                     20000.0    111000.0         111000.0     NaN   CARD
# 28                     10000.0     99000.0          99000.0     NaN   CARD
# ...                        ...         ...              ...     ...    ...
# 105393                 10000.0    149000.0         149000.0   KAKAO  POINT
# 105396                 30000.0    203000.0         203000.0   KAKAO    NaN
# 105414                 20000.0    116000.0         116000.0  INICIS  TRANS
# 105416                 20000.0    116000.0         116000.0  INICIS  VBANK
# 105418                 30000.0    169000.0         169000.0   NAVER  POINT
#
#        subcategory_title marketing_start_at
# 4                PPT/보고서         2019-11-14
# 8                  영상 편집         2020-12-02
# 14              프론트엔드 개발         2021-02-02
# 15              프론트엔드 개발         2021-02-02
# 28                 UX/UI         2021-03-11
# ...                  ...                ...
# 105393             영상 편집         2020-12-02
# 105396           개발자 커리어         2021-07-16
# 105414             영상 편집         2021-06-15
# 105416             영상 편집         2021-06-15
# 105418             영상 편집         2021-08-17
#
# [17409 rows x 18 columns]

# %%
# 쿠폰 사용자 중복값 확인
wc_df_all['customer_id'].value_counts()
# Out:
# 494420.0    23
# 495876.0    11
# 534149.0    10
# 618845.0     8
# 600629.0     8
#             ..
# 528724.0     1
# 525095.0     1
# 528704.0     1
# 525564.0     1
# 610626.0     1
# Name: customer_id, Length: 13258, dtype: int64

# %%
foring = wc_df_all['customer_id'].value_counts().to_frame()
foring
# Out:
#           customer_id
# 494420.0           23
# 495876.0           11
# 534149.0           10
# 618845.0            8
# 600629.0            8
# ...               ...
# 528724.0            1
# 525095.0            1
# 528704.0            1
# 525564.0            1
# 610626.0            1
#
# [13258 rows x 1 columns]

# %%
# PAYMENT.COMPLETED 중 쿠폰 사용자 추출
wc_df = df_pay[(df_pay['coupon_title'].str.contains('웰컴')) | (df_pay['coupon_title'].str.contains('WELCOME'))]
wc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6037 entries, 1 to 20733
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      6037 non-null   int64
#  1   customer_id             6037 non-null   float64
#  2   course_id               6037 non-null   float64
#  3   type                    6037 non-null   object
#  4   state                   6037 non-null   object
#  5   course_title            6037 non-null   object
#  6   category_title          6037 non-null   object
#  7   format                  6037 non-null   object
#  8   completed_at            6037 non-null   datetime64[ns]
#  9   transaction_amount      6037 non-null   int64
#  10  coupon_title            6037 non-null   object
#  11  coupon_discount_amount  6037 non-null   float64
#  12  sale_price              6037 non-null   float64
#  13  tax_free_amount         6037 non-null   float64
#  14  pg                      4828 non-null   object
#  15  method                  6037 non-null   object
#  16  subcategory_title       5336 non-null   object
#  17  marketing_start_at      5435 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(5), int64(2), object(9)
# memory usage: 896.1+ KB

# %%
# PAYMENT.COMPLETED 중 쿠폰 사용자 중복값 확인
wc_df['customer_id'].value_counts()
# Out:
# 478028.0    1
# 529391.0    1
# 529443.0    1
# 529422.0    1
# 529424.0    1
#            ..
# 500006.0    1
# 500624.0    1
# 500173.0    1
# 500604.0    1
# 548090.0    1
# Name: customer_id, Length: 6037, dtype: int64

# %%
foring = foring[foring['customer_id'] > 1]
b = foring.index
b
# Out:
# Float64Index([494420.0, 495876.0, 534149.0, 618845.0, 600629.0, 507048.0,
#               537615.0, 504356.0, 540759.0, 500865.0,
#               ...
#               479936.0, 491654.0, 598826.0, 541391.0, 606282.0, 491585.0,
#               605474.0, 643520.0, 490847.0, 490481.0],
#              dtype='float64', length=2868)

# %%
a = wc_df_all['customer_id'].unique()
a
# Out:
# array([478028., 478033., 478035., ..., 623392., 640697., 610626.])

# %%
# PAYMENT.COMPLETED 중 쿠폰 사용자
a = wc_df['customer_id'].value_counts().to_frame()
a = a.index

# %%
# 쿠폰 사용자 중 중복값이 있는 자
b = foring.index

# %%
while True:
    try:
        if a == b:
            print(a)
    except:
        break

# %%
c = []
for i in a:
    for j in b:
        if i == j:
            c.append(j)
            print(j)
# Out:
# 529422.0
# 529453.0
# 523983.0
# 527236.0
# 529380.0
# 529648.0
# 529559.0
# 529538.0
# 529498.0
# 513020.0
# 523982.0
# 501644.0
# 527134.0
# 528860.0
# 528810.0
# 513854.0
# 529290.0
# 503049.0
# 529160.0
# 528985.0
# 529129.0
# 527228.0
# 529040.0
# 527898.0
# 524490.0
# 529692.0
# 530174.0
# 530060.0
# 530153.0
# 530112.0
# 496634.0
# 520885.0
# 523729.0
# 530379.0
# 530341.0
# 523649.0
# 530312.0
# 530255.0
# 530121.0
# 2182.0
# 529794.0
# 520908.0
# 529803.0
# 529628.0
# 528776.0
# 523364.0
# 504412.0
# 530039.0
# 495383.0
# 528716.0
# 528804.0
# 68947.0
# 523240.0
# 527135.0
# 527097.0
# 527100.0
# 524075.0
# 525528.0
# 133374.0
# 527468.0
# 527457.0
# 527330.0
# 527274.0
# 523291.0
# 526148.0
# 525549.0
# 526283.0
# 527013.0
# 524603.0
# 526257.0
# 50291.0
# 528153.0
# 526098.0
# 528752.0
# 492768.0
# 494904.0
# 528559.0
# 528168.0
# 523828.0
# 521412.0
# 527589.0
# 527610.0
# 528112.0
# 527977.0
# 527965.0
# 524066.0
# 530397.0
# 531694.0
# 529310.0
# 530601.0
# 529163.0
# 532926.0
# 498400.0
# 530763.0
# 503236.0
# 531894.0
# 494327.0
# 521884.0
# 531662.0
# 531650.0
# 532065.0
# 533083.0
# 533913.0
# 532900.0
# 533755.0
# 532975.0
# 533929.0
# 534149.0
# 517834.0
# 534139.0
# 534103.0
# 508892.0
# 533216.0
# 532451.0
# 533100.0
# 517494.0
# 533594.0
# 533464.0
# 532085.0
# 490629.0
# 530768.0
# 530906.0
# 507623.0
# 510221.0
# 523605.0
# 516903.0
# 530842.0
# 13287.0
# 531038.0
# 531031.0
# 528779.0
# 530259.0
# 528997.0
# 530874.0
# 530802.0
# 530589.0
# 530519.0
# 529623.0
# 524777.0
# 529475.0
# 523987.0
# 528178.0
# 530638.0
# 530730.0
# 486784.0
# 530679.0
# 515698.0
# 503326.0
# 531155.0
# 531221.0
# 530327.0
# 510090.0
# 530446.0
# 519809.0
# 531347.0
# 531380.0
# 530402.0
# 531425.0
# 527480.0
# 528923.0
# 531188.0
# 531146.0
# 523607.0
# 527641.0
# 530712.0
# 531069.0
# 529145.0
# 531199.0
# 531160.0
# 531216.0
# 524189.0
# 531193.0
# 531222.0
# 525162.0
# 519099.0
# 513706.0
# 518907.0
# 519430.0
# 516890.0
# 519047.0
# 514336.0
# 518442.0
# 512164.0
# 517891.0
# 509831.0
# 518263.0
# 516950.0
# 518556.0
# 518513.0
# 517543.0
# 518536.0
# 114613.0
# 52658.0
# 513850.0
# 520374.0
# 519362.0
# 520615.0
# 515448.0
# 518269.0
# 521091.0
# 521093.0
# 520870.0
# 519940.0
# 519892.0
# 513298.0
# 519503.0
# 519960.0
# 519863.0
# 520142.0
# 520164.0
# 75177.0
# 517493.0
# 506419.0
# 515145.0
# 508436.0
# 515006.0
# 514518.0
# 515064.0
# 515343.0
# 515226.0
# 515158.0
# 504509.0
# 515141.0
# 513189.0
# 511201.0
# 515062.0
# 512486.0
# 504602.0
# 515042.0
# 505036.0
# 515007.0
# 515056.0
# 513646.0
# 492498.0
# 515132.0
# 503377.0
# 505686.0
# 514938.0
# 14507.0
# 507925.0
# 501167.0
# 515572.0
# 515143.0
# 509977.0
# 516959.0
# 508967.0
# 516922.0
# 516896.0
# 516911.0
# 517709.0
# 517471.0
# 517386.0
# 505878.0
# 65184.0
# 518099.0
# 515925.0
# 510279.0
# 524533.0
# 525028.0
# 515929.0
# 524848.0
# 524797.0
# 524197.0
# 522692.0
# 520398.0
# 524257.0
# 517472.0
# 488202.0
# 523921.0
# 523908.0
# 496508.0
# 526303.0
# 524090.0
# 524093.0
# 523981.0
# 520678.0
# 502362.0
# 523609.0
# 523869.0
# 525343.0
# 525240.0
# 525872.0
# 523885.0
# 526085.0
# 526078.0
# 525132.0
# 525063.0
# 525104.0
# 524016.0
# 525293.0
# 525504.0
# 525506.0
# 525492.0
# 525454.0
# 525425.0
# 522319.0
# 522382.0
# 496829.0
# 522081.0
# 522303.0
# 485249.0
# 520308.0
# 522458.0
# 522118.0
# 522058.0
# 522693.0
# 522599.0
# 234248.0
# 521537.0
# 521477.0
# 521086.0
# 521448.0
# 521827.0
# 521876.0
# 521182.0
# 522816.0
# 519008.0
# 522284.0
# 523091.0
# 520648.0
# 523322.0
# 523796.0
# 523305.0
# 523540.0
# 524881.0
# 498804.0
# 491393.0
# 522988.0
# 523105.0
# 523099.0
# 521299.0
# 523089.0
# 523061.0
# 523054.0
# 522985.0
# 517165.0
# 521219.0
# 523186.0
# 523151.0
# 523145.0
# 534371.0
# 515522.0
# 544942.0
# 522446.0
# 545702.0
# 545661.0
# 537729.0
# 538045.0
# 545578.0
# 545777.0
# 538853.0
# 545868.0
# 545895.0
# 545588.0
# 498511.0
# 545799.0
# 545219.0
# 545309.0
# 545294.0
# 145803.0
# 543279.0
# 545182.0
# 545423.0
# 545235.0
# 546287.0
# 502884.0
# 546262.0
# 540603.0
# 543267.0
# 546326.0
# 518782.0
# 545481.0
# 541940.0
# 523293.0
# 546331.0
# 494296.0
# 545931.0
# 491404.0
# 545973.0
# 546219.0
# 543686.0
# 546212.0
# 546126.0
# 545962.0
# 546048.0
# 543806.0
# 538056.0
# 543024.0
# 543743.0
# 495635.0
# 542168.0
# 544043.0
# 540778.0
# 542755.0
# 505109.0
# 543290.0
# 516712.0
# 542815.0
# 543313.0
# 543593.0
# 543575.0
# 543056.0
# 544936.0
# 544852.0
# 544847.0
# 544702.0
# 494314.0
# 544694.0
# 545041.0
# 545038.0
# 537309.0
# 544788.0
# 544647.0
# 543788.0
# 544235.0
# 544286.0
# 544217.0
# 544181.0
# 544638.0
# 544573.0
# 544554.0
# 544403.0
# 531180.0
# 542453.0
# 514896.0
# 546804.0
# 547098.0
# 537615.0
# 545749.0
# 547780.0
# 547721.0
# 547797.0
# 547837.0
# 545198.0
# 537268.0
# 547799.0
# 547864.0
# 522772.0
# 547682.0
# 547385.0
# 547656.0
# 547379.0
# 547648.0
# 545061.0
# 546690.0
# 547428.0
# 516888.0
# 546582.0
# 543205.0
# 544715.0
# 79772.0
# 548039.0
# 540688.0
# 548018.0
# 515493.0
# 547992.0
# 547790.0
# 548031.0
# 531272.0
# 546178.0
# 548075.0
# 548057.0
# 548081.0
# 24405.0
# 547667.0
# 547912.0
# 547921.0
# 547936.0
# 548006.0
# 547924.0
# 547873.0
# 509495.0
# 547888.0
# 547937.0
# 515384.0
# 537315.0
# 534567.0
# 547942.0
# 527566.0
# 545246.0
# 546511.0
# 546982.0
# 546887.0
# 542054.0
# 544818.0
# 543170.0
# 546668.0
# 526223.0
# 543199.0
# 546214.0
# 547371.0
# 547302.0
# 540188.0
# 547262.0
# 547200.0
# 540995.0
# 547367.0
# 269030.0
# 547057.0
# 547003.0
# 541135.0
# 547067.0
# 547025.0
# 544361.0
# 546992.0
# 546861.0
# 545016.0
# 547211.0
# 546809.0
# 547059.0
# 525142.0
# 540874.0
# 538112.0
# 538083.0
# 538062.0
# 537350.0
# 524089.0
# 538212.0
# 533417.0
# 535789.0
# 46270.0
# 538177.0
# 534531.0
# 537601.0
# 537465.0
# 536362.0
# 537328.0
# 537628.0
# 537650.0
# 537757.0
# 536592.0
# 529853.0
# 538778.0
# 538707.0
# 532749.0
# 531519.0
# 536328.0
# 537017.0
# 539019.0
# 534493.0
# 538565.0
# 538258.0
# 538504.0
# 538464.0
# 509987.0
# 538690.0
# 538693.0
# 538014.0
# 538646.0
# 535553.0
# 535342.0
# 530887.0
# 520849.0
# 535908.0
# 533807.0
# 531319.0
# 129507.0
# 534416.0
# 488164.0
# 525380.0
# 495981.0
# 533405.0
# 536027.0
# 537225.0
# 537235.0
# 537208.0
# 537202.0
# 537200.0
# 536170.0
# 533570.0
# 500781.0
# 534133.0
# 536764.0
# 518448.0
# 534675.0
# 536580.0
# 536552.0
# 532231.0
# 541663.0
# 540668.0
# 533071.0
# 541380.0
# 535873.0
# 540850.0
# 541846.0
# 541224.0
# 541535.0
# 541320.0
# 541060.0
# 541184.0
# 540968.0
# 539195.0
# 539396.0
# 494342.0
# 524576.0
# 540182.0
# 541391.0
# 542225.0
# 533822.0
# 542872.0
# 542709.0
# 488344.0
# 542672.0
# 543029.0
# 541500.0
# 530951.0
# 543139.0
# 522264.0
# 541943.0
# 495094.0
# 531703.0
# 541387.0
# 495764.0
# 541565.0
# 542608.0
# 541008.0
# 537745.0
# 539442.0
# 539437.0
# 260993.0
# 515250.0
# 230536.0
# 515717.0
# 515727.0
# 539013.0
# 539588.0
# 539506.0
# 539455.0
# 539373.0
# 530876.0
# 536656.0
# 539219.0
# 524119.0
# 532478.0
# 525979.0
# 539322.0
# 517963.0
# 540782.0
# 540697.0
# 540522.0
# 512190.0
# 540264.0
# 540759.0
# 540973.0
# 540911.0
# 487266.0
# 540951.0
# 540053.0
# 504556.0
# 539854.0
# 490583.0
# 512882.0
# 486985.0
# 483574.0
# 486884.0
# 487032.0
# 486271.0
# 486991.0
# 486986.0
# 486777.0
# 487024.0
# 486601.0
# 486253.0
# 487081.0
# 184888.0
# 486015.0
# 485749.0
# 486692.0
# 486691.0
# 486894.0
# 486822.0
# 461466.0
# 487391.0
# 488102.0
# 488442.0
# 488274.0
# 487690.0
# 488992.0
# 488973.0
# 88011.0
# 488549.0
# 483297.0
# 486142.0
# 487350.0
# 101934.0
# 487607.0
# 444310.0
# 487502.0
# 487435.0
# 487422.0
# 488160.0
# 487975.0
# 487052.0
# 487928.0
# 484005.0
# 487451.0
# 486612.0
# 485072.0
# 484141.0
# 484225.0
# 484515.0
# 485140.0
# 485387.0
# 484931.0
# 483618.0
# 483529.0
# 483043.0
# 483716.0
# 484085.0
# 484462.0
# 484431.0
# 484394.0
# 484291.0
# 484233.0
# 486172.0
# 438250.0
# 485611.0
# 485965.0
# 486218.0
# 486585.0
# 486592.0
# 486283.0
# 484614.0
# 230094.0
# 486340.0
# 486301.0
# 485464.0
# 484686.0
# 485326.0
# 484098.0
# 92239.0
# 485477.0
# 485368.0
# 275974.0
# 485674.0
# 485889.0
# 268233.0
# 483754.0
# 485766.0
# 485768.0
# 485731.0
# 483838.0
# 489000.0
# 489012.0
# 492227.0
# 492636.0
# 492936.0
# 490347.0
# 492944.0
# 492858.0
# 491613.0
# 492023.0
# 491285.0
# 491214.0
# 491755.0
# 491654.0
# 488296.0
# 492241.0
# 492545.0
# 492477.0
# 492499.0
# 489191.0
# 492005.0
# 491924.0
# 492277.0
# 493581.0
# 493611.0
# 493546.0
# 493593.0
# 493453.0
# 493459.0
# 493548.0
# 492829.0
# 493542.0
# 115470.0
# 493259.0
# 493729.0
# 491190.0
# 493715.0
# 490257.0
# 489076.0
# 493244.0
# 493250.0
# 493207.0
# 493202.0
# 492417.0
# 493272.0
# 483782.0
# 493317.0
# 490847.0
# 491923.0
# 490349.0
# 486832.0
# 489744.0
# 488055.0
# 489712.0
# 490645.0
# 483106.0
# 490540.0
# 490520.0
# 490417.0
# 490415.0
# 488700.0
# 488348.0
# 488383.0
# 489258.0
# 485934.0
# 489043.0
# 489073.0
# 489070.0
# 489027.0
# 488763.0
# 489618.0
# 486266.0
# 489457.0
# 491631.0
# 491585.0
# 489023.0
# 269385.0
# 491810.0
# 491767.0
# 491804.0
# 491756.0
# 490907.0
# 490858.0
# 489976.0
# 490481.0
# 489268.0
# 491274.0
# 491288.0
# 491231.0
# 111447.0
# 490561.0
# 483656.0
# 401036.0
# 480414.0
# 480407.0
# 480347.0
# 462824.0
# 464632.0
# 480565.0
# 396530.0
# 480390.0
# 480553.0
# 479313.0
# 479190.0
# 480032.0
# 479936.0
# 476679.0
# 478789.0
# 419784.0
# 480286.0
# 451007.0
# 261026.0
# 479444.0
# 453761.0
# 480162.0
# 186884.0
# 481061.0
# 479765.0
# 481283.0
# 456400.0
# 469055.0
# 481258.0
# 481229.0
# 479231.0
# 429291.0
# 480694.0
# 480903.0
# 480877.0
# 480799.0
# 480766.0
# 474958.0
# 478488.0
# 478397.0
# 478425.0
# 7002.0
# 478363.0
# 478462.0
# 478566.0
# 443346.0
# 439025.0
# 478660.0
# 477816.0
# 459090.0
# 436888.0
# 478428.0
# 478167.0
# 478101.0
# 474083.0
# 478035.0
# 478366.0
# 183570.0
# 478339.0
# 477954.0
# 477325.0
# 478845.0
# 477967.0
# 393322.0
# 441007.0
# 479679.0
# 439072.0
# 479876.0
# 476278.0
# 478539.0
# 462160.0
# 475655.0
# 479117.0
# 134364.0
# 172482.0
# 477646.0
# 478569.0
# 482587.0
# 481810.0
# 478550.0
# 482698.0
# 482164.0
# 482677.0
# 482662.0
# 480335.0
# 480586.0
# 481496.0
# 481705.0
# 482204.0
# 482589.0
# 475995.0
# 477193.0
# 456332.0
# 482499.0
# 482736.0
# 482873.0
# 482935.0
# 482852.0
# 483531.0
# 483395.0
# 483539.0
# 483549.0
# 483394.0
# 483393.0
# 482846.0
# 471900.0
# 477431.0
# 479200.0
# 470459.0
# 481897.0
# 478716.0
# 482861.0
# 482851.0
# 482836.0
# 482829.0
# 467574.0
# 482815.0
# 479207.0
# 481018.0
# 481506.0
# 478688.0
# 481056.0
# 481750.0
# 480357.0
# 477637.0
# 480237.0
# 481416.0
# 481521.0
# 479868.0
# 481534.0
# 481579.0
# 474928.0
# 479235.0
# 482214.0
# 472901.0
# 396832.0
# 481738.0
# 481183.0
# 435342.0
# 439232.0
# 482294.0
# 481771.0
# 482064.0
# 481831.0
# 476368.0
# 479991.0
# 477672.0
# 482050.0
# 480830.0
# 56644.0
# 480677.0
# 493827.0
# 509498.0
# 509458.0
# 506577.0
# 509430.0
# 494954.0
# 507945.0
# 509237.0
# 509531.0
# 509819.0
# 509773.0
# 505058.0
# 509739.0
# 507960.0
# 509567.0
# 508149.0
# 508110.0
# 507248.0
# 496683.0
# 503285.0
# 1094.0
# 508796.0
# 501171.0
# 491075.0
# 496000.0
# 509868.0
# 510517.0
# 510359.0
# 510265.0
# 510362.0
# 510325.0
# 510255.0
# 492688.0
# 510620.0
# 518384.0
# 498993.0
# 510066.0
# 509890.0
# 506433.0
# 506206.0
# 509374.0
# 507890.0
# 493661.0
# 506827.0
# 504653.0
# 499791.0
# 506682.0
# 505744.0
# 506678.0
# 504075.0
# 507048.0
# 494310.0
# 506131.0
# 506093.0
# 505882.0
# 504143.0
# 506224.0
# 506474.0
# 506356.0
# 506219.0
# 504733.0
# 484482.0
# 503721.0
# 507743.0
# 507390.0
# 507719.0
# 507581.0
# 495876.0
# 238766.0
# 507646.0
# 507815.0
# 505301.0
# 505496.0
# 507393.0
# 507415.0
# 506867.0
# 506961.0
# 507262.0
# 507400.0
# 507239.0
# 498562.0
# 525887.0
# 507259.0
# 506983.0
# 501675.0
# 507477.0
# 492671.0
# 512815.0
# 514205.0
# 512656.0
# 509616.0
# 514138.0
# 514145.0
# 513441.0
# 496625.0
# 505187.0
# 497418.0
# 514249.0
# 513593.0
# 513584.0
# 64136.0
# 513569.0
# 142781.0
# 513484.0
# 510959.0
# 513846.0
# 513835.0
# 512412.0
# 513717.0
# 277474.0
# 514925.0
# 511290.0
# 171704.0
# 513742.0
# 514993.0
# 514798.0
# 514568.0
# 514631.0
# 514991.0
# 514502.0
# 514472.0
# 514430.0
# 514411.0
# 514402.0
# 416384.0
# 511535.0
# 514558.0
# 510994.0
# 514722.0
# 505521.0
# 514573.0
# 514571.0
# 466525.0
# 511999.0
# 507858.0
# 511982.0
# 503567.0
# 192990.0
# 512065.0
# 512302.0
# 490729.0
# 497238.0
# 511981.0
# 509548.0
# 169794.0
# 512113.0
# 493845.0
# 511732.0
# 511122.0
# 510805.0
# 506694.0
# 508529.0
# 509984.0
# 509949.0
# 510900.0
# 511543.0
# 511624.0
# 511213.0
# 511597.0
# 511551.0
# 504609.0
# 488785.0
# 511293.0
# 512341.0
# 512854.0
# 508857.0
# 512080.0
# 128227.0
# 513174.0
# 512978.0
# 507517.0
# 497529.0
# 259838.0
# 501774.0
# 512908.0
# 512568.0
# 216202.0
# 510254.0
# 510944.0
# 512602.0
# 504356.0
# 512441.0
# 512642.0
# 512714.0
# 508478.0
# 506258.0
# 512837.0
# 509908.0
# 512799.0
# 512712.0
# 505456.0
# 496009.0
# 495869.0
# 496846.0
# 496790.0
# 496710.0
# 493072.0
# 173845.0
# 497802.0
# 484241.0
# 494350.0
# 494685.0
# 496698.0
# 496705.0
# 495838.0
# 495732.0
# 495714.0
# 495035.0
# 496437.0
# 495309.0
# 496040.0
# 496202.0
# 496141.0
# 497895.0
# 498810.0
# 497164.0
# 498942.0
# 69542.0
# 499141.0
# 499067.0
# 499054.0
# 38848.0
# 495260.0
# 264455.0
# 495146.0
# 515770.0
# 494919.0
# 498164.0
# 498231.0
# 498547.0
# 498557.0
# 498524.0
# 498498.0
# 495175.0
# 495589.0
# 491069.0
# 494047.0
# 490731.0
# 492968.0
# 494068.0
# 493991.0
# 491665.0
# 492000.0
# 494146.0
# 494140.0
# 70358.0
# 492913.0
# 409464.0
# 493867.0
# 488406.0
# 494006.0
# 493999.0
# 493018.0
# 493613.0
# 493974.0
# 495576.0
# 495148.0
# 495124.0
# 495049.0
# 492943.0
# 490886.0
# 495061.0
# 495537.0
# 494968.0
# 493490.0
# 495286.0
# 491849.0
# 495115.0
# 495398.0
# 495205.0
# 494853.0
# 494264.0
# 483835.0
# 197719.0
# 494449.0
# 494907.0
# 488769.0
# 502154.0
# 501153.0
# 502982.0
# 499227.0
# 497048.0
# 502036.0
# 509478.0
# 502212.0
# 501818.0
# 502886.0
# 502477.0
# 502032.0
# 503551.0
# 494420.0
# 505266.0
# 503412.0
# 504578.0
# 505067.0
# 500880.0
# 500746.0
# 504641.0
# 505518.0
# 505423.0
# 505411.0
# 504298.0
# 488991.0
# 161012.0
# 504825.0
# 488219.0
# 504636.0
# 500180.0
# 499449.0
# 497101.0
# 500198.0
# 498152.0
# 500032.0
# 500149.0
# 500114.0
# 152341.0
# 500240.0
# 499473.0
# 496719.0
# 499700.0
# 498705.0
# 499921.0
# 499754.0
# 501083.0
# 501085.0
# 500567.0
# 490749.0
# 501651.0
# 501472.0
# 501431.0
# 158971.0
# 428406.0
# 500595.0
# 500578.0
# 499599.0
# 506903.0
# 500625.0
# 500803.0
# 500663.0
# 500680.0
# 500604.0

# %%
len(c)
# Out:
# 1327

# %%
print(len(a))
print(len(b))
# Out:
# 6037
# 2868

# %%
wc_df[wc_df['customer_id'] == c]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-160-5912435473d3> in <module>()
# ----> 1 wc_df[wc_df['customer_id'] == c]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arraylike.py in __eq__(self, other)
#      30     @unpack_zerodim_and_defer("__eq__")
#      31     def __eq__(self, other):
# ---> 32         return self._cmp_method(other, operator.eq)
#      33
#      34     @unpack_zerodim_and_defer("__ne__")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    5500
#    5501         with np.errstate(all="ignore"):
# -> 5502             res_values = ops.comparison_op(lvalues, rvalues, op)
#    5503
#    5504         return self._construct_result(res_values, name=res_name)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     260         if len(lvalues) != len(rvalues):
#     261             raise ValueError(
# --> 262                 "Lengths must match to compare", lvalues.shape, rvalues.shape
#     263             )
#     264
#
# ValueError: ('Lengths must match to compare', (6037,), (1327,))

# %%
wc_df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17409 entries, 4 to 105418
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             17409 non-null  float64
#  1   course_id               17409 non-null  float64
#  2   type                    17409 non-null  object
#  3   state                   17409 non-null  object
#  4   course_title            17409 non-null  object
#  5   category_title          17409 non-null  object
#  6   format                  17409 non-null  object
#  7   completed_at            17409 non-null  datetime64[ns]
#  8   transaction_amount      17409 non-null  int64
#  9   coupon_title            17409 non-null  object
#  10  coupon_discount_amount  17409 non-null  float64
#  11  sale_price              17409 non-null  float64
#  12  pg                      15421 non-null  object
#  13  method                  16011 non-null  object
#  14  subcategory_title       16167 non-null  object
#  15  marketing_start_at      15461 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(4), int64(1), object(9)
# memory usage: 2.3+ MB

# %%
cond = wc_df_all['customer_id'] == 494420.0
wc_df_all[cond]
# Out:
#             id  customer_id  course_id     type      state  \
# 16136  1019637     494420.0   204035.0    ORDER  CANCELLED
# 16138  1019640     494420.0   202072.0    ORDER  CANCELLED
# 16149  1019664     494420.0   202072.0    ORDER  CANCELLED
# 16356  1020481     494420.0   201582.0    ORDER  CANCELLED
# 16357  1020483     494420.0   202072.0    ORDER  CANCELLED
# 16566  1021135     494420.0   202072.0  PAYMENT    PENDING
# 16683  1021569     494420.0   202072.0  PAYMENT  COMPLETED
# 30274  1060893     494420.0   201582.0    ORDER  CANCELLED
# 30396  1061169     494420.0   201582.0    ORDER  CANCELLED
# 30401  1061172     494420.0   201582.0    ORDER  CANCELLED
# 36889  1080090     494420.0   201582.0    ORDER  CANCELLED
# 37583  1082665     494420.0   201582.0    ORDER  CANCELLED
# 37750  1083262     494420.0   201582.0    ORDER  CANCELLED
# 37819  1083487     494420.0   201582.0    ORDER  CANCELLED
# 37900  1084034     494420.0   201582.0    ORDER  CANCELLED
# 37916  1084123     494420.0   201582.0    ORDER  CANCELLED
# 37936  1084262     494420.0   201582.0    ORDER  CANCELLED
# 38127  1085403     494420.0   201582.0    ORDER  CANCELLED
# 38139  1085446     494420.0   201582.0    ORDER  CANCELLED
# 38143  1085473     494420.0   204035.0    ORDER  CANCELLED
# 38361  1086656     494420.0   201582.0    ORDER  CANCELLED
# 38462  1087001     494420.0   201582.0    ORDER  CANCELLED
# 41107  1097494     494420.0   201582.0    ORDER  CANCELLED
#
#                        course_title category_title format        completed_at  \
# 16136  바이블 : 파이썬 기초부터 시작하는 딥러닝 영상인식        데이터사이언스    올인원 2021-04-20 16:34:17
# 16138        올인원 패키지 : 코딩 첫 걸음 프로젝트          프로그래밍    올인원 2021-04-20 16:35:26
# 16149        올인원 패키지 : 코딩 첫 걸음 프로젝트          프로그래밍    올인원 2021-04-20 16:51:59
# 16356        올인원 패키지 : 컴퓨터 공학 전공 필수          프로그래밍    올인원 2021-04-21 09:14:29
# 16357        올인원 패키지 : 코딩 첫 걸음 프로젝트          프로그래밍    올인원 2021-04-21 09:15:48
# 16566        올인원 패키지 : 코딩 첫 걸음 프로젝트          프로그래밍    올인원 2021-04-21 16:23:08
# 16683        올인원 패키지 : 코딩 첫 걸음 프로젝트          프로그래밍    올인원 2021-04-21 20:13:04
# 30274        올인원 패키지 : 컴퓨터 공학 전공 필수          프로그래밍    올인원 2021-05-09 20:41:06
# 30396        올인원 패키지 : 컴퓨터 공학 전공 필수          프로그래밍    올인원 2021-05-09 22:10:56
# 30401        올인원 패키지 : 컴퓨터 공학 전공 필수          프로그래밍    올인원 2021-05-09 22:13:28
# 36889        올인원 패키지 : 컴퓨터 공학 전공 필수          프로그래밍    올인원 2021-05-18 13:03:12
# 37583        올인원 패키지 : 컴퓨터 공학 전공 필수          프로그래밍    올인원 2021-05-19 21:00:43
# 37750        올인원 패키지 : 컴퓨터 공학 전공 필수          프로그래밍    올인원 2021-05-20 06:48:18
# 37819        올인원 패키지 : 컴퓨터 공학 전공 필수          프로그래밍    올인원 2021-05-20 10:36:17
# 37900        올인원 패키지 : 컴퓨터 공학 전공 필수          프로그래밍    올인원 2021-05-20 13:25:05
# 37916        올인원 패키지 : 컴퓨터 공학 전공 필수          프로그래밍    올인원 2021-05-20 13:41:41
# 37936        올인원 패키지 : 컴퓨터 공학 전공 필수          프로그래밍    올인원 2021-05-20 14:10:05
# 38127        올인원 패키지 : 컴퓨터 공학 전공 필수          프로그래밍    올인원 2021-05-20 19:36:36
# 38139        올인원 패키지 : 컴퓨터 공학 전공 필수          프로그래밍    올인원 2021-05-20 19:49:48
# 38143  바이블 : 파이썬 기초부터 시작하는 딥러닝 영상인식        데이터사이언스    올인원 2021-05-20 20:01:20
# 38361        올인원 패키지 : 컴퓨터 공학 전공 필수          프로그래밍    올인원 2021-05-21 10:22:37
# 38462        올인원 패키지 : 컴퓨터 공학 전공 필수          프로그래밍    올인원 2021-05-21 12:54:15
# 41107        올인원 패키지 : 컴퓨터 공학 전공 필수          프로그래밍    올인원 2021-05-25 15:36:15
#
#        transaction_amount              coupon_title  coupon_discount_amount  \
# 16136              109000  [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰                 10000.0
# 16138               87500  [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰                 10000.0
# 16149               87500  [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰                 10000.0
# 16356              117500  [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰                 10000.0
# 16357               87500  [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰                 10000.0
# 16566               87500  [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰                 10000.0
# 16683               87500  [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰                 10000.0
# 30274              109500  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 30396              109500  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 30401              109500  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 36889              109500  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 37583              109500  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 37750              109500  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 37819              109500  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 37900              109500  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 37916              109500  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 37936              109500  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 38127              109500  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 38139              109500  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 38143              100000  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 38361              109500  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 38462              109500  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 41107              109500  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
#
#        sale_price  tax_free_amount      pg method subcategory_title  \
# 16136    119000.0         119000.0  INICIS   CARD          딥러닝/인공지능
# 16138     97500.0          97500.0  INICIS   CARD             코딩 입문
# 16149     97500.0          97500.0  INICIS   CARD             코딩 입문
# 16356    127500.0         127500.0  INICIS   CARD           개발자 커리어
# 16357     97500.0          97500.0  INICIS   CARD             코딩 입문
# 16566     97500.0          97500.0  INICIS  VBANK             코딩 입문
# 16683     97500.0          97500.0  INICIS   CARD             코딩 입문
# 30274    129500.0         129500.0  INICIS   CARD           개발자 커리어
# 30396    129500.0         129500.0  INICIS   CARD           개발자 커리어
# 30401    129500.0         129500.0  INICIS   CARD           개발자 커리어
# 36889    129500.0         129500.0  INICIS   CARD           개발자 커리어
# 37583    129500.0         129500.0  INICIS   CARD           개발자 커리어
# 37750    129500.0         129500.0  INICIS   CARD           개발자 커리어
# 37819    129500.0         129500.0  INICIS   CARD           개발자 커리어
# 37900    129500.0         129500.0  INICIS   CARD           개발자 커리어
# 37916    129500.0         129500.0  INICIS   CARD           개발자 커리어
# 37936    129500.0         129500.0  INICIS   CARD           개발자 커리어
# 38127    129500.0         129500.0  INICIS   CARD           개발자 커리어
# 38139    129500.0         129500.0  INICIS   CARD           개발자 커리어
# 38143    120000.0         120000.0  INICIS   CARD          딥러닝/인공지능
# 38361    129500.0         129500.0  INICIS   CARD           개발자 커리어
# 38462    129500.0         129500.0  INICIS   CARD           개발자 커리어
# 41107    129500.0         129500.0  INICIS   CARD           개발자 커리어
#
#       marketing_start_at
# 16136         2021-04-07
# 16138         2020-01-23
# 16149         2020-01-23
# 16356         2019-09-30
# 16357         2020-01-23
# 16566         2020-01-23
# 16683         2020-01-23
# 30274         2019-09-30
# 30396         2019-09-30
# 30401         2019-09-30
# 36889         2019-09-30
# 37583         2019-09-30
# 37750         2019-09-30
# 37819         2019-09-30
# 37900         2019-09-30
# 37916         2019-09-30
# 37936         2019-09-30
# 38127         2019-09-30
# 38139         2019-09-30
# 38143         2021-04-07
# 38361         2019-09-30
# 38462         2019-09-30
# 41107         2019-09-30

# %%
cond = wc_df_all['customer_id'] == 495876.0
wc_df_all[cond]
# Out:
#             id  customer_id  course_id     type      state  \
# 18703  1024341     495876.0   203787.0  PAYMENT  COMPLETED
# 20087  1031997     495876.0   204013.0    ORDER  CANCELLED
# 20097  1032006     495876.0   204013.0    ORDER  CANCELLED
# 20103  1032038     495876.0   204013.0    ORDER  CANCELLED
# 20223  1032332     495876.0   204013.0    ORDER  CANCELLED
# 20229  1032352     495876.0   204013.0    ORDER  CANCELLED
# 20316  1032562     495876.0   204013.0    ORDER  CANCELLED
# 20521  1033082     495876.0   204286.0    ORDER  CANCELLED
# 20534  1033115     495876.0   204013.0    ORDER  CANCELLED
# 20789  1033062     495876.0   204013.0    ORDER  CANCELLED
# 20790  1033771     495876.0   204013.0  PAYMENT  COMPLETED
#
#                      course_title category_title format        completed_at  \
# 18703     초격차 패키지 : 한번에 끝내는 디자인 툴            디자인    올인원 2021-04-25 22:44:32
# 20087     올인원 패키지 : 완전정복 시각디자인 기초            디자인    올인원 2021-04-26 22:37:05
# 20097     올인원 패키지 : 완전정복 시각디자인 기초            디자인    올인원 2021-04-26 22:41:06
# 20103     올인원 패키지 : 완전정복 시각디자인 기초            디자인    올인원 2021-04-26 22:48:12
# 20223     올인원 패키지 : 완전정복 시각디자인 기초            디자인    올인원 2021-04-27 01:03:44
# 20229     올인원 패키지 : 완전정복 시각디자인 기초            디자인    올인원 2021-04-27 01:09:56
# 20316     올인원 패키지 : 완전정복 시각디자인 기초            디자인    올인원 2021-04-27 08:14:51
# 20521  초격차 패키지 : 한번에 끝내는 3D 디자인 툴            디자인    올인원 2021-04-27 12:22:42
# 20534     올인원 패키지 : 완전정복 시각디자인 기초            디자인    올인원 2021-04-27 12:33:29
# 20789     올인원 패키지 : 완전정복 시각디자인 기초            디자인    올인원 2021-04-27 16:58:49
# 20790     올인원 패키지 : 완전정복 시각디자인 기초            디자인    올인원 2021-04-27 16:59:47
#
#        transaction_amount              coupon_title  coupon_discount_amount  \
# 18703              142000  [웰컴쿠폰] 올인원 패키지 3만원 할인 쿠폰                 30000.0
# 20087              150000  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 20097              150000  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 20103              150000  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 20223              150000  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 20229              150000  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 20316              150000  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 20521              199000  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 20534              150000  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 20789              150000  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 20790              150000  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
#
#        sale_price  tax_free_amount      pg method subcategory_title  \
# 18703    172000.0         172000.0  INICIS  VBANK              디자인툴
# 20087    170000.0         170000.0  INICIS   CARD             시각디자인
# 20097    170000.0         170000.0  INICIS   CARD             시각디자인
# 20103    170000.0         170000.0  INICIS   CARD             시각디자인
# 20223    170000.0         170000.0  INICIS   CARD             시각디자인
# 20229    170000.0         170000.0  INICIS   CARD             시각디자인
# 20316    170000.0         170000.0  INICIS   CARD             시각디자인
# 20521    219000.0         219000.0  INICIS   CARD              디자인툴
# 20534    170000.0         170000.0  INICIS   CARD             시각디자인
# 20789    170000.0         170000.0  INICIS   CARD             시각디자인
# 20790    170000.0         170000.0  INICIS   CARD             시각디자인
#
#        marketing_start_at
# 18703 2020-12-24 11:00:00
# 20087 2021-03-16 00:00:00
# 20097 2021-03-16 00:00:00
# 20103 2021-03-16 00:00:00
# 20223 2021-03-16 00:00:00
# 20229 2021-03-16 00:00:00
# 20316 2021-03-16 00:00:00
# 20521 2021-04-23 00:00:00
# 20534 2021-03-16 00:00:00
# 20789 2021-03-16 00:00:00
# 20790 2021-03-16 00:00:00

# %%
wc_df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17409 entries, 4 to 105418
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             17409 non-null  float64
#  1   course_id               17409 non-null  float64
#  2   type                    17409 non-null  object
#  3   state                   17409 non-null  object
#  4   course_title            17409 non-null  object
#  5   category_title          17409 non-null  object
#  6   format                  17409 non-null  object
#  7   completed_at            17409 non-null  datetime64[ns]
#  8   transaction_amount      17409 non-null  int64
#  9   coupon_title            17409 non-null  object
#  10  coupon_discount_amount  17409 non-null  float64
#  11  sale_price              17409 non-null  float64
#  12  pg                      15421 non-null  object
#  13  method                  16011 non-null  object
#  14  subcategory_title       16167 non-null  object
#  15  marketing_start_at      15461 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(4), int64(1), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# ## 1. 전체 강의 수강률 > 결제 금액과 연관성 > 할인(쿠폰) 연관성

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105419 entries, 0 to 105418
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      105419 non-null  int64
#  1   customer_id             105416 non-null  float64
#  2   course_id               100212 non-null  float64
#  3   type                    105419 non-null  object
#  4   state                   105419 non-null  object
#  5   course_title            105403 non-null  object
#  6   category_title          105395 non-null  object
#  7   format                  105403 non-null  object
#  8   completed_at            105419 non-null  datetime64[ns]
#  9   transaction_amount      105419 non-null  int64
#  10  coupon_title            31817 non-null   object
#  11  coupon_discount_amount  31817 non-null   float64
#  12  sale_price              104291 non-null  float64
#  13  tax_free_amount         104291 non-null  float64
#  14  pg                      90344 non-null   object
#  15  method                  92323 non-null   object
#  16  subcategory_title       85590 non-null   object
#  17  marketing_start_at      87440 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(5), int64(2), object(9)
# memory usage: 14.5+ MB

# %%
# 전체 강의 수강률

df["course_title"].value_counts()
# Out:
# 초격차 패키지 : 한 번에 끝내는 프론트엔드 개발               3257
# 초격차 패키지 : 한번에 끝내는 Java/Spring 웹 개발 마스터    2756
# 초격차 패키지 : 한번에 끝내는 영상 촬영과 편집               2541
# The RED : 김영하 작가의 내 안의 숨은 이야기를 찾아 쓰는 법    2132
# 올인원 패키지 : star741의 캐주얼 일러스트 드로잉           1636
#                                           ...
# (B2B) 미니랜드 온라인 구독 올 플랜 - 비대면바우처              1
# (B2B) (주)유투바이오 온라인 구독 패키지 플랜 - 비대면바우처        1
# (B2B) 카테크 온라인 구독 올 플랜 - 비대면바우처               1
# (B2B) 주식회사 마링 온라인 구독 올 플랜 - 비대면바우처           1
# (B2B) (주)오디 온라인 구독 올 플랜 - 비대면바우처             1
# Name: course_title, Length: 1641, dtype: int64

# %%
df['course_title'].nunique()
# Out:
# 1641

# %%
df.isna().sum()
# Out:
# id                            0
# customer_id                   3
# course_id                  5207
# type                          0
# state                         0
# course_title                 16
# category_title               24
# format                       16
# completed_at                  0
# transaction_amount            0
# coupon_title              73602
# coupon_discount_amount    73602
# sale_price                 1128
# tax_free_amount            1128
# pg                        15075
# method                    13096
# subcategory_title         19829
# marketing_start_at        17979
# dtype: int64

# %%
cour_ti = df.dropna(subset=['course_title'])
cour_ti.isna().sum()
# Out:
# id                            0
# customer_id                   0
# course_id                  5191
# type                          0
# state                         0
# course_title                  0
# category_title                8
# format                        0
# completed_at                  0
# transaction_amount            0
# coupon_title              73586
# coupon_discount_amount    73586
# sale_price                 1112
# tax_free_amount            1112
# pg                        15059
# method                    13096
# subcategory_title         19813
# marketing_start_at        17963
# dtype: int64

# %%
cour_ti['course_title']
# Out:
# 0               올인원 패키지 : 알고리즘 기술면접 완전 정복
# 1             초격차 패키지 : 한번에 끝내는 영상 촬영과 편집
# 2                    시크릿코드 : 프론트엔드 실무 완성편
# 3                    시크릿코드 : 프론트엔드 실무 완성편
# 4           올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX
#                        ...
# 105414    초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기
# 105415                부동산 디벨로퍼 아카데미 : 인허가
# 105416    초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기
# 105417                부동산 디벨로퍼 아카데미 : 인허가
# 105418                 용호수의 돈 버는 실전 영상 제작
# Name: course_title, Length: 105403, dtype: object

# %%
coti_df = cour_ti[cour_ti['course_title'].str.contains('패키지')]
co_df = coti_df[['course_title', 'transaction_amount']].value_counts()
cdf = co_df.to_frame()
cdf
# sns.scatterplot(data=cdf)
# Out:
#                                                                          0
# course_title                                       transaction_amount
# 올인원 패키지 : star741의 캐주얼 일러스트 드로잉                    144000              573
# 초격차 패키지 : 일잘러 필수 스킬 모음.zip                         109000              553
# 올인원 패키지 : 아카데미 : 편집하는여자의 영상편집 마스터클래스 - 제 1강 프리미... 98000               541
# 초격차 패키지 : 한 번에 끝내는 프론트엔드 개발                        95000               463
#                                                    116000              454
# ...                                                                    ...
# 올인원 패키지 : 수학적으로 접근하는 딥러닝                           76000                 1
#                                                    76500                 1
#                                                    84000                 1
#                                                    85000                 1
# 올인원 패키지 : 아파트 말고 부동산 재테크 시작하기                      222000                1
#
# [7374 rows x 1 columns]

# %%
cdf.columns
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
df[['course_title', 'transaction_amount', 'sale_price']]
# Out:
#                            course_title  transaction_amount  sale_price
# 0             올인원 패키지 : 알고리즘 기술면접 완전 정복               90500    110500.0
# 1           초격차 패키지 : 한번에 끝내는 영상 촬영과 편집               96000    116000.0
# 2                  시크릿코드 : 프론트엔드 실무 완성편              171810    190900.0
# 3                  시크릿코드 : 프론트엔드 실무 완성편              171810    190900.0
# 4         올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX               97500    117500.0
# ...                                 ...                 ...         ...
# 105414  초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기               96000    116000.0
# 105415              부동산 디벨로퍼 아카데미 : 인허가              189000    189000.0
# 105416  초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기               96000    116000.0
# 105417              부동산 디벨로퍼 아카데미 : 인허가              189000    189000.0
# 105418               용호수의 돈 버는 실전 영상 제작              139000    169000.0
#
# [105419 rows x 3 columns]

# %%
co_ti = df.groupby('course_title').mean()
co_ti
# Out:
#                                                 id    customer_id  course_id  \
# course_title
# (B2B)  컨테이너 랩 온라인 구독 올 플랜 - 비대면바우처    1.130005e+06  556177.000000   205478.0
# (B2B) (재)은행권청년창업재단 온라인 구독 올 플랜        1.274762e+06  557372.000000   205213.0
# (B2B) (주)가이던스 온라인 구독 올 플랜 - 비대면바우처    1.216739e+06  594286.000000   206267.0
# (B2B) (주)경원테크 온라인 구독 올 플랜 - 비대면바우처    1.085206e+06  535617.000000   205327.0
# (B2B) (주)공정씨컴퍼니 온라인 구독 올 플랜 - 비대면바우처  1.367252e+06  672301.000000   207714.0
# ...                                            ...            ...        ...
# 프론트엔드 개발자 되기 온라인 완주반 3기               9.957672e+05  333459.794118   204265.0
# 프론트엔드 개발자 되기 온라인 완주반 4기               1.073298e+06  424479.656863   205058.0
# 합격 패스 : ADsP                          1.029687e+06  418192.495822   202589.0
# 합격 패스 : 데이터베이스와 SQLD                  1.134520e+06  418817.864789   202698.0
# 합격 패스 : 정보처리기사 필기&실기                  1.160277e+06  409125.182398   201518.0
#
#                                       transaction_amount  \
# course_title
# (B2B)  컨테이너 랩 온라인 구독 올 플랜 - 비대면바우처          6.000000e+05
# (B2B) (재)은행권청년창업재단 온라인 구독 올 플랜              1.738000e+06
# (B2B) (주)가이던스 온라인 구독 올 플랜 - 비대면바우처          2.000000e+06
# (B2B) (주)경원테크 온라인 구독 올 플랜 - 비대면바우처          1.200000e+06
# (B2B) (주)공정씨컴퍼니 온라인 구독 올 플랜 - 비대면바우처        2.000000e+06
# ...                                                  ...
# 프론트엔드 개발자 되기 온라인 완주반 3기                     4.729485e+05
# 프론트엔드 개발자 되기 온라인 완주반 4기                     4.909804e+05
# 합격 패스 : ADsP                                4.812716e+04
# 합격 패스 : 데이터베이스와 SQLD                        6.400614e+04
# 합격 패스 : 정보처리기사 필기&실기                        7.162691e+03
#
#                                       coupon_discount_amount     sale_price  \
# course_title
# (B2B)  컨테이너 랩 온라인 구독 올 플랜 - 비대면바우처                       NaN            NaN
# (B2B) (재)은행권청년창업재단 온라인 구독 올 플랜                           NaN            NaN
# (B2B) (주)가이던스 온라인 구독 올 플랜 - 비대면바우처                       NaN            NaN
# (B2B) (주)경원테크 온라인 구독 올 플랜 - 비대면바우처                       NaN            NaN
# (B2B) (주)공정씨컴퍼니 온라인 구독 올 플랜 - 비대면바우처                     NaN            NaN
# ...                                                      ...            ...
# 프론트엔드 개발자 되기 온라인 완주반 3기                         91375.000000  615147.058824
# 프론트엔드 개발자 되기 온라인 완주반 4기                         60157.894737  600294.117647
# 합격 패스 : ADsP                                    16799.561404   59000.000000
# 합격 패스 : 데이터베이스와 SQLD                            26603.278689   79000.000000
# 합격 패스 : 정보처리기사 필기&실기                             9603.737864    9940.816327
#
#                                       tax_free_amount
# course_title
# (B2B)  컨테이너 랩 온라인 구독 올 플랜 - 비대면바우처                NaN
# (B2B) (재)은행권청년창업재단 온라인 구독 올 플랜                    NaN
# (B2B) (주)가이던스 온라인 구독 올 플랜 - 비대면바우처                NaN
# (B2B) (주)경원테크 온라인 구독 올 플랜 - 비대면바우처                NaN
# (B2B) (주)공정씨컴퍼니 온라인 구독 올 플랜 - 비대면바우처              NaN
# ...                                               ...
# 프론트엔드 개발자 되기 온라인 완주반 3기                 615147.058824
# 프론트엔드 개발자 되기 온라인 완주반 4기                 600294.117647
# 합격 패스 : ADsP                             59000.000000
# 합격 패스 : 데이터베이스와 SQLD                     79000.000000
# 합격 패스 : 정보처리기사 필기&실기                      9940.816327
#
# [1641 rows x 7 columns]

# %%
df[['course_title', 'transaction_amount', 'sale_price']].value_counts()
# Out:
# course_title                            transaction_amount  sale_price
# The RED : 김영하 작가의 내 안의 숨은 이야기를 찾아 쓰는 법  140000              140000.0      880
# 네카라쿠배 프론트엔드 취업완성 스쿨 2기_1차 테스트           0                   1.0           875
# The RED : 김영하 작가의 내 안의 숨은 이야기를 찾아 쓰는 법  149000              149000.0      606
# 올인원 패키지 : star741의 캐주얼 일러스트 드로잉         144000              144000.0      559
# 합격 패스 : 정보처리기사 필기&실기                    9900                9900.0        527
#                                                                          ...
# 올인원 패키지 : 부동산 투자                        26000               115000.0        1
#                                         25500               116500.0        1
#                                         24000               147000.0        1
#                                         23500               115500.0        1
# 올인원 패키지 : 소금툰과 함께 캐릭터 드로잉/굿즈/임티/컷툰      26000               95000.0         1
# Length: 10576, dtype: int64

# %% [markdown]
# ## 2. pg/method를 통해 결제 수단 통계 > 결제 금액과 연관성

# %%
df[['pg', 'method']].value_counts()
# Out:
# pg      method
# INICIS  CARD        50823
#         VBANK        7138
# KAKAO   POINT        6174
#         CARD         3528
# NAVER   CARD         3350
# INICIS  TRANS        2126
# PAYCO   CARD         1839
# NAVER   POINT        1276
# PAYCO   POINT         634
# NAVER   TRANS         197
# CHAI    TRANS         154
# PAYCO   VBANK           8
#         TRANSFER        1
# dtype: int64

# %%
df['transaction_amount'].value_counts()
# Out:
#  0         4736
#  299000    2191
#  99000     1906
#  119000    1649
#  149000    1616
#            ...
#  53700        1
#  58700        1
#  94300        1
# -186666       1
# -108186       1
# Name: transaction_amount, Length: 2393, dtype: int64

# %%
adf = df['transaction_amount'] == '0'
adf[[adf, 'courts_title']]
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/common.py:241: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = np.asarray(values, dtype=dtype)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-135-6f47f9f9f407> in <module>()
#       1 adf = df['transaction_amount'] == '0'
# ----> 2 adf[[adf, 'courts_title']]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     964             return self._get_values(key)
#     965
# --> 966         return self._get_with(key)
#     967
#     968     def _get_with(self, key):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _get_with(self, key)
#    1004
#    1005         # handle the dup indexing case GH#4246
# -> 1006         return self.loc[key]
#    1007
#    1008     def _get_values_tuple(self, key):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1151                     raise ValueError("Cannot index with multidimensional key")
#    1152
# -> 1153                 return self._getitem_iterable(key, axis=axis)
#    1154
#    1155             # nested tuple slicing
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1091
#    1092         # A collection of keys
# -> 1093         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1094         return self.obj._reindex_with_indexers(
#    1095             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1307
#    1308         if ax._index_as_unique:
# -> 1309             indexer = ax.get_indexer_for(keyarr)
#    1310             keyarr = ax.reindex(keyarr)[0]
#    1311         else:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_indexer_for(self, target, **kwargs)
#    5273         """
#    5274         if self._index_as_unique:
# -> 5275             return self.get_indexer(target, **kwargs)
#    5276         indexer, _ = self.get_indexer_non_unique(target)
#    5277         return indexer
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    3484             )
#    3485
# -> 3486         return self._get_indexer(target, method, limit, tolerance)
#    3487
#    3488     def _get_indexer(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/range.py in _get_indexer(self, target, method, limit, tolerance)
#     411         if not is_signed_integer_dtype(target):
#     412             # checks/conversions/roundings are delegated to general method
# --> 413             return super()._get_indexer(target, method=method, tolerance=tolerance)
#     414
#     415         target_array = np.asarray(target)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in _get_indexer(self, target, method, limit, tolerance)
#    3502             target = target.astype(dtype, copy=False)
#    3503             return this.get_indexer(
# -> 3504                 target, method=method, limit=limit, tolerance=tolerance
#    3505             )
#    3506
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    3484             )
#    3485
# -> 3486         return self._get_indexer(target, method, limit, tolerance)
#    3487
#    3488     def _get_indexer(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in _get_indexer(self, target, method, limit, tolerance)
#    3510             indexer = self._get_nearest_indexer(target, limit, tolerance)
#    3511         else:
# -> 3512             indexer = self._engine.get_indexer(target._get_engine_target())
#    3513
#    3514         return ensure_platform_int(indexer)
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_indexer()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.lookup()
#
# TypeError: unhashable type: 'Series'

# %% [markdown]
# ## 3. 강의 종류의 따른 수강 통계 > 마케팅 시작(달 기준) or 금액과 연관성
