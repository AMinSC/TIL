# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-460 nsight-compute-2020.2.0
# Use 'sudo apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

plt.rc('font', family='NanumBarunGothic')
# 설치된 폰트 출력
font_list = [font.name for font in fm.fontManager.ttflist]
font_list
# Out:
# ['cmsy10',
#  'cmss10',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'DejaVu Sans Display',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'DejaVu Serif Display',
#  'cmex10',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'cmmi10',
#  'STIXSizeTwoSym',
#  'STIXSizeFiveSym',
#  'cmtt10',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'STIXSizeFourSym',
#  'cmr10',
#  'STIXSizeThreeSym',
#  'STIXGeneral',
#  'STIXSizeTwoSym',
#  'STIXSizeThreeSym',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'STIXSizeOneSym',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'STIXSizeFourSym',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'STIXSizeOneSym',
#  'DejaVu Sans',
#  'cmb10',
#  'Liberation Serif',
#  'NanumBarunGothic',
#  'Liberation Mono',
#  'NanumSquare',
#  'Liberation Sans',
#  'Liberation Sans Narrow',
#  'Liberation Serif',
#  'NanumBarunGothic',
#  'Liberation Sans Narrow',
#  'NanumMyeongjo',
#  'NanumSquare',
# ...

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/mini_project/파이널프로젝트_RAW_210329_210926.xlsx')
df.head()
# Out:
#        id  customer_id  course_id     type      state  \
# 0  970634     504760.0   201435.0    ORDER  CANCELLED
# 1  970650     432862.0   203178.0    ORDER  CANCELLED
# 2  970657      72297.0   204246.0  PAYMENT  COMPLETED
# 3  970656      72297.0   204246.0    ORDER  CANCELLED
# 4  970658     478028.0   201797.0  PAYMENT  COMPLETED
#
#                     course_title category_title  format        completed_at  \
# 0      올인원 패키지 : 알고리즘 기술면접 완전 정복          프로그래밍     올인원 2021-03-28 15:00:11
# 1    초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원 2021-03-28 15:16:53
# 2           시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인 2021-03-28 15:21:43
# 3           시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인 2021-03-28 15:21:43
# 4  올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성     올인원 2021-03-28 15:21:54
#
#    transaction_amount              coupon_title  coupon_discount_amount  \
# 0               90500                       NaN                     NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105419 entries, 0 to 105418
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      105419 non-null  int64
#  1   customer_id             105416 non-null  float64
#  2   course_id               100212 non-null  float64
#  3   type                    105419 non-null  object
#  4   state                   105419 non-null  object
#  5   course_title            105403 non-null  object
#  6   category_title          105395 non-null  object
#  7   format                  105403 non-null  object
#  8   completed_at            105419 non-null  datetime64[ns]
#  9   transaction_amount      105419 non-null  int64
#  10  coupon_title            31817 non-null   object
#  11  coupon_discount_amount  31817 non-null   float64
#  12  sale_price              104291 non-null  float64
# ...

# %%
df = df[['customer_id', 'type', 'state' , 'course_title', 'category_title', 'transaction_amount', 'coupon_title', 'coupon_discount_amount', 'sale_price', 'subcategory_title']]
df.head()
# Out:
#    customer_id     type      state                   course_title  \
# 0     504760.0    ORDER  CANCELLED      올인원 패키지 : 알고리즘 기술면접 완전 정복
# 1     432862.0    ORDER  CANCELLED    초격차 패키지 : 한번에 끝내는 영상 촬영과 편집
# 2      72297.0  PAYMENT  COMPLETED           시크릿코드 : 프론트엔드 실무 완성편
# 3      72297.0    ORDER  CANCELLED           시크릿코드 : 프론트엔드 실무 완성편
# 4     478028.0  PAYMENT  COMPLETED  올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX
#
#   category_title  transaction_amount              coupon_title  \
# 0          프로그래밍               90500                       NaN
# 1          영상/3D               96000                       NaN
# 2          프로그래밍              171810     [10% 할인] 시크릿코드 실무 완성편
# 3          프로그래밍              171810                       NaN
# 4         업무 생산성               97500  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
#
#    coupon_discount_amount  sale_price subcategory_title
# 0                     NaN    110500.0           개발자 커리어
# 1                     NaN    116000.0             영상 편집
# ...

# %%
df.info()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105419 entries, 0 to 105418
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   customer_id             105416 non-null  float64
#  1   type                    105419 non-null  object
#  2   state                   105419 non-null  object
#  3   course_title            105403 non-null  object
#  4   category_title          105395 non-null  object
#  5   transaction_amount      105419 non-null  int64
#  6   coupon_title            31817 non-null   object
#  7   coupon_discount_amount  31817 non-null   float64
#  8   sale_price              104291 non-null  float64
#  9   subcategory_title       85590 non-null   object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 8.0+ MB
# customer_id                   3
# type                          0
# state                         0
# course_title                 16
# ...

# %% [markdown]
# ## category 8개로 축약하기

# %%
df['category_title'].value_counts().to_frame()
# Out:
#           category_title
# 프로그래밍              34430
# 데이터사이언스            14076
# 업무 생산성             13323
# 디자인                12009
# 영상/3D              10260
# 마케팅                 9857
# 부동산/금융              5523
# 투자/재테크              2501
# 크리에이티브              2250
# 교육                  1031
# 지식콘텐츠                 56
# 비즈니스                  42
# 파이낸스                  25
# 데이터 사이언스               9
# 관리                     2
# 일러스트                   1

# %%
df = df.replace({'category_title':{'일러스트':'디자인'}})
df = df.replace({'category_title':{'데이터 사이언스':'데이터사이언스'}})
df['category_title'].value_counts().to_frame()
# Out:
#          category_title
# 프로그래밍             34430
# 데이터사이언스           14085
# 업무 생산성            13323
# 디자인               12010
# 영상/3D             10260
# 마케팅                9857
# 부동산/금융             5523
# 투자/재테크             2501
# 크리에이티브             2250
# 교육                 1031
# 지식콘텐츠                56
# 비즈니스                 42
# 파이낸스                 25
# 관리                    2

# %%
df = df[df.category_title != '교육']
df = df[df.category_title != '지식콘텐츠']
df = df[df.category_title != '비즈니스']
df = df[df.category_title != '파이낸스']
df = df[df.category_title != '관리']

df['category_title'].value_counts().to_frame()
# Out:
#          category_title
# 프로그래밍             34430
# 데이터사이언스           14085
# 업무 생산성            13323
# 디자인               12010
# 영상/3D             10260
# 마케팅                9857
# 부동산/금융             5523
# 투자/재테크             2501
# 크리에이티브             2250

# %%
df.isna().sum()
# Out:
# customer_id                   3
# type                          0
# state                         0
# course_title                 16
# category_title               24
# transaction_amount            0
# coupon_title              72450
# coupon_discount_amount    72450
# sale_price                  223
# subcategory_title         18673
# dtype: int64

# %%
# 결측치 제거
df = df.dropna(subset=['category_title']) 
df.isna().sum()
# Out:
# customer_id                   0
# type                          0
# state                         0
# course_title                  0
# category_title                0
# transaction_amount            0
# coupon_title              72426
# coupon_discount_amount    72426
# sale_price                  207
# subcategory_title         18649
# dtype: int64

# %%
sub_df = df.copy()

# %%
sub_df = df.dropna(subset=['subcategory_title'])
sub_df.isna().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of         customer_id   type  state  course_title  category_title  \
# 0             False  False  False         False           False
# 1             False  False  False         False           False
# 4             False  False  False         False           False
# 5             False  False  False         False           False
# 7             False  False  False         False           False
# ...             ...    ...    ...           ...             ...
# 105414        False  False  False         False           False
# 105415        False  False  False         False           False
# 105416        False  False  False         False           False
# 105417        False  False  False         False           False
# 105418        False  False  False         False           False
#
#         transaction_amount  coupon_title  coupon_discount_amount  sale_price  \
# ...

# %%
sub_df[sub_df['sale_price'].isnull()] 
sub_df = sub_df.dropna(subset=['sale_price'])
sub_df.isna().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of         customer_id   type  state  course_title  category_title  \
# 0             False  False  False         False           False
# 1             False  False  False         False           False
# 4             False  False  False         False           False
# 5             False  False  False         False           False
# 7             False  False  False         False           False
# ...             ...    ...    ...           ...             ...
# 105414        False  False  False         False           False
# 105415        False  False  False         False           False
# 105416        False  False  False         False           False
# 105417        False  False  False         False           False
# 105418        False  False  False         False           False
#
#         transaction_amount  coupon_title  coupon_discount_amount  sale_price  \
# ...

# %%
sub_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85562 entries, 0 to 105418
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             85562 non-null  float64
#  1   type                    85562 non-null  object
#  2   state                   85562 non-null  object
#  3   course_title            85562 non-null  object
#  4   category_title          85562 non-null  object
#  5   transaction_amount      85562 non-null  int64
#  6   coupon_title            29122 non-null  object
#  7   coupon_discount_amount  29122 non-null  float64
#  8   sale_price              85562 non-null  float64
#  9   subcategory_title       85562 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 7.2+ MB

# %% [markdown]
# ## 구매자 [PAYMENT.COMPLETED.customer_id - REFUND.COMPLETED.customer_id]

# %%
a = df['type'] == 'PAYMENT'
a = df[a]
b = a['state'] == 'COMPLETED'
a = a[b]
a
# Out:
#         customer_id  course_id     type      state  \
# 2           72297.0   204246.0  PAYMENT  COMPLETED
# 4          478028.0   201797.0  PAYMENT  COMPLETED
# 8          478033.0   203178.0  PAYMENT  COMPLETED
# 10         469860.0   203644.0  PAYMENT  COMPLETED
# 14         478035.0   203720.0  PAYMENT  COMPLETED
# ...             ...        ...      ...        ...
# 105411     669238.0   204286.0  PAYMENT  COMPLETED
# 105412     384003.0   203178.0  PAYMENT  COMPLETED
# 105413     670891.0   203935.0  PAYMENT  COMPLETED
# 105416     640697.0   205365.0  PAYMENT  COMPLETED
# 105418     610626.0   206720.0  PAYMENT  COMPLETED
#
#                                           course_title category_title  format  \
# 2                                 시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인
# 4                        올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성     올인원
# 8                          초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원
# ...

# %%
df['type'].unique()
# Out:
# array(['ORDER', 'PAYMENT', 'REFUND', 'TRANSACTION'], dtype=object)

# %%
c = df['type'] == 'REFUND'
c = df[c]
d = c['state'] == 'COMPLETED'
b = c[d]
b
# Out:
#         customer_id  course_id    type      state  \
# 651        444760.0   204122.0  REFUND  COMPLETED
# 652        472666.0   203178.0  REFUND  COMPLETED
# 666        447177.0   203989.0  REFUND  COMPLETED
# 672        373915.0   204264.0  REFUND  COMPLETED
# 675        456086.0        NaN  REFUND  COMPLETED
# ...             ...        ...     ...        ...
# 105169     600073.0   206065.0  REFUND  COMPLETED
# 105175     645911.0        NaN  REFUND  COMPLETED
# 105205     506356.0   206720.0  REFUND  COMPLETED
# 105245     604077.0   205569.0  REFUND  COMPLETED
# 105248     552100.0   203525.0  REFUND  COMPLETED
#
#                                             course_title category_title  \
# 651                               퍼포먼스 마케터 되기 온라인 완주반 2기            마케팅
# 652                          초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D
# 666                   올인원 패키지 : 소금툰과 함께 캐릭터 드로잉/굿즈/임티/컷툰            디자인
# ...

# %%
df_total = pd.merge(a,b,how='outer')
df_total
# Out:
#        customer_id  course_id     type      state  \
# 0          72297.0   204246.0  PAYMENT  COMPLETED
# 1         478028.0   201797.0  PAYMENT  COMPLETED
# 2         478033.0   203178.0  PAYMENT  COMPLETED
# 3         469860.0   203644.0  PAYMENT  COMPLETED
# 4         478035.0   203720.0  PAYMENT  COMPLETED
# ...            ...        ...      ...        ...
# 56719     600073.0   206065.0   REFUND  COMPLETED
# 56720     645911.0        NaN   REFUND  COMPLETED
# 56721     506356.0   206720.0   REFUND  COMPLETED
# 56722     604077.0   205569.0   REFUND  COMPLETED
# 56723     552100.0   203525.0   REFUND  COMPLETED
#
#                                            course_title category_title  \
# 0                                  시크릿코드 : 프론트엔드 실무 완성편          프로그래밍
# 1                         올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성
# 2                           초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D
# 3        올인원 패키지 : 권오상의 금융 아카데미 - 권오상의 재무제표 분석 기초(평생소장)         부동산/금융
# ...

# %%
df_total = df_total.drop_duplicates(subset='customer_id')

# %%
df_pay = df_total['type'] == 'PAYMENT'
df_pay = df_total[df_pay]
df_pay
# Out:
#        customer_id  course_id     type      state  \
# 0          72297.0   204246.0  PAYMENT  COMPLETED
# 1         478028.0   201797.0  PAYMENT  COMPLETED
# 2         478033.0   203178.0  PAYMENT  COMPLETED
# 3         469860.0   203644.0  PAYMENT  COMPLETED
# 4         478035.0   203720.0  PAYMENT  COMPLETED
# ...            ...        ...      ...        ...
# 52896     545804.0        NaN  PAYMENT  COMPLETED
# 52897     669238.0   204286.0  PAYMENT  COMPLETED
# 52899     670891.0   203935.0  PAYMENT  COMPLETED
# 52900     640697.0   205365.0  PAYMENT  COMPLETED
# 52901     610626.0   206720.0  PAYMENT  COMPLETED
#
#                                          course_title category_title  format  \
# 0                                시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인
# 1                       올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성     올인원
# 2                         초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원
# ...

# %% [markdown]
# ## 할인 금액 > 강의 가격 > 메인 카테고리

# %%
a.head()
# Out:
#    customer_id  course_id     type      state                   course_title  \
# 0     504760.0   201435.0    ORDER  CANCELLED      올인원 패키지 : 알고리즘 기술면접 완전 정복
# 1     432862.0   203178.0    ORDER  CANCELLED    초격차 패키지 : 한번에 끝내는 영상 촬영과 편집
# 2      72297.0   204246.0  PAYMENT  COMPLETED           시크릿코드 : 프론트엔드 실무 완성편
# 3      72297.0   204246.0    ORDER  CANCELLED           시크릿코드 : 프론트엔드 실무 완성편
# 4     478028.0   201797.0  PAYMENT  COMPLETED  올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX
#
#   category_title  format        completed_at  transaction_amount  \
# 0          프로그래밍     올인원 2021-03-28 15:00:11               90500
# 1          영상/3D     올인원 2021-03-28 15:16:53               96000
# 2          프로그래밍  스쿨 온라인 2021-03-28 15:21:43              171810
# 3          프로그래밍  스쿨 온라인 2021-03-28 15:21:43              171810
# 4         업무 생산성     올인원 2021-03-28 15:21:54               97500
#
#                coupon_title  coupon_discount_amount  sale_price   pg method  \
# ...

# %%
# 판매가와 실 구매가가 다른 값 구하기
sale_df = sub_df[sub_df['sale_price'] != sub_df['transaction_amount']]
# sale_df.info()
# 강의명에 '샘플'값 들어간 데이터 지우기
sample_df = sale_df[sale_df['course_title'].str.contains('샘플')].index
sale_df.drop(sample_df, inplace=True)
sale_df[sale_df.course_title.str.contains('테스트')]
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#         customer_id     type      state  \
# 13231      496790.0    ORDER  CANCELLED
# 13232      496790.0  PAYMENT  COMPLETED
# 13458      494922.0    ORDER  CANCELLED
# 13527       25280.0    ORDER  CANCELLED
# 13843      498212.0  PAYMENT  COMPLETED
# ...             ...      ...        ...
# 104727     662606.0   REFUND  COMPLETED
# 104900     666018.0   REFUND  COMPLETED
# 105056     659482.0  PAYMENT  COMPLETED
# 105237     618278.0  PAYMENT  CANCELLED
# 105296     670557.0  PAYMENT  COMPLETED
#
#                                            course_title category_title  \
# 13231                초격차 패키지 : 한 번에 끝내는 코딩테스트 369 Java편          프로그래밍
# ...

# %%
sale_df.course_title.value_counts()
# Out:
# 초격차 패키지 : 한 번에 끝내는 프론트엔드 개발               1767
# 초격차 패키지 : 한번에 끝내는 영상 촬영과 편집               1582
# 초격차 패키지 : 한번에 끝내는 Java/Spring 웹 개발 마스터    1525
# 초격차 패키지 : 한번에 끝내는 디자인 툴                    995
# 초격차 패키지 : 한번에 끝내는 UX/UI 디자인                793
#                                           ...
# The RED : 최고제품책임자(CPO) 윤희경                   5
# The RED : 데이터 사이언티스트 하용호                     5
# The RED : 프론트엔드 개발자 김태곤                      4
# The RED : 1조 기업 가치를 만들어 낸 경영 원칙 by 신현성       4
# 올인원 패키지 : Unity를 활용한 영화 애니메이션 제작             1
# Name: course_title, Length: 203, dtype: int64

# %%
sale_df[sale_df.sale_price < 10000]
# Out:
#        customer_id     type      state          course_title category_title  \
# 545       440315.0  PAYMENT  COMPLETED  합격 패스 : 정보처리기사 필기&실기          프로그래밍
# 556       459090.0  PAYMENT  COMPLETED  합격 패스 : 정보처리기사 필기&실기          프로그래밍
# 610       459433.0  PAYMENT  COMPLETED  합격 패스 : 정보처리기사 필기&실기          프로그래밍
# 826       461518.0  PAYMENT  COMPLETED  합격 패스 : 정보처리기사 필기&실기          프로그래밍
# 849       464874.0  PAYMENT  COMPLETED  합격 패스 : 정보처리기사 필기&실기          프로그래밍
# ...            ...      ...        ...                   ...            ...
# 95641     641292.0  PAYMENT  COMPLETED  합격 패스 : 정보처리기사 필기&실기          프로그래밍
# 95970     640661.0  PAYMENT  COMPLETED  합격 패스 : 정보처리기사 필기&실기          프로그래밍
# 96810     650987.0  PAYMENT  COMPLETED  합격 패스 : 정보처리기사 필기&실기          프로그래밍
# 97057     651681.0  PAYMENT  COMPLETED  합격 패스 : 정보처리기사 필기&실기          프로그래밍
# 97175     617027.0  PAYMENT  COMPLETED  합격 패스 : 정보처리기사 필기&실기          프로그래밍
#
# ...

# %% [markdown]
# 정처기 필기&실기 는

# %%
a = df[df.sale_price < 10000]
a = a.course_title.value_counts()

# %%
a.plot.barh()

# %%
sale_df = df[['sale_price', 'transaction_amount']]
sale_df.corr
# Out:
# <bound method DataFrame.corr of         sale_price  transaction_amount
# 0         110500.0               90500
# 1         116000.0               96000
# 2         190900.0              171810
# 3         190900.0              171810
# 4         117500.0               97500
# ...            ...                 ...
# 105414    116000.0               96000
# 105415    189000.0              189000
# 105416    116000.0               96000
# 105417    189000.0              189000
# 105418    169000.0              139000
#
# [104239 rows x 2 columns]>

# %%
sale_df.plot.scatter('transaction_amount', 'sale_price')

# %%
only_coupon = a['coupon_discount_amount'] > 0
only_coupon.value_counts()
# Out:
# False    72220
# True     31812
# Name: coupon_discount_amount, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 104239 entries, 0 to 105418
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   customer_id             104239 non-null  float64
#  1   course_id               99109 non-null   float64
#  2   type                    104239 non-null  object
#  3   state                   104239 non-null  object
#  4   course_title            104239 non-null  object
#  5   category_title          104239 non-null  object
#  6   format                  104239 non-null  object
#  7   completed_at            104239 non-null  datetime64[ns]
#  8   transaction_amount      104239 non-null  int64
#  9   coupon_title            31813 non-null   object
#  10  coupon_discount_amount  31813 non-null   float64
#  11  sale_price              104032 non-null  float64
#  12  pg                      90116 non-null   object
# ...

# %% [markdown]
# ## 재결재율:
# 1. 웰컴 할인쿠폰을 받은 사람 중 재결재률
# 2. 동일한 결제 수단으로 재 결제 여부

# %%
df_pay['coupon_title'].value_counts()
# Out:
# [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                      3455
# [WELCOME] 온라인 강의 3만원 할인쿠폰                     2036
# [WELCOME] 온라인 강의 2만원 할인쿠폰                     1488
# [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰                      1446
# [WELCOME] 온라인 강의 1만원 할인쿠폰                     1051
#                                               ...
# [무료수강권] 30개 프로젝트로 배우는 Android 앱 개발_최종원 강사님       1
# [패스트캠퍼스] 올인원 패키지: 컴퓨터 공학 전공_박용현 강사님              1
# [무료수강권] GA4 탑재, 구글 애널리틱스 끝장내기_안혜진 강사님            1
# [디자인 툴] 기수강생 5만원 구매 쿠폰                           1
# [재결제쿠폰]초격차 패키지 : 한 번에 끝내는 node.js 웹 프로그래밍        1
# Name: coupon_title, Length: 367, dtype: int64

# %%
# 쿠폰 사용자 추출
wc_df_all = df[(df['coupon_title'].str.contains('웰컴')) | (df['coupon_title'].str.contains('WELCOME'))]
a = wc_df_all['customer_id'].unique()

# %%
a
# Out:
# 13258

# %%
# 쿠폰 사용자 중복값 확인
wc_df_all['customer_id'].value_counts()
# Out:
# 494420.0    23
# 495876.0    11
# 534149.0    10
# 618845.0     8
# 600629.0     8
#             ..
# 528724.0     1
# 525095.0     1
# 528704.0     1
# 525564.0     1
# 610626.0     1
# Name: customer_id, Length: 13258, dtype: int64

# %%
# 쿠폰 사용자 중 중복값만 추출
foring = wc_df_all['customer_id'].value_counts().to_frame()
foring = foring[foring['customer_id'] > 1]
b = foring.index
len(b)
# Out:
# 2868

# %%
c = []
for i in a:
    for j in b:
        if i == j:
            c.append(j)
            print(j)
# Out:
# 478035.0
# 474083.0
# 463647.0
# 477557.0
# 478101.0
# 478138.0
# 478167.0
# 473323.0
# 478214.0
# 471221.0
# 478305.0
# 477325.0
# 477954.0
# 478339.0
# 183570.0
# 478325.0
# 429291.0
# 478366.0
# 431851.0
# 478428.0
# 436888.0
# 478462.0
# 478363.0
# 7002.0
# 478069.0
# 478397.0
# 478425.0
# 478488.0
# 477967.0
# 478550.0
# 478566.0
# 459090.0
# 477816.0
# 478632.0
# 478660.0
# 478716.0
# 439025.0
# 478789.0
# 478845.0
# 478539.0
# 476278.0
# 476679.0
# 462160.0
# 134364.0
# 479117.0
# 479231.0
# 479188.0
# 479292.0
# 475655.0
# 467574.0
# 439072.0
# 479679.0
# 441007.0
# 393322.0
# 477237.0
# 508436.0
# 479876.0
# 443346.0
# 479190.0
# 474958.0
# 480286.0
# 479936.0
# 477219.0
# 475995.0
# 480032.0
# 419784.0
# 480155.0
# 480162.0
# 451007.0
# 453761.0
# 479444.0
# 261026.0
# 462824.0
# 480347.0
# 480407.0
# 480414.0
# 401036.0
# 464632.0
# 480516.0
# 479313.0
# 480551.0
# 480553.0
# 480390.0
# 480565.0
# 396530.0
# 480586.0
# 186884.0
# 480694.0
# 480766.0
# 480799.0
# 480877.0
# ...

# %%
len(c)
# Out:
# 2868

# %%
print(len(a)) # 
print(len(b))
# Out:
# 13258
# 2868

# %%
def func(x):
    if x == c:
        return 1
    else:
        return 0

df['customer_id'] = df['customer_id'].map(func)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-150-232537ea67bb> in <module>()
#       5         return 0
#       6
# ----> 7 df['customer_id'] = df['customer_id'].map(func)
#       8 df.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in map(self, arg, na_action)
#    4159         dtype: object
#    4160         """
# -> 4161         new_values = super()._map_values(arg, na_action=na_action)
#    4162         return self._constructor(new_values, index=self.index).__finalize__(
#    4163             self, method="map"
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#     868
#     869         # mapper is a function
# --> 870         new_values = map_f(values, mapper)
#     871
#     872         return new_values
#
# ...

# %%
from collections import Counter

counter = Counter(c)

print(counter)
# Out:
# Counter({478035.0: 1, 474083.0: 1, 463647.0: 1, 477557.0: 1, 478101.0: 1, 478138.0: 1, 478167.0: 1, 473323.0: 1, 478214.0: 1, 471221.0: 1, 478305.0: 1, 477325.0: 1, 477954.0: 1, 478339.0: 1, 183570.0: 1, 478325.0: 1, 429291.0: 1, 478366.0: 1, 431851.0: 1, 478428.0: 1, 436888.0: 1, 478462.0: 1, 478363.0: 1, 7002.0: 1, 478069.0: 1, 478397.0: 1, 478425.0: 1, 478488.0: 1, 477967.0: 1, 478550.0: 1, 478566.0: 1, 459090.0: 1, 477816.0: 1, 478632.0: 1, 478660.0: 1, 478716.0: 1, 439025.0: 1, 478789.0: 1, 478845.0: 1, 478539.0: 1, 476278.0: 1, 476679.0: 1, 462160.0: 1, 134364.0: 1, 479117.0: 1, 479231.0: 1, 479188.0: 1, 479292.0: 1, 475655.0: 1, 467574.0: 1, 439072.0: 1, 479679.0: 1, 441007.0: 1, 393322.0: 1, 477237.0: 1, 508436.0: 1, 479876.0: 1, 443346.0: 1, 479190.0: 1, 474958.0: 1, 480286.0: 1, 479936.0: 1, 477219.0: 1, 475995.0: 1, 480032.0: 1, 419784.0: 1, 480155.0: 1, 480162.0: 1, 451007.0: 1, 453761.0: 1, 479444.0: 1, 261026.0: 1, 462824.0: 1, 480347.0: 1, 480407.0: 1, 480414.0: 1, 401
# ...

# %%
a = wc_df_all[wc_df_all['customer_id'].duplicated()]
a = a[a['type'] == 'PAYMENT']
a = a[a['customer_id'].duplicated()]
b = a[a['state'] != 'COMPLETED']

# %%
a.head()
# Out:
#         id  customer_id  course_id     type      state  \
# 2   970657      72297.0   204246.0  PAYMENT  COMPLETED
# 4   970658     478028.0   201797.0  PAYMENT  COMPLETED
# 8   970669     478033.0   203178.0  PAYMENT  COMPLETED
# 10  970671     469860.0   203644.0  PAYMENT  COMPLETED
# 14  970676     478035.0   203720.0  PAYMENT  COMPLETED
#
#                                       course_title category_title  format  \
# 2                             시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인
# 4                    올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성     올인원
# 8                      초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원
# 10  올인원 패키지 : 권오상의 금융 아카데미 - 권오상의 재무제표 분석 기초(평생소장)         부동산/금융     올인원
# 14                     초격차 패키지 : 한 번에 끝내는 프론트엔드 개발          프로그래밍     올인원
#
#           completed_at  transaction_amount              coupon_title  \
# 2  2021-03-28 15:21:43              171810     [10% 할인] 시크릿코드 실무 완성편
# ...

# %%
b.head()
# Out:
#        customer_id  course_id     type    state  \
# 10083     490886.0   201547.0  PAYMENT  PENDING
# 15352     491214.0   203532.0  PAYMENT  PENDING
# 26496     495380.0   203499.0  PAYMENT  DELETED
# 35991     531363.0   202357.0  PAYMENT  PENDING
# 38000     521513.0   202845.0  PAYMENT  PENDING
#
#                                   course_title category_title format  \
# 10083                       올인원 패키지 : 구글 애널리틱스            마케팅    올인원
# 15352    연습문제 패키지 : 퀴즈처럼 풀면서 배우는 파이썬 딥러닝 300제+        데이터사이언스    올인원
# 26496          올인원 패키지 : 100억을 움직이는 단 10장의 PPT         업무 생산성    올인원
# 35991              올인원 패키지 : 직장인을 위한 파이썬 데이터분석        데이터사이언스    올인원
# 38000  글로벌 엑스퍼트 : GAN 딥러닝 완벽 가이드 with 글로벌 엔지니어        데이터사이언스    올인원
#
#              completed_at  transaction_amount              coupon_title  \
# 10083 2021-04-09 11:03:39              100500  [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰
# 15352 2021-04-18 23:24:20               82000  [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰
# ...

# %%
cond = wc_df_all['customer_id'] == 
wc_df_all[cond]
# Out:
#       customer_id  course_id     type      state             course_title  \
# 479      477967.0   204267.0  PAYMENT    PENDING     프로그래밍 유치원 온라인 완주반 5기
# 492      477967.0   204267.0    ORDER  CANCELLED     프로그래밍 유치원 온라인 완주반 5기
# 1524     477967.0   204013.0  PAYMENT  COMPLETED  올인원 패키지 : 완전정복 시각디자인 기초
# 1561     477967.0   203782.0  PAYMENT  COMPLETED  초격차 패키지 : 한번에 끝내는 모션그래픽
#
#      category_title   format        completed_at  transaction_amount  \
# 479           프로그래밍  온라인 완주반 2021-03-28 23:49:04              250000
# 492           프로그래밍  온라인 완주반 2021-03-28 23:56:21              250000
# 1524            디자인      올인원 2021-03-29 19:22:58              139000
# 1561          영상/3D      올인원 2021-03-29 20:04:25              119000
#
#                   coupon_title  coupon_discount_amount  sale_price   pg  \
# 479   [웰컴쿠폰] 온라인 완주반 5만원 할인 쿠폰                 50000.0    300000.0  NaN
# 492   [웰컴쿠폰] 온라인 완주반 5만원 할인 쿠폰                 50000.0    300000.0  NaN
# ...

# %%
wc_df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17409 entries, 4 to 105418
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             17409 non-null  float64
#  1   course_id               17409 non-null  float64
#  2   type                    17409 non-null  object
#  3   state                   17409 non-null  object
#  4   course_title            17409 non-null  object
#  5   category_title          17409 non-null  object
#  6   format                  17409 non-null  object
#  7   completed_at            17409 non-null  datetime64[ns]
#  8   transaction_amount      17409 non-null  int64
#  9   coupon_title            17409 non-null  object
#  10  coupon_discount_amount  17409 non-null  float64
#  11  sale_price              17409 non-null  float64
#  12  pg                      15421 non-null  object
#  13  method                  16011 non-null  object
# ...

# %% [markdown]
# ## 1. 전체 강의 수강률 > 결제 금액과 연관성 > 할인(쿠폰) 연관성

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105419 entries, 0 to 105418
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      105419 non-null  int64
#  1   customer_id             105416 non-null  float64
#  2   course_id               100212 non-null  float64
#  3   type                    105419 non-null  object
#  4   state                   105419 non-null  object
#  5   course_title            105403 non-null  object
#  6   category_title          105395 non-null  object
#  7   format                  105403 non-null  object
#  8   completed_at            105419 non-null  datetime64[ns]
#  9   transaction_amount      105419 non-null  int64
#  10  coupon_title            31817 non-null   object
#  11  coupon_discount_amount  31817 non-null   float64
#  12  sale_price              104291 non-null  float64
# ...

# %%
# 전체 강의 수강률

df["course_title"].value_counts()
# Out:
# 초격차 패키지 : 한 번에 끝내는 프론트엔드 개발               3257
# 초격차 패키지 : 한번에 끝내는 Java/Spring 웹 개발 마스터    2756
# 초격차 패키지 : 한번에 끝내는 영상 촬영과 편집               2541
# The RED : 김영하 작가의 내 안의 숨은 이야기를 찾아 쓰는 법    2132
# 올인원 패키지 : star741의 캐주얼 일러스트 드로잉           1636
#                                           ...
# (B2B) 미니랜드 온라인 구독 올 플랜 - 비대면바우처              1
# (B2B) (주)유투바이오 온라인 구독 패키지 플랜 - 비대면바우처        1
# (B2B) 카테크 온라인 구독 올 플랜 - 비대면바우처               1
# (B2B) 주식회사 마링 온라인 구독 올 플랜 - 비대면바우처           1
# (B2B) (주)오디 온라인 구독 올 플랜 - 비대면바우처             1
# Name: course_title, Length: 1641, dtype: int64

# %%
df['course_title'].nunique()
# Out:
# 1641

# %%
df.isna().sum()
# Out:
# id                            0
# customer_id                   3
# course_id                  5207
# type                          0
# state                         0
# course_title                 16
# category_title               24
# format                       16
# completed_at                  0
# transaction_amount            0
# coupon_title              73602
# coupon_discount_amount    73602
# sale_price                 1128
# tax_free_amount            1128
# pg                        15075
# method                    13096
# subcategory_title         19829
# marketing_start_at        17979
# dtype: int64

# %%
cour_ti = df.dropna(subset=['course_title'])
cour_ti.isna().sum()
# Out:
# id                            0
# customer_id                   0
# course_id                  5191
# type                          0
# state                         0
# course_title                  0
# category_title                8
# format                        0
# completed_at                  0
# transaction_amount            0
# coupon_title              73586
# coupon_discount_amount    73586
# sale_price                 1112
# tax_free_amount            1112
# pg                        15059
# method                    13096
# subcategory_title         19813
# marketing_start_at        17963
# dtype: int64

# %%
cour_ti['course_title']
# Out:
# 0               올인원 패키지 : 알고리즘 기술면접 완전 정복
# 1             초격차 패키지 : 한번에 끝내는 영상 촬영과 편집
# 2                    시크릿코드 : 프론트엔드 실무 완성편
# 3                    시크릿코드 : 프론트엔드 실무 완성편
# 4           올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX
#                        ...
# 105414    초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기
# 105415                부동산 디벨로퍼 아카데미 : 인허가
# 105416    초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기
# 105417                부동산 디벨로퍼 아카데미 : 인허가
# 105418                 용호수의 돈 버는 실전 영상 제작
# Name: course_title, Length: 105403, dtype: object

# %%
coti_df = cour_ti[cour_ti['course_title'].str.contains('패키지')]
co_df = coti_df[['course_title', 'transaction_amount']].value_counts()
cdf = co_df.to_frame()
cdf
# sns.scatterplot(data=cdf)
# Out:
#                                                                          0
# course_title                                       transaction_amount
# 올인원 패키지 : star741의 캐주얼 일러스트 드로잉                    144000              573
# 초격차 패키지 : 일잘러 필수 스킬 모음.zip                         109000              553
# 올인원 패키지 : 아카데미 : 편집하는여자의 영상편집 마스터클래스 - 제 1강 프리미... 98000               541
# 초격차 패키지 : 한 번에 끝내는 프론트엔드 개발                        95000               463
#                                                    116000              454
# ...                                                                    ...
# 올인원 패키지 : 수학적으로 접근하는 딥러닝                           76000                 1
#                                                    76500                 1
#                                                    84000                 1
#                                                    85000                 1
# 올인원 패키지 : 아파트 말고 부동산 재테크 시작하기                      222000                1
#
# ...

# %%
cdf.columns
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
df[['course_title', 'transaction_amount', 'sale_price']]
# Out:
#                            course_title  transaction_amount  sale_price
# 0             올인원 패키지 : 알고리즘 기술면접 완전 정복               90500    110500.0
# 1           초격차 패키지 : 한번에 끝내는 영상 촬영과 편집               96000    116000.0
# 2                  시크릿코드 : 프론트엔드 실무 완성편              171810    190900.0
# 3                  시크릿코드 : 프론트엔드 실무 완성편              171810    190900.0
# 4         올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX               97500    117500.0
# ...                                 ...                 ...         ...
# 105414  초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기               96000    116000.0
# 105415              부동산 디벨로퍼 아카데미 : 인허가              189000    189000.0
# 105416  초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기               96000    116000.0
# 105417              부동산 디벨로퍼 아카데미 : 인허가              189000    189000.0
# 105418               용호수의 돈 버는 실전 영상 제작              139000    169000.0
#
# [105419 rows x 3 columns]

# %%
co_ti = df.groupby('course_title').mean()
co_ti
# Out:
#                                                 id    customer_id  course_id  \
# course_title
# (B2B)  컨테이너 랩 온라인 구독 올 플랜 - 비대면바우처    1.130005e+06  556177.000000   205478.0
# (B2B) (재)은행권청년창업재단 온라인 구독 올 플랜        1.274762e+06  557372.000000   205213.0
# (B2B) (주)가이던스 온라인 구독 올 플랜 - 비대면바우처    1.216739e+06  594286.000000   206267.0
# (B2B) (주)경원테크 온라인 구독 올 플랜 - 비대면바우처    1.085206e+06  535617.000000   205327.0
# (B2B) (주)공정씨컴퍼니 온라인 구독 올 플랜 - 비대면바우처  1.367252e+06  672301.000000   207714.0
# ...                                            ...            ...        ...
# 프론트엔드 개발자 되기 온라인 완주반 3기               9.957672e+05  333459.794118   204265.0
# 프론트엔드 개발자 되기 온라인 완주반 4기               1.073298e+06  424479.656863   205058.0
# 합격 패스 : ADsP                          1.029687e+06  418192.495822   202589.0
# 합격 패스 : 데이터베이스와 SQLD                  1.134520e+06  418817.864789   202698.0
# 합격 패스 : 정보처리기사 필기&실기                  1.160277e+06  409125.182398   201518.0
#
# ...

# %%
df[['course_title', 'transaction_amount', 'sale_price']].value_counts()
# Out:
# course_title                            transaction_amount  sale_price
# The RED : 김영하 작가의 내 안의 숨은 이야기를 찾아 쓰는 법  140000              140000.0      880
# 네카라쿠배 프론트엔드 취업완성 스쿨 2기_1차 테스트           0                   1.0           875
# The RED : 김영하 작가의 내 안의 숨은 이야기를 찾아 쓰는 법  149000              149000.0      606
# 올인원 패키지 : star741의 캐주얼 일러스트 드로잉         144000              144000.0      559
# 합격 패스 : 정보처리기사 필기&실기                    9900                9900.0        527
#                                                                          ...
# 올인원 패키지 : 부동산 투자                        26000               115000.0        1
#                                         25500               116500.0        1
#                                         24000               147000.0        1
#                                         23500               115500.0        1
# 올인원 패키지 : 소금툰과 함께 캐릭터 드로잉/굿즈/임티/컷툰      26000               95000.0         1
# Length: 10576, dtype: int64
