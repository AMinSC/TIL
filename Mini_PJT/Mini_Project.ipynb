# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-460 nsight-compute-2020.2.0
# Use 'sudo apt autoremove' to remove them.
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 42 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 0s (45.7 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 155203 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

plt.rc('font', family='NanumBarunGothic')
# 설치된 폰트 출력
font_list = [font.name for font in fm.fontManager.ttflist]
font_list
# Out:
# ['STIXSizeFourSym',
#  'STIXGeneral',
#  'DejaVu Serif Display',
#  'DejaVu Sans',
#  'DejaVu Sans Mono',
#  'cmtt10',
#  'STIXNonUnicode',
#  'STIXSizeOneSym',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'STIXSizeFiveSym',
#  'DejaVu Sans Display',
#  'DejaVu Serif',
#  'STIXSizeTwoSym',
#  'STIXGeneral',
#  'STIXSizeOneSym',
#  'STIXGeneral',
#  'cmb10',
#  'cmss10',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'STIXSizeTwoSym',
#  'STIXSizeFourSym',
#  'cmr10',
#  'cmex10',
#  'STIXNonUnicode',
#  'STIXNonUnicode',
#  'STIXSizeThreeSym',
#  'DejaVu Serif',
#  'DejaVu Sans Mono',
#  'STIXSizeThreeSym',
#  'DejaVu Serif',
#  'cmmi10',
#  'cmsy10',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'Liberation Serif',
#  'Liberation Sans Narrow',
#  'NanumSquare',
#  'NanumMyeongjo',
#  'NanumBarunGothic',
#  'Humor Sans',
#  'Liberation Serif',
#  'Liberation Sans',
#  'Liberation Mono',
#  'Liberation Sans',
#  'Liberation Sans Narrow',
#  'NanumBarunGothic',
#  'NanumMyeongjo',
#  'Liberation Serif',
#  'Liberation Sans Narrow',
#  'Liberation Sans',
#  'NanumSquareRound',
#  'Liberation Sans Narrow',
#  'NanumGothic',
#  'Liberation Mono',
#  'Liberation Serif',
#  'Liberation Sans',
#  'NanumSquare',
#  'NanumGothic',
#  'Liberation Mono',
#  'Liberation Mono',
#  'NanumSquareRound']

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/mini_project/파이널프로젝트_RAW_210329_210926.xlsx')
df.head()
# Out:
#        id  customer_id  course_id     type      state  \
# 0  970634     504760.0   201435.0    ORDER  CANCELLED
# 1  970650     432862.0   203178.0    ORDER  CANCELLED
# 2  970657      72297.0   204246.0  PAYMENT  COMPLETED
# 3  970656      72297.0   204246.0    ORDER  CANCELLED
# 4  970658     478028.0   201797.0  PAYMENT  COMPLETED
#
#                     course_title category_title  format        completed_at  \
# 0      올인원 패키지 : 알고리즘 기술면접 완전 정복          프로그래밍     올인원 2021-03-28 15:00:11
# 1    초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원 2021-03-28 15:16:53
# 2           시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인 2021-03-28 15:21:43
# 3           시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인 2021-03-28 15:21:43
# 4  올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성     올인원 2021-03-28 15:21:54
#
#    transaction_amount              coupon_title  coupon_discount_amount  \
# 0               90500                       NaN                     NaN
# 1               96000                       NaN                     NaN
# 2              171810     [10% 할인] 시크릿코드 실무 완성편                 19090.0
# 3              171810                       NaN                     NaN
# 4               97500  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
#
#    sale_price  tax_free_amount   pg method subcategory_title  \
# 0    110500.0         110500.0  NaN  VBANK           개발자 커리어
# 1    116000.0         116000.0  NaN   CARD             영상 편집
# 2    190900.0         190900.0  NaN   CARD               NaN
# 3    190900.0         190900.0  NaN   CARD               NaN
# 4    117500.0         117500.0  NaN   CARD           PPT/보고서
#
#   marketing_start_at
# 0                NaT
# 1         2020-12-02
# 2         2021-03-04
# 3         2021-03-04
# 4         2019-11-14

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105419 entries, 0 to 105418
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      105419 non-null  int64
#  1   customer_id             105416 non-null  float64
#  2   course_id               100212 non-null  float64
#  3   type                    105419 non-null  object
#  4   state                   105419 non-null  object
#  5   course_title            105403 non-null  object
#  6   category_title          105395 non-null  object
#  7   format                  105403 non-null  object
#  8   completed_at            105419 non-null  datetime64[ns]
#  9   transaction_amount      105419 non-null  int64
#  10  coupon_title            31817 non-null   object
#  11  coupon_discount_amount  31817 non-null   float64
#  12  sale_price              104291 non-null  float64
#  13  tax_free_amount         104291 non-null  float64
#  14  pg                      90344 non-null   object
#  15  method                  92323 non-null   object
#  16  subcategory_title       85590 non-null   object
#  17  marketing_start_at      87440 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(5), int64(2), object(9)
# memory usage: 14.5+ MB

# %%
df = df[['customer_id', 'type', 'state' , 'course_title', 'category_title', 'transaction_amount', 'coupon_title', 'coupon_discount_amount', 'sale_price', 'subcategory_title']]
df.head()
# Out:
#    customer_id     type      state                   course_title  \
# 0     504760.0    ORDER  CANCELLED      올인원 패키지 : 알고리즘 기술면접 완전 정복
# 1     432862.0    ORDER  CANCELLED    초격차 패키지 : 한번에 끝내는 영상 촬영과 편집
# 2      72297.0  PAYMENT  COMPLETED           시크릿코드 : 프론트엔드 실무 완성편
# 3      72297.0    ORDER  CANCELLED           시크릿코드 : 프론트엔드 실무 완성편
# 4     478028.0  PAYMENT  COMPLETED  올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX
#
#   category_title  transaction_amount              coupon_title  \
# 0          프로그래밍               90500                       NaN
# 1          영상/3D               96000                       NaN
# 2          프로그래밍              171810     [10% 할인] 시크릿코드 실무 완성편
# 3          프로그래밍              171810                       NaN
# 4         업무 생산성               97500  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
#
#    coupon_discount_amount  sale_price subcategory_title
# 0                     NaN    110500.0           개발자 커리어
# 1                     NaN    116000.0             영상 편집
# 2                 19090.0    190900.0               NaN
# 3                     NaN    190900.0               NaN
# 4                 20000.0    117500.0           PPT/보고서

# %%
df.info()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105419 entries, 0 to 105418
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   customer_id             105416 non-null  float64
#  1   type                    105419 non-null  object
#  2   state                   105419 non-null  object
#  3   course_title            105403 non-null  object
#  4   category_title          105395 non-null  object
#  5   transaction_amount      105419 non-null  int64
#  6   coupon_title            31817 non-null   object
#  7   coupon_discount_amount  31817 non-null   float64
#  8   sale_price              104291 non-null  float64
#  9   subcategory_title       85590 non-null   object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 8.0+ MB
# customer_id                   3
# type                          0
# state                         0
# course_title                 16
# category_title               24
# transaction_amount            0
# coupon_title              73602
# coupon_discount_amount    73602
# sale_price                 1128
# subcategory_title         19829
# dtype: int64

# %% [markdown]
# ## category 8개로 축약하기 (정제)

# %%
df['category_title'].value_counts().to_frame()
# Out:
#           category_title
# 프로그래밍              34430
# 데이터사이언스            14076
# 업무 생산성             13323
# 디자인                12009
# 영상/3D              10260
# 마케팅                 9857
# 부동산/금융              5523
# 투자/재테크              2501
# 크리에이티브              2250
# 교육                  1031
# 지식콘텐츠                 56
# 비즈니스                  42
# 파이낸스                  25
# 데이터 사이언스               9
# 관리                     2
# 일러스트                   1

# %%
df = df.replace({'category_title':{'일러스트':'디자인'}})
df = df.replace({'category_title':{'데이터 사이언스':'데이터사이언스'}})
df['category_title'].value_counts().to_frame()
# Out:
#          category_title
# 프로그래밍             34430
# 데이터사이언스           14085
# 업무 생산성            13323
# 디자인               12010
# 영상/3D             10260
# 마케팅                9857
# 부동산/금융             5523
# 투자/재테크             2501
# 크리에이티브             2250
# 교육                 1031
# 지식콘텐츠                56
# 비즈니스                 42
# 파이낸스                 25
# 관리                    2

# %%
df = df[df.category_title != '교육']
df = df[df.category_title != '지식콘텐츠']
df = df[df.category_title != '비즈니스']
df = df[df.category_title != '파이낸스']
df = df[df.category_title != '관리']

df['category_title'].value_counts().to_frame()
# Out:
#          category_title
# 프로그래밍             34430
# 데이터사이언스           14085
# 업무 생산성            13323
# 디자인               12010
# 영상/3D             10260
# 마케팅                9857
# 부동산/금융             5523
# 투자/재테크             2501
# 크리에이티브             2250

# %%
df = df[df.category_title != '크리에이티브']
df['category_title'].value_counts().to_frame()
# Out:
#          category_title
# 프로그래밍             34430
# 데이터사이언스           14085
# 업무 생산성            13323
# 디자인               12010
# 영상/3D             10260
# 마케팅                9857
# 부동산/금융             5523
# 투자/재테크             2501

# %%
df.isna().sum()
# Out:
# customer_id                   3
# type                          0
# state                         0
# course_title                 16
# category_title               24
# transaction_amount            0
# coupon_title              70532
# coupon_discount_amount    70532
# sale_price                  208
# subcategory_title         16423
# dtype: int64

# %%
# 결측치 제거
df = df.dropna(subset=['category_title']) 
df.isna().sum()
# Out:
# customer_id                   0
# type                          0
# state                         0
# course_title                  0
# category_title                0
# transaction_amount            0
# coupon_title              70508
# coupon_discount_amount    70508
# sale_price                  192
# subcategory_title         16399
# dtype: int64

# %%
sub_df = df.copy()

# %%
sub_df = df.dropna(subset=['subcategory_title'])
sub_df.isna().sum()
# Out:
# customer_id                   0
# type                          0
# state                         0
# course_title                  0
# category_title                0
# transaction_amount            0
# coupon_title              56468
# coupon_discount_amount    56468
# sale_price                   28
# subcategory_title             0
# dtype: int64

# %%
sub_df[sub_df['sale_price'].isnull()] 
sub_df = sub_df.dropna(subset=['sale_price'])
sub_df.isna().sum()
# Out:
# customer_id                   0
# type                          0
# state                         0
# course_title                  0
# category_title                0
# transaction_amount            0
# coupon_title              56440
# coupon_discount_amount    56440
# sale_price                    0
# subcategory_title             0
# dtype: int64

# %%
sub_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85562 entries, 0 to 105418
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             85562 non-null  float64
#  1   type                    85562 non-null  object
#  2   state                   85562 non-null  object
#  3   course_title            85562 non-null  object
#  4   category_title          85562 non-null  object
#  5   transaction_amount      85562 non-null  int64
#  6   coupon_title            29122 non-null  object
#  7   coupon_discount_amount  29122 non-null  float64
#  8   sale_price              85562 non-null  float64
#  9   subcategory_title       85562 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 7.2+ MB

# %% [markdown]
# ## 구매자 [PAYMENT.COMPLETED.customer_id - REFUND.COMPLETED.customer_id] (정제)

# %%
a = sub_df['type'] == 'PAYMENT'
a = sub_df[a]
b = a['state'] == 'COMPLETED'
a = a[b]
a
# Out:
#         customer_id     type      state                     course_title  \
# 4          478028.0  PAYMENT  COMPLETED    올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX
# 8          478033.0  PAYMENT  COMPLETED      초격차 패키지 : 한번에 끝내는 영상 촬영과 편집
# 14         478035.0  PAYMENT  COMPLETED      초격차 패키지 : 한 번에 끝내는 프론트엔드 개발
# 22         455311.0  PAYMENT  COMPLETED      The RED : 현실 세상의 TDD by 이규원
# 28         471759.0  PAYMENT  COMPLETED       올인원 패키지 : 마디아의 UX/UI 포트폴리오
# ...             ...      ...        ...                              ...
# 105411     669238.0  PAYMENT  COMPLETED       초격차 패키지 : 한번에 끝내는 3D 디자인 툴
# 105412     384003.0  PAYMENT  COMPLETED      초격차 패키지 : 한번에 끝내는 영상 촬영과 편집
# 105413     670891.0  PAYMENT  COMPLETED      초격차 패키지 : 한 번에 끝내는 파이썬 웹 개발
# 105416     640697.0  PAYMENT  COMPLETED  초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기
# 105418     610626.0  PAYMENT  COMPLETED               용호수의 돈 버는 실전 영상 제작
#
#        category_title  transaction_amount               coupon_title  \
# 4              업무 생산성               97500   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 8               영상/3D               96000   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 14              프로그래밍               91000   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 22              프로그래밍              149500                        NaN
# 28                디자인               89000   [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰
# ...               ...                 ...                        ...
# 105411            디자인              212000    [미래투자금] 온라인 강의 2만원 할인쿠폰
# 105412          영상/3D              149000                        NaN
# 105413          프로그래밍              159000    [미래투자금] 온라인 강의 2만원 할인쿠폰
# 105416          영상/3D               96000  [WELCOME] 온라인 강의 2만원 할인쿠폰
# 105418          영상/3D              139000  [WELCOME] 온라인 강의 3만원 할인쿠폰
#
#         coupon_discount_amount  sale_price subcategory_title
# 4                      20000.0    117500.0           PPT/보고서
# 8                      20000.0    116000.0             영상 편집
# 14                     20000.0    111000.0          프론트엔드 개발
# 22                         NaN    149500.0            DevOps
# 28                     10000.0     99000.0             UX/UI
# ...                        ...         ...               ...
# 105411                 20000.0    232000.0              디자인툴
# 105412                     NaN    149000.0             영상 편집
# 105413                 20000.0    179000.0            백엔드 개발
# 105416                 20000.0    116000.0             영상 편집
# 105418                 30000.0    169000.0             영상 편집
#
# [43446 rows x 10 columns]

# %%
c = sub_df['type'] == 'REFUND'
c = sub_df[c]
d = c['state'] == 'COMPLETED'
b = c[d]
b
# Out:
#         customer_id    type      state  \
# 652        472666.0  REFUND  COMPLETED
# 666        447177.0  REFUND  COMPLETED
# 676        469406.0  REFUND  COMPLETED
# 701        456206.0  REFUND  COMPLETED
# 814         23129.0  REFUND  COMPLETED
# ...             ...     ...        ...
# 105168     670215.0  REFUND  COMPLETED
# 105169     600073.0  REFUND  COMPLETED
# 105205     506356.0  REFUND  COMPLETED
# 105245     604077.0  REFUND  COMPLETED
# 105248     552100.0  REFUND  COMPLETED
#
#                                             course_title category_title  \
# 652                          초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D
# 666                   올인원 패키지 : 소금툰과 함께 캐릭터 드로잉/굿즈/임티/컷툰            디자인
# 676                         올인원 패키지 : Financial Modeling         부동산/금융
# 701                              초격차 패키지 : 한번에 끝내는 디자인 툴            디자인
# 814                              초격차 패키지 : 한번에 끝내는 모션그래픽          영상/3D
# ...                                                  ...            ...
# 105168            The RED : 김영하 작가의 내 안의 숨은 이야기를 찾아 쓰는 법            마케팅
# 105169  (프로모션 7/16-7/29) 초격차 패키지 : 한 번에 끝내는 Spring 완.전.판          프로그래밍
# 105205                                용호수의 돈 버는 실전 영상 제작          영상/3D
# 105245                     올인원 패키지 : 공여사와 무작정 풀어보는 엑셀 실무         업무 생산성
# 105248            초격차 패키지 : 한번에 끝내는 Java/Spring 웹 개발 마스터          프로그래밍
#
#         transaction_amount coupon_title  coupon_discount_amount  sale_price  \
# 652                 -96000          NaN                     NaN    116000.0
# 666                 -79000          NaN                     NaN     89000.0
# 676                -125000          NaN                     NaN    145000.0
# 701                -140000          NaN                     NaN    170000.0
# 814                -132050          NaN                     NaN    139000.0
# ...                    ...          ...                     ...         ...
# 105168             -171000          NaN                     NaN    171000.0
# 105169             -149000          NaN                     NaN    179000.0
# 105205             -259000          NaN                     NaN    259000.0
# 105245             -109000          NaN                     NaN    129000.0
# 105248             -108186          NaN                     NaN    114000.0
#
#        subcategory_title
# 652                영상 편집
# 666                 일러스트
# 676             금융/투자 실무
# 701                 디자인툴
# 814                모션그래픽
# ...                  ...
# 105168         글쓰기/카피라이팅
# 105169            백엔드 개발
# 105205             영상 편집
# 105245            엑셀/VBA
# 105248            백엔드 개발
#
# [2949 rows x 10 columns]

# %%
df_total = pd.merge(a,b,how='outer')
df_total
# Out:
#        customer_id     type      state  \
# 0         478028.0  PAYMENT  COMPLETED
# 1         478033.0  PAYMENT  COMPLETED
# 2         478035.0  PAYMENT  COMPLETED
# 3         455311.0  PAYMENT  COMPLETED
# 4         471759.0  PAYMENT  COMPLETED
# ...            ...      ...        ...
# 46390     670215.0   REFUND  COMPLETED
# 46391     600073.0   REFUND  COMPLETED
# 46392     506356.0   REFUND  COMPLETED
# 46393     604077.0   REFUND  COMPLETED
# 46394     552100.0   REFUND  COMPLETED
#
#                                            course_title category_title  \
# 0                         올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성
# 1                           초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D
# 2                           초격차 패키지 : 한 번에 끝내는 프론트엔드 개발          프로그래밍
# 3                           The RED : 현실 세상의 TDD by 이규원          프로그래밍
# 4                            올인원 패키지 : 마디아의 UX/UI 포트폴리오            디자인
# ...                                                 ...            ...
# 46390            The RED : 김영하 작가의 내 안의 숨은 이야기를 찾아 쓰는 법            마케팅
# 46391  (프로모션 7/16-7/29) 초격차 패키지 : 한 번에 끝내는 Spring 완.전.판          프로그래밍
# 46392                                용호수의 돈 버는 실전 영상 제작          영상/3D
# 46393                     올인원 패키지 : 공여사와 무작정 풀어보는 엑셀 실무         업무 생산성
# 46394            초격차 패키지 : 한번에 끝내는 Java/Spring 웹 개발 마스터          프로그래밍
#
#        transaction_amount              coupon_title  coupon_discount_amount  \
# 0                   97500  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 1                   96000  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 2                   91000  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 3                  149500                       NaN                     NaN
# 4                   89000  [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰                 10000.0
# ...                   ...                       ...                     ...
# 46390             -171000                       NaN                     NaN
# 46391             -149000                       NaN                     NaN
# 46392             -259000                       NaN                     NaN
# 46393             -109000                       NaN                     NaN
# 46394             -108186                       NaN                     NaN
#
#        sale_price subcategory_title
# 0        117500.0           PPT/보고서
# 1        116000.0             영상 편집
# 2        111000.0          프론트엔드 개발
# 3        149500.0            DevOps
# 4         99000.0             UX/UI
# ...           ...               ...
# 46390    171000.0         글쓰기/카피라이팅
# 46391    179000.0            백엔드 개발
# 46392    259000.0             영상 편집
# 46393    129000.0            엑셀/VBA
# 46394    114000.0            백엔드 개발
#
# [46395 rows x 10 columns]

# %%
# df_total = df_total.drop_duplicates(subset='customer_id')
df_total = df_total.drop_duplicates(['customer_id' , 'course_title','coupon_title'],keep = 'last')

# %%
df_pay = df_total['type'] == 'PAYMENT'
df_pay = df_total[df_pay]
df_pay
# Out:
#        customer_id     type      state                     course_title  \
# 0         478028.0  PAYMENT  COMPLETED    올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX
# 1         478033.0  PAYMENT  COMPLETED      초격차 패키지 : 한번에 끝내는 영상 촬영과 편집
# 2         478035.0  PAYMENT  COMPLETED      초격차 패키지 : 한 번에 끝내는 프론트엔드 개발
# 3         455311.0  PAYMENT  COMPLETED      The RED : 현실 세상의 TDD by 이규원
# 4         471759.0  PAYMENT  COMPLETED       올인원 패키지 : 마디아의 UX/UI 포트폴리오
# ...            ...      ...        ...                              ...
# 43441     669238.0  PAYMENT  COMPLETED       초격차 패키지 : 한번에 끝내는 3D 디자인 툴
# 43442     384003.0  PAYMENT  COMPLETED      초격차 패키지 : 한번에 끝내는 영상 촬영과 편집
# 43443     670891.0  PAYMENT  COMPLETED      초격차 패키지 : 한 번에 끝내는 파이썬 웹 개발
# 43444     640697.0  PAYMENT  COMPLETED  초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기
# 43445     610626.0  PAYMENT  COMPLETED               용호수의 돈 버는 실전 영상 제작
#
#       category_title  transaction_amount               coupon_title  \
# 0             업무 생산성               97500   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 1              영상/3D               96000   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 2              프로그래밍               91000   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 3              프로그래밍              149500                        NaN
# 4                디자인               89000   [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰
# ...              ...                 ...                        ...
# 43441            디자인              212000    [미래투자금] 온라인 강의 2만원 할인쿠폰
# 43442          영상/3D              149000                        NaN
# 43443          프로그래밍              159000    [미래투자금] 온라인 강의 2만원 할인쿠폰
# 43444          영상/3D               96000  [WELCOME] 온라인 강의 2만원 할인쿠폰
# 43445          영상/3D              139000  [WELCOME] 온라인 강의 3만원 할인쿠폰
#
#        coupon_discount_amount  sale_price subcategory_title
# 0                     20000.0    117500.0           PPT/보고서
# 1                     20000.0    116000.0             영상 편집
# 2                     20000.0    111000.0          프론트엔드 개발
# 3                         NaN    149500.0            DevOps
# 4                     10000.0     99000.0             UX/UI
# ...                       ...         ...               ...
# 43441                 20000.0    232000.0              디자인툴
# 43442                     NaN    149000.0             영상 편집
# 43443                 20000.0    179000.0            백엔드 개발
# 43444                 20000.0    116000.0             영상 편집
# 43445                 30000.0    169000.0             영상 편집
#
# [42427 rows x 10 columns]

# %%
a.head()
# Out:
#     customer_id     type      state                   course_title  \
# 4      478028.0  PAYMENT  COMPLETED  올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX
# 8      478033.0  PAYMENT  COMPLETED    초격차 패키지 : 한번에 끝내는 영상 촬영과 편집
# 14     478035.0  PAYMENT  COMPLETED    초격차 패키지 : 한 번에 끝내는 프론트엔드 개발
# 22     455311.0  PAYMENT  COMPLETED    The RED : 현실 세상의 TDD by 이규원
# 28     471759.0  PAYMENT  COMPLETED     올인원 패키지 : 마디아의 UX/UI 포트폴리오
#
#    category_title  transaction_amount              coupon_title  \
# 4          업무 생산성               97500  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 8           영상/3D               96000  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 14          프로그래밍               91000  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 22          프로그래밍              149500                       NaN
# 28            디자인               89000  [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰
#
#     coupon_discount_amount  sale_price subcategory_title
# 4                  20000.0    117500.0           PPT/보고서
# 8                  20000.0    116000.0             영상 편집
# 14                 20000.0    111000.0          프론트엔드 개발
# 22                     NaN    149500.0            DevOps
# 28                 10000.0     99000.0             UX/UI

# %% [markdown]
# ## 재결재율:
# 1. 웰컴 할인쿠폰을 받은 사람 중 재결재률

# %%
df_pay['coupon_title'].value_counts()
# Out:
# [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                                3616
# [WELCOME] 온라인 강의 3만원 할인쿠폰                               2143
# [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰                                1657
# [WELCOME] 온라인 강의 2만원 할인쿠폰                               1656
# [WELCOME] 온라인 강의 1만원 할인쿠폰                               1332
#                                                         ...
# [분할결제쿠폰]초격차 패키지 : 한 번에 끝내는 node.js 웹 프로그래밍_30,458원결제       1
# [테스트쿠폰] 네이버 페이 간편결제 테스트용 쿠폰                                1
# 디지털 마케팅 MAX 무료 수강 쿠폰 (신수현)                                 1
# [무료수강권] 완전정복! 시각디자인 기초_김진희 강사님                             1
# [재결제쿠폰]초격차 패키지 : 한 번에 끝내는 node.js 웹 프로그래밍                  1
# Name: coupon_title, Length: 404, dtype: int64

# %%
sub_df['coupon_title'].value_counts()
# Out:
# [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                      5146
# [WELCOME] 온라인 강의 3만원 할인쿠폰                     3206
# [WELCOME] 온라인 강의 2만원 할인쿠폰                     2325
# [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰                      2301
# [WELCOME] 온라인 강의 1만원 할인쿠폰                     1899
#                                               ...
# [무료수강권] 부동산 디벨로퍼                                 1
# 한 번에 끝내는 Java/Sring 웹 개발 마스터 초격차 패키지 무료 쿠폰       1
# [CX] 관리자 외 계정 테스트용                               1
# 김영하 강의 후기 쿠폰                                     1
# [재결제쿠폰]초격차 패키지 : 한 번에 끝내는 node.js 웹 프로그래밍        1
# Name: coupon_title, Length: 418, dtype: int64

# %%
# 쿠폰 사용자 추출
coupon_df = sub_df[(sub_df['coupon_title'].str.contains('웰컴')) | (sub_df['coupon_title'].str.contains('WELCOME'))]
coupon_df
# Out:
#         customer_id     type      state  \
# 4          478028.0  PAYMENT  COMPLETED
# 8          478033.0  PAYMENT  COMPLETED
# 14         478035.0  PAYMENT  COMPLETED
# 15         478035.0    ORDER  CANCELLED
# 28         471759.0  PAYMENT  COMPLETED
# ...             ...      ...        ...
# 105393     638903.0  PAYMENT  COMPLETED
# 105396     623392.0  PAYMENT  CANCELLED
# 105414     640697.0  PAYMENT  CANCELLED
# 105416     640697.0  PAYMENT  COMPLETED
# 105418     610626.0  PAYMENT  COMPLETED
#
#                                     course_title category_title  \
# 4                  올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성
# 8                    초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D
# 14                   초격차 패키지 : 한 번에 끝내는 프론트엔드 개발          프로그래밍
# 15                   초격차 패키지 : 한 번에 끝내는 프론트엔드 개발          프로그래밍
# 28                    올인원 패키지 : 마디아의 UX/UI 포트폴리오            디자인
# ...                                          ...            ...
# 105393               초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D
# 105396  초격차 패키지 : 한 번에 끝내는 컴퓨터 공학 전공필수 & 인공지능 심화          프로그래밍
# 105414           초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기          영상/3D
# 105416           초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기          영상/3D
# 105418                        용호수의 돈 버는 실전 영상 제작          영상/3D
#
#         transaction_amount               coupon_title  coupon_discount_amount  \
# 4                    97500   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 8                    96000   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 14                   91000   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 15                   91000   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
# 28                   89000   [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰                 10000.0
# ...                    ...                        ...                     ...
# 105393              139000  [WELCOME] 온라인 강의 1만원 할인쿠폰                 10000.0
# 105396              173000  [WELCOME] 온라인 강의 3만원 할인쿠폰                 30000.0
# 105414               96000  [WELCOME] 온라인 강의 2만원 할인쿠폰                 20000.0
# 105416               96000  [WELCOME] 온라인 강의 2만원 할인쿠폰                 20000.0
# 105418              139000  [WELCOME] 온라인 강의 3만원 할인쿠폰                 30000.0
#
#         sale_price subcategory_title
# 4         117500.0           PPT/보고서
# 8         116000.0             영상 편집
# 14        111000.0          프론트엔드 개발
# 15        111000.0          프론트엔드 개발
# 28         99000.0             UX/UI
# ...            ...               ...
# 105393    149000.0             영상 편집
# 105396    203000.0           개발자 커리어
# 105414    116000.0             영상 편집
# 105416    116000.0             영상 편집
# 105418    169000.0             영상 편집
#
# [16167 rows x 10 columns]

# %%
# 쿠폰 사용자 중, customer_id 중복값 추출
dup = coupon_df.duplicated(['customer_id'], keep=False)
overlap_df = coupon_df[dup]
overlap_df
# Out:
#         customer_id     type      state                     course_title  \
# 14         478035.0  PAYMENT  COMPLETED      초격차 패키지 : 한 번에 끝내는 프론트엔드 개발
# 15         478035.0    ORDER  CANCELLED      초격차 패키지 : 한 번에 끝내는 프론트엔드 개발
# 38         474083.0    ORDER  CANCELLED          초격차 패키지 : 한번에 끝내는 모션그래픽
# 39         474083.0    ORDER  CANCELLED          초격차 패키지 : 한번에 끝내는 모션그래픽
# 42         474083.0    ORDER  CANCELLED          초격차 패키지 : 한번에 끝내는 모션그래픽
# ...             ...      ...        ...                              ...
# 105362     639924.0  PAYMENT  CANCELLED    올인원 패키지 : 해외소싱으로 온라인 커머스 정복하기
# 105387     638903.0  PAYMENT  COMPLETED               용호수의 돈 버는 실전 영상 제작
# 105393     638903.0  PAYMENT  COMPLETED      초격차 패키지 : 한번에 끝내는 영상 촬영과 편집
# 105414     640697.0  PAYMENT  CANCELLED  초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기
# 105416     640697.0  PAYMENT  COMPLETED  초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기
#
#        category_title  transaction_amount               coupon_title  \
# 14              프로그래밍               91000   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 15              프로그래밍               91000   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 38              영상/3D              119000   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 39              영상/3D              119000   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 42              영상/3D              119000   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# ...               ...                 ...                        ...
# 105362            마케팅              159000  [WELCOME] 온라인 강의 1만원 할인쿠폰
# 105387          영상/3D              159000  [WELCOME] 온라인 강의 1만원 할인쿠폰
# 105393          영상/3D              139000  [WELCOME] 온라인 강의 1만원 할인쿠폰
# 105414          영상/3D               96000  [WELCOME] 온라인 강의 2만원 할인쿠폰
# 105416          영상/3D               96000  [WELCOME] 온라인 강의 2만원 할인쿠폰
#
#         coupon_discount_amount  sale_price subcategory_title
# 14                     20000.0    111000.0          프론트엔드 개발
# 15                     20000.0    111000.0          프론트엔드 개발
# 38                     20000.0    139000.0             모션그래픽
# 39                     20000.0    139000.0             모션그래픽
# 42                     20000.0    139000.0             모션그래픽
# ...                        ...         ...               ...
# 105362                 10000.0    169000.0            SNS마케팅
# 105387                 10000.0    169000.0             영상 편집
# 105393                 10000.0    149000.0             영상 편집
# 105414                 20000.0    116000.0             영상 편집
# 105416                 20000.0    116000.0             영상 편집
#
# [6375 rows x 10 columns]

# %%
# 웰컴 쿠폰 사용자중 

fig = plt.figure(figsize=(16,10))
graph1 = fig.add_subplot(1,2,1)
overlap_df['state'].value_counts().plot.pie(autopct='%1.2f%%',ax=graph1)
graph1.set_title('재 구매율')
graph1.set_ylabel('')
graph2 = fig.add_subplot(1,2,2)
sns.countplot('state',data=overlap_df,ax=graph2)
graph2.set_title('재 구매율')
plt.show(fig)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## 강의 가격
# 1. 같은 카테고리 안에서 서브 카테고리별 높은 가격 vs 낮은 가격 (인기)

# %%
sub_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85562 entries, 0 to 105418
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             85562 non-null  float64
#  1   type                    85562 non-null  object
#  2   state                   85562 non-null  object
#  3   course_title            85562 non-null  object
#  4   category_title          85562 non-null  object
#  5   transaction_amount      85562 non-null  int64
#  6   coupon_title            29122 non-null  object
#  7   coupon_discount_amount  29122 non-null  float64
#  8   sale_price              85562 non-null  float64
#  9   subcategory_title       85562 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 7.2+ MB

# %%
sub_df.category_title.value_counts()
# Out:
# 프로그래밍      26285
# 디자인        11989
# 데이터사이언스    11122
# 영상/3D      10251
# 업무 생산성      9451
# 마케팅         8770
# 부동산/금융      5193
# 투자/재테크      2501
# Name: category_title, dtype: int64

# %%
# 프로그래밍
cate1_df = sub_df[sub_df['category_title'] == '프로그래밍']
cate1_df

how = {
    "sale_price" : np.mean
}
subctgr1_df = cate1_df.groupby('subcategory_title').agg(how)

# 디자인
cate2_df = sub_df[sub_df['category_title'] == '디자인']
cate2_df

how = {
    "sale_price" : np.mean
}
subctgr2_df = cate2_df.groupby('subcategory_title').agg(how)

# 데이터사이언스
cate3_df = sub_df[sub_df['category_title'] == '데이터사이언스']
cate3_df

how = {
    "sale_price" : np.mean
}
subctgr3_df = cate3_df.groupby('subcategory_title').agg(how)

# 영상/ 3D
cate4_df = sub_df[sub_df['category_title'] == '영상/3D']
cate4_df

how = {
    "sale_price" : np.mean
}
subctgr4_df = cate4_df.groupby('subcategory_title').agg(how)

# 업무 생산성
cate5_df = sub_df[sub_df['category_title'] == '업무 생산성']
cate5_df

how = {
    "sale_price" : np.mean
}
subctgr5_df = cate5_df.groupby('subcategory_title').agg(how)

# 마케팅
cate6_df = sub_df[sub_df['category_title'] == '마케팅']
cate6_df

how = {
    "sale_price" : np.mean
}
subctgr6_df = cate6_df.groupby('subcategory_title').agg(how)

# 부동산 금융
cate7_df = sub_df[sub_df['category_title'] == '부동산/금융']
cate7_df

how = {
    "sale_price" : np.mean
}
subctgr7_df = cate7_df.groupby('subcategory_title').agg(how)

# 투자/재테크
cate8_df = sub_df[sub_df['category_title'] == '투자/재테크']
cate8_df

how = {
    "sale_price" : np.mean
}
subctgr8_df = cate8_df.groupby('subcategory_title').agg(how)

test_df.plot.barh()

# %%
fig = plt.figure(figsize=(30,30))
graph1 = fig.add_subplot(2,4,1)
graph2 = fig.add_subplot(2,4,2)
graph3 = fig.add_subplot(2,4,3)
graph4 = fig.add_subplot(2,4,4)
graph5 = fig.add_subplot(2,4,5)
graph6 = fig.add_subplot(2,4,6)
graph7 = fig.add_subplot(2,4,7)
graph8 = fig.add_subplot(2,4,8)

subctgr1_df.plot.barh(ax=graph1)
subctgr2_df.plot.barh(ax=graph2)
subctgr3_df.plot.barh(ax=graph3)
subctgr4_df.plot.barh(ax=graph4)
subctgr5_df.plot.barh(ax=graph5)
subctgr6_df.plot.barh(ax=graph6)
subctgr7_df.plot.barh(ax=graph7)
subctgr8_df.plot.barh(ax=graph8)

# %% [markdown]
# ## 쿠폰 관련

# %%
# 판매가와 실 구매가가 다른 값 구하기
sale_df = sub_df[sub_df['sale_price'] != sub_df['transaction_amount']]
# sale_df.info()
# 강의명에 '샘플'값 들어간 데이터 지우기
sample_df = sale_df[sale_df['course_title'].str.contains('샘플')].index
sale_df.drop(sample_df, inplace=True)
sale_df[sale_df.course_title.str.contains('테스트')]
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#         customer_id     type      state  \
# 13231      496790.0    ORDER  CANCELLED
# 13232      496790.0  PAYMENT  COMPLETED
# 13458      494922.0    ORDER  CANCELLED
# 13527       25280.0    ORDER  CANCELLED
# 13843      498212.0  PAYMENT  COMPLETED
# ...             ...      ...        ...
# 104727     662606.0   REFUND  COMPLETED
# 104900     666018.0   REFUND  COMPLETED
# 105056     659482.0  PAYMENT  COMPLETED
# 105237     618278.0  PAYMENT  CANCELLED
# 105296     670557.0  PAYMENT  COMPLETED
#
#                                            course_title category_title  \
# 13231                초격차 패키지 : 한 번에 끝내는 코딩테스트 369 Java편          프로그래밍
# 13232                초격차 패키지 : 한 번에 끝내는 코딩테스트 369 Java편          프로그래밍
# 13458                초격차 패키지 : 한 번에 끝내는 코딩테스트 369 Java편          프로그래밍
# 13527                초격차 패키지 : 한 번에 끝내는 코딩테스트 369 Java편          프로그래밍
# 13843                초격차 패키지 : 한 번에 끝내는 코딩테스트 369 Java편          프로그래밍
# ...                                                 ...            ...
# 104727  The RED : 고객 경험을 개선하는 A/B테스트 기반 모바일 앱 개발 by 이승민          프로그래밍
# 104900               초격차 패키지 : 한 번에 끝내는 코딩테스트 369 Java편          프로그래밍
# 105056               초격차 패키지 : 한 번에 끝내는 코딩테스트 369 Java편          프로그래밍
# 105237               초격차 패키지 : 한 번에 끝내는 코딩테스트 369 Java편          프로그래밍
# 105296               초격차 패키지 : 한 번에 끝내는 코딩테스트 369 Java편          프로그래밍
#
#         transaction_amount               coupon_title  coupon_discount_amount  \
# 13231                79000                        NaN                     NaN
# 13232                79000   [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰                 10000.0
# 13458                79000                        NaN                     NaN
# 13527                79000                        NaN                     NaN
# 13843                79000   [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰                 10000.0
# ...                    ...                        ...                     ...
# 104727             -189000                        NaN                     NaN
# 104900             -111925                        NaN                     NaN
# 105056              121000    [미래투자금] 온라인 강의 1만원 할인쿠폰                 10000.0
# 105237              121000  [WELCOME] 온라인 강의 1만원 할인쿠폰                 10000.0
# 105296              121000    [미래투자금] 온라인 강의 1만원 할인쿠폰                 10000.0
#
#         sale_price subcategory_title
# 13231      89000.0           개발자 커리어
# 13232      89000.0           개발자 커리어
# 13458      89000.0           개발자 커리어
# 13527      89000.0           개발자 커리어
# 13843      89000.0           개발자 커리어
# ...            ...               ...
# 104727    189000.0              모바일앱
# 104900    131000.0           개발자 커리어
# 105056    131000.0           개발자 커리어
# 105237    131000.0           개발자 커리어
# 105296    131000.0           개발자 커리어
#
# [572 rows x 10 columns]

# %%
sale_df.course_title.value_counts()
# Out:
# 초격차 패키지 : 한 번에 끝내는 프론트엔드 개발               1767
# 초격차 패키지 : 한번에 끝내는 영상 촬영과 편집               1582
# 초격차 패키지 : 한번에 끝내는 Java/Spring 웹 개발 마스터    1525
# 초격차 패키지 : 한번에 끝내는 디자인 툴                    995
# 초격차 패키지 : 한번에 끝내는 UX/UI 디자인                793
#                                           ...
# The RED : 최고제품책임자(CPO) 윤희경                   5
# The RED : 데이터 사이언티스트 하용호                     5
# The RED : 프론트엔드 개발자 김태곤                      4
# The RED : 1조 기업 가치를 만들어 낸 경영 원칙 by 신현성       4
# 올인원 패키지 : Unity를 활용한 영화 애니메이션 제작             1
# Name: course_title, Length: 203, dtype: int64

# %%
sale_df[sale_df.sale_price < 10000]
# Out:
#        customer_id     type      state          course_title category_title  \
# 545       440315.0  PAYMENT  COMPLETED  합격 패스 : 정보처리기사 필기&실기          프로그래밍
# 556       459090.0  PAYMENT  COMPLETED  합격 패스 : 정보처리기사 필기&실기          프로그래밍
# 610       459433.0  PAYMENT  COMPLETED  합격 패스 : 정보처리기사 필기&실기          프로그래밍
# 826       461518.0  PAYMENT  COMPLETED  합격 패스 : 정보처리기사 필기&실기          프로그래밍
# 849       464874.0  PAYMENT  COMPLETED  합격 패스 : 정보처리기사 필기&실기          프로그래밍
# ...            ...      ...        ...                   ...            ...
# 95641     641292.0  PAYMENT  COMPLETED  합격 패스 : 정보처리기사 필기&실기          프로그래밍
# 95970     640661.0  PAYMENT  COMPLETED  합격 패스 : 정보처리기사 필기&실기          프로그래밍
# 96810     650987.0  PAYMENT  COMPLETED  합격 패스 : 정보처리기사 필기&실기          프로그래밍
# 97057     651681.0  PAYMENT  COMPLETED  합격 패스 : 정보처리기사 필기&실기          프로그래밍
# 97175     617027.0  PAYMENT  COMPLETED  합격 패스 : 정보처리기사 필기&실기          프로그래밍
#
#        transaction_amount               coupon_title  coupon_discount_amount  \
# 545                     0   [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰                 10000.0
# 556                     0   [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰                 10000.0
# 610                     0      수강생 50만명 돌파 기념 감사제 쿠폰                110500.0
# 826                     0   [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰                 10000.0
# 849                     0   [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰                 10000.0
# ...                   ...                        ...                     ...
# 95641                   0  [WELCOME] 온라인 강의 1만원 할인쿠폰                 10000.0
# 95970                   0  [WELCOME] 온라인 강의 1만원 할인쿠폰                 10000.0
# 96810                4900    [미래투자금] 온라인 강의 5천원 할인쿠폰                  5000.0
# 97057                4900    [미래투자금] 온라인 강의 5천원 할인쿠폰                  5000.0
# 97175                   0  [WELCOME] 온라인 강의 1만원 할인쿠폰                 10000.0
#
#        sale_price subcategory_title
# 545        9900.0           개발자 커리어
# 556        9900.0           개발자 커리어
# 610        9900.0           개발자 커리어
# 826        9900.0           개발자 커리어
# 849        9900.0           개발자 커리어
# ...           ...               ...
# 95641      9900.0           개발자 커리어
# 95970      9900.0           개발자 커리어
# 96810      9900.0           개발자 커리어
# 97057      9900.0           개발자 커리어
# 97175      9900.0           개발자 커리어
#
# [193 rows x 10 columns]

# %%
a = df[df.sale_price < 10000]
a = a.course_title.value_counts()

# %%
a.plot.barh()

# %%
only_coupon = a['coupon_discount_amount'] > 0
only_coupon.value_counts()
# Out:
# False    72220
# True     31812
# Name: coupon_discount_amount, dtype: int64

# %%
# 재결제시 수단 여부

fig = plt.figure(figsize=(16,10))
graph1 = fig.add_subplot(1,2,1)
overlap_df['cateogty_title'].value_counts().plot.pie(autopct='%1.2f%%',ax=graph1)
graph1.set_title('카테고리')
graph1.set_ylabel('')
graph2 = fig.add_subplot(1,2,2)
sns.countplot('state',data=overlap_df,ax=graph2)
graph2.set_title('재 구매율')
plt.show(fig)

# %%
# 전체 강의 수강률

sub_df["course_title"].value_counts()
# Out:
# 초격차 패키지 : 한 번에 끝내는 프론트엔드 개발                                                   3255
# 초격차 패키지 : 한번에 끝내는 Java/Spring 웹 개발 마스터                                        2756
# 초격차 패키지 : 한번에 끝내는 영상 촬영과 편집                                                   2540
# The RED : 김영하 작가의 내 안의 숨은 이야기를 찾아 쓰는 법                                        2132
# 올인원 패키지 : star741의 캐주얼 일러스트 드로잉                                               1636
#                                                                               ...
# [묶음] 용호수의 입문+실전 강의를 한 번에!                                                        3
# OpenCV로 배우는 컴퓨터 비전 프로그래밍 22기                                                     2
# (B2B) K-Digital Training 핀테크 서비스 프론트엔드 개발 과정 1기                                  1
# 올인원 패키지 : SNS 콘텐츠 기획/제작 MAX 2020 + [20%할인쿠폰]초격차 패키지 : 무조건 팔리는 SNS 콘텐츠 끝장내기       1
# 올인원 패키지 : Unity를 활용한 영화 애니메이션 제작                                                 1
# Name: course_title, Length: 207, dtype: int64

# %%
df['course_title'].nunique()
# Out:
# 659

# %%
sub_df.isna().sum()
# Out:
# customer_id                   0
# type                          0
# state                         0
# course_title                  0
# category_title                0
# transaction_amount            0
# coupon_title              56440
# coupon_discount_amount    56440
# sale_price                    0
# subcategory_title             0
# dtype: int64

# %%
sub_df['course_title'].nunique()
# Out:
# 207

# %%
coti_df = cour_ti[cour_ti['course_title'].str.contains('패키지')]
co_df = coti_df[['course_title', 'transaction_amount']].value_counts()
cdf = co_df.to_frame()
cdf
# sns.scatterplot(data=cdf)
# Out:
#                                                                          0
# course_title                                       transaction_amount
# 올인원 패키지 : star741의 캐주얼 일러스트 드로잉                    144000              573
# 초격차 패키지 : 일잘러 필수 스킬 모음.zip                         109000              553
# 올인원 패키지 : 아카데미 : 편집하는여자의 영상편집 마스터클래스 - 제 1강 프리미... 98000               541
# 초격차 패키지 : 한 번에 끝내는 프론트엔드 개발                        95000               463
#                                                    116000              454
# ...                                                                    ...
# 올인원 패키지 : 수학적으로 접근하는 딥러닝                           76000                 1
#                                                    76500                 1
#                                                    84000                 1
#                                                    85000                 1
# 올인원 패키지 : 아파트 말고 부동산 재테크 시작하기                      222000                1
#
# [7374 rows x 1 columns]

# %%
df[['course_title', 'transaction_amount', 'sale_price']]
# Out:
#                            course_title  transaction_amount  sale_price
# 0             올인원 패키지 : 알고리즘 기술면접 완전 정복               90500    110500.0
# 1           초격차 패키지 : 한번에 끝내는 영상 촬영과 편집               96000    116000.0
# 2                  시크릿코드 : 프론트엔드 실무 완성편              171810    190900.0
# 3                  시크릿코드 : 프론트엔드 실무 완성편              171810    190900.0
# 4         올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX               97500    117500.0
# ...                                 ...                 ...         ...
# 105414  초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기               96000    116000.0
# 105415              부동산 디벨로퍼 아카데미 : 인허가              189000    189000.0
# 105416  초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기               96000    116000.0
# 105417              부동산 디벨로퍼 아카데미 : 인허가              189000    189000.0
# 105418               용호수의 돈 버는 실전 영상 제작              139000    169000.0
#
# [105419 rows x 3 columns]
